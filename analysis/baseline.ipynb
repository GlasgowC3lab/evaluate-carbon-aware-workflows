# %%
# Constants
ENERGY_CONSUMPTION = "Energy Consumption (exc. PUE)"
ENERGY_CONSUMPTION_PUE = "Energy Consumption (inc. PUE)"
MEMORY_CONSUMPTION = "Memory Energy Consumption (exc. PUE)"
MEMORY_CONSUMPTION_PUE = "Memory Energy Consumption (inc. PUE)"
CARBON_EMISSIONS = "Carbon Emissions"

# %%
# Parse Key Details from Summary Files
def get_data(lines):
    data = {}

    for line in lines:
        parts = line.strip().split(':')
        parts[0] = parts[0][2:].strip()
        data[parts[0]] = parts[1].replace('kWh', '').replace('gCO2e', '').strip()

    return data


def get_bonus_data(lines):
    data = {}

    for line in lines:
        if ':' in line: 
            parts = line.strip().split(':')

            if parts[0] == 'Task Runtime':
                continue

            data[parts[0]] = parts[1].replace('kWh', '').replace('gCO2e', '').strip()
        else:
            if '|' in line:
                cpu_mem_split = line.split('|')
                cpu = cpu_mem_split[0].strip()
                mem = cpu_mem_split[1].strip()

    data['cpu'] = cpu.replace('% CPU [', '').replace('%]', '')
    data['mem'] = mem.replace('% Memory [', '').replace('%]', '')

    return data


def parse_summary(filename):
    with open(filename, 'r') as file:
        lines = file.readlines()

    info = get_data(lines[2:5])
    data = get_data(lines[7:12])
    bonus = get_bonus_data(lines[12:])

    return (info, data, bonus)


def get_average(first, second, third):
    data = {}

    for key in first.keys():
        data[key] = (float(first[key]) + float(second[key]) + float(third[key])) / 3

    return data


def print_summary(data):
    print(f"{ENERGY_CONSUMPTION}: {data[ENERGY_CONSUMPTION]:.2f}kWh")
    print(f"{ENERGY_CONSUMPTION_PUE}: {data[ENERGY_CONSUMPTION_PUE]:.2f}kWh")
    print(f"{MEMORY_CONSUMPTION}: {data[MEMORY_CONSUMPTION]:.2f}kWh")
    print(f"{MEMORY_CONSUMPTION_PUE}: {data[MEMORY_CONSUMPTION_PUE]:.2f}kWh")
    print(f"{CARBON_EMISSIONS}: {data[CARBON_EMISSIONS]:.2f}gCO2e")


def print_bonus(data):
    RES_MEM_ENERGY_CONSUMPTION = "Reserved Memory Energy Consumption"
    REST_MEM_CARBON_EMISSIONS = "Reserved Memory Carbon Emissions"

    print(f"{RES_MEM_ENERGY_CONSUMPTION}: {data[RES_MEM_ENERGY_CONSUMPTION]:.2f}kWh")
    print(f"{REST_MEM_CARBON_EMISSIONS}: {data[REST_MEM_CARBON_EMISSIONS]:.2f}kWh")
    print(f"CPU [{data['cpu']:.2f}% | {data['mem']:.2f}%] Memory")


def print_info(data_1, data_2, data_3):
    matches = data_1 == data_2 == data_3

    if not matches:
        print("[ERROR] Workflow Data does not match ...")
        return

    print(f"INFO: CPU Energy Consumption [{data_1['min to max watts']}] | PUE [{data_1['power-usage-effectiveness']}] | Memory Energy Consumption [{data_1['memory-power-draw']} W/GB]") 


def report_summary_for(filename_1, filename_2, filename_3, bonus=False):
    (info_1, data_1, bonus_1) = parse_summary(filename_1)
    (info_2, data_2, bonus_2) = parse_summary(filename_2)
    (info_3, data_3, bonus_3) = parse_summary(filename_3)
    avg_data = get_average(data_1, data_2, data_3)

    if bonus:
        avg_bonus = get_average(bonus_1, bonus_2, bonus_3)
        print_info(info_1, info_2, info_3)
        print_summary(avg_data)
        print_bonus(avg_bonus)
    else:
        print_summary(avg_data)

    return avg_data[CARBON_EMISSIONS]

# %%
# Trace File Paths List
workflows = ['chipseq', 'mag', 'montage', 'nanoseq', 'rangeland', 'rnaseq', 'sarek']
memory = [128, 256, 128, 32, 256, 128, 128]
no_nodes = [8, 8, 8, 1, 8, 8, 8]
workflows_avg_folders = [f'data/traces/workflows/{workflow}/output/avg/' for workflow in workflows]
workflows_marg_folders = [f'data/traces/workflows/{workflow}/output/marg/' for workflow in workflows]
# [[f'{avg_path}/{workflow}-{iteration}-summary.txt' for iteration in range(1,4)] for (avg_path, workflow) in zip(workflows_avg_paths, workflows)]

# %%
# Display Data for Each Average Workflow
for folder, workflow, node_memory, nodes in zip(workflows_avg_folders, workflows, memory, no_nodes):
    print(f'\n{workflow}:')
    print(f'INFO: Node Memory [{node_memory} GB] | No. Nodes [{nodes}]')
    summary_files = [f'{folder}summary-{workflow}/{workflow}-{iteration}-summary.txt' for iteration in range(1, 4)]
    workflow_stats = report_summary_for(summary_files[0], summary_files[1], summary_files[2], bonus=True)
# Out:
# chipseq:
# INFO: Node Memory [128 GB] | No. Nodes [8]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 6
#       4 print(f'INFO: Node Memory [{node_memory} GB] | No. Nodes [{nodes}]')
#       5 summary_files = [f'{folder}summary-{workflow}/{workflow}-{iteration}-summary.txt' for iteration in range(1, 4)]
# ----> 6 workflow_stats = report_summary_for(summary_files[0], summary_files[1], summary_files[2], bonus=True)
#
# Cell In[2], line 84, in report_summary_for(filename_1, filename_2, filename_3, bonus)
#      83 def report_summary_for(filename_1, filename_2, filename_3, bonus=False):
# ---> 84     (info_1, data_1, bonus_1) = parse_summary(filename_1)
#      85     (info_2, data_2, bonus_2) = parse_summary(filename_2)
#      86     (info_3, data_3, bonus_3) = parse_summary(filename_3)
#
# Cell In[2], line 37, in parse_summary(filename)
#      36 def parse_summary(filename):
# ---> 37     with open(filename, 'r') as file:
#      38         lines = file.readlines()
#      40     info = get_data(lines[2:5])
#
# File /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/processed-traces/chipseq-avg/summary-chipseq/chipseq-1-summary.txt'

# %%
# Display Data for Each Marginal Workflow
for folder, workflow, node_memory, nodes in zip(workflows_marg_folders, workflows, memory, no_nodes):
    print(f'\n{workflow}:')
    print(f'INFO: Node Memory [{node_memory} GB] | No. Nodes [{nodes}]')
    summary_files = [f'{folder}summary-{workflow}/{workflow}-{iteration}-summary.txt' for iteration in range(1, 4)]
    workflow_stats = report_summary_for(summary_files[0], summary_files[1], summary_files[2], bonus=True)
# Out:
# chipseq:
# INFO: Node Memory [128 GB] | No. Nodes [8]
# INFO: CPU Energy Consumption [113.0W to 262.0W] | PUE [1.0] | Memory Energy Consumption [0.392 W/GB]
# Energy Consumption (exc. PUE): 35.16kWh
# Energy Consumption (inc. PUE): 35.16kWh
# Memory Energy Consumption (exc. PUE): 0.52kWh
# Memory Energy Consumption (inc. PUE): 0.52kWh
# Carbon Emissions: 27615.39gCO2e
# Reserved Memory Energy Consumption: 1.49kWh
# Reserved Memory Carbon Emissions: 1149.08kWh
# CPU [94.60% | 5.40%] Memory
#
# mag:
# INFO: Node Memory [256 GB] | No. Nodes [8]
# INFO: CPU Energy Consumption [80.0W to 135.0W] | PUE [1.0] | Memory Energy Consumption [0.392 W/GB]
# Energy Consumption (exc. PUE): 47.51kWh
# Energy Consumption (inc. PUE): 47.51kWh
# Memory Energy Consumption (exc. PUE): 2.59kWh
# Memory Energy Consumption (inc. PUE): 2.59kWh
# Carbon Emissions: 38983.77gCO2e
# Reserved Memory Energy Consumption: 10.14kWh
# Reserved Memory Carbon Emissions: 7876.42kWh
# CPU [78.87% | 21.13%] Memory
#
# montage:
# INFO: Node Memory [128 GB] | No. Nodes [8]
# INFO: CPU Energy Consumption [113.0W to 262.0W] | PUE [1.0] | Memory Energy Consumption [0.392 W/GB]
# Energy Consumption (exc. PUE): 1.03kWh
# Energy Consumption (inc. PUE): 1.03kWh
# Memory Energy Consumption (exc. PUE): 0.02kWh
# Memory Energy Consumption (inc. PUE): 0.02kWh
# Carbon Emissions: 791.00gCO2e
# Reserved Memory Energy Consumption: 0.21kWh
# Reserved Memory Carbon Emissions: 161.00kWh
# CPU [81.49% | 18.51%] Memory
#
# nanoseq:
# INFO: Node Memory [32 GB] | No. Nodes [1]
# INFO: CPU Energy Consumption [35.0W to 123.0W] | PUE [1.0] | Memory Energy Consumption [0.392 W/GB]
# Energy Consumption (exc. PUE): 0.54kWh
# Energy Consumption (inc. PUE): 0.54kWh
# Memory Energy Consumption (exc. PUE): 0.05kWh
# Memory Energy Consumption (inc. PUE): 0.05kWh
# Carbon Emissions: 232.36gCO2e
# Reserved Memory Energy Consumption: 0.07kWh
# Reserved Memory Carbon Emissions: 26.30kWh
# CPU [82.73% | 17.27%] Memory
#
# rangeland:
# INFO: Node Memory [256 GB] | No. Nodes [8]
# INFO: CPU Energy Consumption [80.0W to 135.0W] | PUE [1.0] | Memory Energy Consumption [0.392 W/GB]
# Energy Consumption (exc. PUE): 11.54kWh
# Energy Consumption (inc. PUE): 11.54kWh
# Memory Energy Consumption (exc. PUE): 1.46kWh
# Memory Energy Consumption (inc. PUE): 1.46kWh
# Carbon Emissions: 10074.96gCO2e
# Reserved Memory Energy Consumption: 5.53kWh
# Reserved Memory Carbon Emissions: 4276.88kWh
# CPU [62.27% | 37.73%] Memory
#
# rnaseq:
# INFO: Node Memory [128 GB] | No. Nodes [8]
# INFO: CPU Energy Consumption [113.0W to 262.0W] | PUE [1.0] | Memory Energy Consumption [0.392 W/GB]
# Energy Consumption (exc. PUE): 21.33kWh
# Energy Consumption (inc. PUE): 21.33kWh
# Memory Energy Consumption (exc. PUE): 0.59kWh
# Memory Energy Consumption (inc. PUE): 0.59kWh
# Carbon Emissions: 16865.30gCO2e
# Reserved Memory Energy Consumption: 1.23kWh
# Reserved Memory Carbon Emissions: 945.69kWh
# CPU [92.16% | 7.84%] Memory
#
# sarek:
# INFO: Node Memory [128 GB] | No. Nodes [8]
# INFO: CPU Energy Consumption [113.0W to 262.0W] | PUE [1.0] | Memory Energy Consumption [0.392 W/GB]
# Energy Consumption (exc. PUE): 66.60kWh
# Energy Consumption (inc. PUE): 66.60kWh
# Memory Energy Consumption (exc. PUE): 0.73kWh
# Memory Energy Consumption (inc. PUE): 0.73kWh
# Carbon Emissions: 51850.07gCO2e
# Reserved Memory Energy Consumption: 2.04kWh
# Reserved Memory Carbon Emissions: 1570.09kWh
# CPU [96.02% | 3.98%] Memory
