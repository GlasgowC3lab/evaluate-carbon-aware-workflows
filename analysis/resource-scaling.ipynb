# %%
# Imports
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl
from tabulate import tabulate

# %%
# Constants
regions = ['Great Britain', 'Germany', 'California', 'Texas', 'South Africa', 'Tokyo', 'New South Wales']
short_regions = ['gb', 'de', 'ca', 'tx', 'zaf', 'tyo', 'nsw']
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
short_months = ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec'] 
tasks=['bowtie2_build', 'fastp', 'fastqc', 'trimgalore']
machines=['gpg13', 'gpg14', 'gpg15', 'gpg22', 'hu26']
governors=['performance', 'powersave']

# %%
# Constants
ENERGY_CONSUMPTION = "Energy Consumption (exc. PUE)"
ENERGY_CONSUMPTION_PUE = "Energy Consumption (inc. PUE)"
MEMORY_CONSUMPTION = "Memory Energy Consumption (exc. PUE)"
MEMORY_CONSUMPTION_PUE = "Memory Energy Consumption (inc. PUE)"
CARBON_EMISSIONS = "Operational Carbon Emissions"
EMBODIED_CARBON_EMISSIONS = "Embodied Carbon Emissions"
TOTAL_CARBON_EMISSIONS = "Total Carbon Emissions"
RES_MEM_ENERGY_CONSUMPTION = "Reserved Memory Energy Consumption"
RES_MEM_CARBON_EMISSIONS = "Reserved Memory Carbon Emissions"

# %%
# Parse Key Details from Summary Files
def get_data(lines):
    data = {}

    for line in lines:
        parts = line.strip().split(':')
        parts[0] = parts[0][2:].strip()
        data[parts[0]] = parts[1].replace('kWh', '').replace('gCO2e', '').strip()

    return data


def parse_summary(filename):
    with open(filename, 'r') as file:
        lines = file.readlines()

    info = get_data(lines[2:5])
    data = get_data(lines[7:14])

    return (info, data)


def get_average(first, second, third):
    data = {}

    for key in first.keys():
        data[key] = (float(first[key]) + float(second[key]) + float(third[key])) / 3

    return data


def print_summary(data):
    return {
        ENERGY_CONSUMPTION: data[ENERGY_CONSUMPTION],
        MEMORY_CONSUMPTION: data[MEMORY_CONSUMPTION],
        CARBON_EMISSIONS: data[CARBON_EMISSIONS],
        EMBODIED_CARBON_EMISSIONS: data[EMBODIED_CARBON_EMISSIONS],
        TOTAL_CARBON_EMISSIONS: data[TOTAL_CARBON_EMISSIONS]
    }


def print_info(data_1, data_2, data_3):
    matches = data_1 == data_2 == data_3

    if not matches:
        print("[ERROR] Workflow Data does not match ...")
        return

def report_summary_for(filename_1, filename_2, filename_3):
    (_, data_1) = parse_summary(filename_1)
    (_, data_2) = parse_summary(filename_2)
    (_, data_3) = parse_summary(filename_3)
    avg_data = get_average(data_1, data_2, data_3)
    summary = print_summary(avg_data)

    return summary

# %% [markdown]
# **Workflow Task Resource Scaling -- Processor Governor**

# %%
# Process Data for each task on each machine, in each month of the year, for each region 
task_stats_avg = {}

for region in short_regions:
    task_stats_avg[region] = {}
    for month in short_months:
        task_stats_avg[region][month] = {}
        for task in tasks:
            task_stats_avg[region][month][task] = {}
            for machine in machines:
                task_stats_avg[region][month][task][machine] = {}
                for gov in governors:
                    temp_f = [f'../data/results/resource-scaling/tasks/out/{region}/{machine}-{gov}-{task}-{iteration}-{month}-{region}-2024-{month}-mid-{machine}_{gov}_linear-summary.txt' for iteration in range(1, 4)]
                    task_stats_avg[region][month][task][machine][gov] = report_summary_for(temp_f[0], temp_f[1], temp_f[2])

# %%
# Process Data for each task on each machine, in each month of the year, for each region 
task_stats_marg = {}

for region in short_regions:
    task_stats_marg[region] = {}
    for month in short_months:
        task_stats_marg[region][month] = {}
        for task in tasks:
            task_stats_marg[region][month][task] = {}
            for machine in machines:
                task_stats_marg[region][month][task][machine] = {}
                for gov in governors:
                    temp_f = [f'../data/results/resource-scaling/tasks/out/{region}/{machine}-{gov}-{task}-{iteration}-{month}-{region}-2024-{month}-mid-marg-{machine}_{gov}_linear-summary.txt' for iteration in range(1, 4)]
                    task_stats_marg[region][month][task][machine][gov] = report_summary_for(temp_f[0], temp_f[1], temp_f[2])

# %%
def print_stats_for_month(month, all_data_avg, all_data_marg, task_runtimes):
    headers = ['region', 'task', 'machine', 'governor', 'runtime (h)', 'energy consumption (kWh)', 'average emissions (gCO2e)', 'marginal emissions (gCO2e)']
    table_data = []

    for region in short_regions:
        for task in tasks:
            for machine in machines:
                for gov in governors:
                    curr = task_stats_avg[region][month][task][machine][gov]
                    curr_energy = round(curr[ENERGY_CONSUMPTION] + curr[MEMORY_CONSUMPTION], 3)
                    curr_emissions = round(curr[CARBON_EMISSIONS], 2)
                    curr_runtime = round(task_runtimes[task][machine][gov], 2)
                    curr_marg = task_stats_marg[region][month][task][machine][gov]
                    curr_marg_emissions = round(curr_marg[CARBON_EMISSIONS], 2)
                    table_data.append([region, task, machine, gov, curr_runtime, curr_energy, curr_emissions, curr_marg_emissions])

    print("Comparison of Tasks @ Varied Frequencies using Average CI Data")
    print(tabulate(table_data, headers, tablefmt='orgtbl'))

    return table_data

# %%
def get_runtime(filename):
    with open(filename, 'r') as f:
        lines = f.readlines()

    parts = lines[1].split(',')
    return int(parts[19])

all_task_runtimes = {}

for task in tasks:
    all_task_runtimes[task] = {}
    for machine in machines:
        all_task_runtimes[task][machine] = {}
        for gov in governors:
            filebase = f'../data/traces/tasks/{task}/{machine}-{gov}-{task}-ITER.csv'
            runtime_1 = get_runtime(filebase.replace('ITER', '1'))
            runtime_2 = get_runtime(filebase.replace('ITER', '2'))
            runtime_3 = get_runtime(filebase.replace('ITER', '3'))
            avg_runtime = (runtime_1 + runtime_2 + runtime_3) / 3
            all_task_runtimes[task][machine][gov] = avg_runtime / 1000 / 3600

# %%
all_ra_data = {}

for month in short_months:
    print('\n' + month)
    month_data = print_stats_for_month(month, task_stats_avg, task_stats_marg, all_task_runtimes)

    for row in month_data:
        c_region = row[0]
        c_task = row[1]
        c_mach = row[2]
        c_gov = row[3]

        if c_mach in all_ra_data:
            if c_task in all_ra_data[c_mach]:
                if c_gov in all_ra_data[c_mach][c_task]:
                    all_ra_data[c_mach][c_task][c_gov]['avg emissions'].append(row[6])
                    all_ra_data[c_mach][c_task][c_gov]['marg emissions'].append(row[7])
                else:
                    all_ra_data[c_mach][c_task][c_gov] = {
                        'region': c_region,
                        'runtime': row[4],
                        'energy': row[5],
                        'avg emissions': [row[6]],
                        'marg emissions': [row[7]]
                    }
            else:
                all_ra_data[c_mach][c_task] = {}
                all_ra_data[c_mach][c_task][c_gov] = {
                    'region': c_region,
                    'runtime': row[4],
                    'energy': row[5],
                    'avg emissions': [row[6]],
                    'marg emissions': [row[7]]
                }
        else: 
            all_ra_data[c_mach] = {}
            all_ra_data[c_mach][c_task] = {}
            all_ra_data[c_mach][c_task][c_gov] = {
                'region': c_region,
                'runtime': row[4],
                'energy': row[5],
                'avg emissions': [row[6]],
                'marg emissions': [row[7]]
            }
# Out:
# jan
# Comparison of Tasks @ Varied Frequencies using Average CI Data
# | region   | task          | machine   | governor    |   runtime (h) |   energy consumption (kWh) |   average emissions (gCO2e) |   marginal emissions (gCO2e) |
# |----------+---------------+-----------+-------------+---------------+----------------------------+-----------------------------+------------------------------|
# | gb       | bowtie2_build | gpg13     | performance |          0.25 |                      0.016 |                        3.86 |                         4.29 |
# | gb       | bowtie2_build | gpg13     | powersave   |          0.31 |                      0.017 |                        4.26 |                         5.22 |
# | gb       | bowtie2_build | gpg14     | performance |          0.25 |                      0.016 |                        3.93 |                         4.38 |
# | gb       | bowtie2_build | gpg14     | powersave   |          0.31 |                      0.018 |                        4.34 |                         5.33 |
# | gb       | bowtie2_build | gpg15     | performance |          0.25 |                      0.017 |                        4.23 |                         4.73 |
# | gb       | bowtie2_build | gpg15     | powersave   |          0.31 |                      0.019 |                        4.68 |                         5.75 |
# | gb       | bowtie2_build | gpg22     | performance |          0.15 |                      0.029 |                        7.02 |                         5.04 |
# | gb       | bowtie2_build | gpg22     | powersave   |          0.15 |                      0.027 |                        6.56 |                         4.72 |
# | gb       | bowtie2_build | hu26      | performance |          0.16 |                      0.014 |                        3.53 |                         2.83 |
# | gb       | bowtie2_build | hu26      | powersave   |          0.64 |                      0.028 |                        6.89 |                        10.17 |
# | gb       | fastp         | gpg13     | performance |          0.14 |                      0.009 |                        2.24 |                         1.64 |
# | gb       | fastp         | gpg13     | powersave   |          0.17 |                      0.01  |                        2.36 |                         2.03 |
# | gb       | fastp         | gpg14     | performance |          0.16 |                      0.01  |                        2.56 |                         2.13 |
# | gb       | fastp         | gpg14     | powersave   |          0.15 |                      0.009 |                        2.23 |                         1.78 |
# | gb       | fastp         | gpg15     | performance |          0.17 |                      0.012 |                        2.86 |                         2.75 |
# | gb       | fastp         | gpg15     | powersave   |          0.15 |                      0.01  |                        2.39 |                         1.89 |
# | gb       | fastp         | gpg22     | performance |          0.11 |                      0.022 |                        5.35 |                         2.4  |
# | gb       | fastp         | gpg22     | powersave   |          0.11 |                      0.021 |                        5.1  |                         2.61 |
# | gb       | fastp         | hu26      | performance |          0.05 |                      0.005 |                        1.11 |                         1.87 |
# | gb       | fastp         | hu26      | powersave   |          0.2  |                      0.009 |                        2.15 |                         2.1  |
# | gb       | fastqc        | gpg13     | performance |          0.26 |                      0.016 |                        4.04 |                         4.79 |
# | gb       | fastqc        | gpg13     | powersave   |          0.31 |                      0.018 |                        4.4  |                         5.67 |
# | gb       | fastqc        | gpg14     | performance |          0.26 |                      0.017 |                        4.11 |                         4.9  |
# | gb       | fastqc        | gpg14     | powersave   |          0.31 |                      0.018 |                        4.43 |                         5.7  |
# | gb       | fastqc        | gpg15     | performance |          0.26 |                      0.018 |                        4.38 |                         5.21 |
# | gb       | fastqc        | gpg15     | powersave   |          0.31 |                      0.019 |                        4.81 |                         6.18 |
# | gb       | fastqc        | gpg22     | performance |          0.13 |                      0.025 |                        6.09 |                         3.63 |
# | gb       | fastqc        | gpg22     | powersave   |          0.13 |                      0.023 |                        5.64 |                         7.62 |
# | gb       | fastqc        | hu26      | performance |          0.16 |                      0.015 |                        3.6  |                         3.09 |
# | gb       | fastqc        | hu26      | powersave   |          0.63 |                      0.028 |                        6.84 |                        10.52 |
# | gb       | trimgalore    | gpg13     | performance |          1.5  |                      0.032 |                        7.4  |                        44.33 |
# | gb       | trimgalore    | gpg13     | powersave   |          1.79 |                      0.045 |                       10.38 |                        47.53 |
# | gb       | trimgalore    | gpg14     | performance |          1.49 |                      0.032 |                        7.31 |                        44.51 |
# | gb       | trimgalore    | gpg14     | powersave   |          1.79 |                      0.046 |                       10.51 |                        48.14 |
# | gb       | trimgalore    | gpg15     | performance |          1.56 |                      0.039 |                        8.81 |                        49.52 |
# | gb       | trimgalore    | gpg15     | powersave   |          1.79 |                      0.05  |                       11.43 |                        52.34 |
# | gb       | trimgalore    | gpg22     | performance |          0.86 |                      0.168 |                       41.31 |                        72.48 |
# | gb       | trimgalore    | gpg22     | powersave   |          0.86 |                      0.158 |                       39.8  |                        73.62 |
# | gb       | trimgalore    | hu26      | performance |          1.05 |                      0.004 |                        0.96 |                        42.14 |
# | gb       | trimgalore    | hu26      | powersave   |          4.27 |                      0.145 |                       31.5  |                        88.44 |
# | de       | bowtie2_build | gpg13     | performance |          0.25 |                      0.016 |                        6.47 |                         8.05 |
# | de       | bowtie2_build | gpg13     | powersave   |          0.31 |                      0.017 |                        7.13 |                         9.73 |
# | de       | bowtie2_build | gpg14     | performance |          0.25 |                      0.016 |                        6.59 |                         8.22 |
# | de       | bowtie2_build | gpg14     | powersave   |          0.31 |                      0.018 |                        7.26 |                         9.93 |
# | de       | bowtie2_build | gpg15     | performance |          0.25 |                      0.017 |                        7.08 |                         8.88 |
# | de       | bowtie2_build | gpg15     | powersave   |          0.31 |                      0.019 |                        7.85 |                        10.71 |
# | de       | bowtie2_build | gpg22     | performance |          0.15 |                      0.029 |                       11.77 |                         9.47 |
# | de       | bowtie2_build | gpg22     | powersave   |          0.15 |                      0.027 |                       10.99 |                         8.87 |
# | de       | bowtie2_build | hu26      | performance |          0.16 |                      0.014 |                        5.91 |                         5.31 |
# | de       | bowtie2_build | hu26      | powersave   |          0.64 |                      0.028 |                       11.54 |                        18.95 |
# | de       | fastp         | gpg13     | performance |          0.14 |                      0.009 |                        4.07 |                         2.98 |
# | de       | fastp         | gpg13     | powersave   |          0.17 |                      0.01  |                        4.28 |                         3.68 |
# | de       | fastp         | gpg14     | performance |          0.16 |                      0.01  |                        4.66 |                         3.88 |
# | de       | fastp         | gpg14     | powersave   |          0.15 |                      0.009 |                        4.06 |                         3.24 |
# | de       | fastp         | gpg15     | performance |          0.17 |                      0.012 |                        5.19 |                         5.01 |
# | de       | fastp         | gpg15     | powersave   |          0.15 |                      0.01  |                        4.35 |                         3.44 |
# | de       | fastp         | gpg22     | performance |          0.11 |                      0.022 |                        9.73 |                         4.36 |
# | de       | fastp         | gpg22     | powersave   |          0.11 |                      0.021 |                        9.26 |                         4.74 |
# | de       | fastp         | hu26      | performance |          0.05 |                      0.005 |                        2.02 |                         3.39 |
# | de       | fastp         | hu26      | powersave   |          0.2  |                      0.009 |                        3.91 |                         3.82 |
# | de       | fastqc        | gpg13     | performance |          0.26 |                      0.016 |                        7.94 |                         8.5  |
# | de       | fastqc        | gpg13     | powersave   |          0.31 |                      0.018 |                        8.65 |                        10.07 |
# | de       | fastqc        | gpg14     | performance |          0.26 |                      0.017 |                        8.09 |                         8.69 |
# | de       | fastqc        | gpg14     | powersave   |          0.31 |                      0.018 |                        8.71 |                        10.11 |
# | de       | fastqc        | gpg15     | performance |          0.26 |                      0.018 |                        8.61 |                         9.25 |
# | de       | fastqc        | gpg15     | powersave   |          0.31 |                      0.019 |                        9.45 |                        10.97 |
# | de       | fastqc        | gpg22     | performance |          0.13 |                      0.025 |                       11.97 |                         6.44 |
# | de       | fastqc        | gpg22     | powersave   |          0.13 |                      0.023 |                       11    |                        14    |
# | de       | fastqc        | hu26      | performance |          0.16 |                      0.015 |                        7.08 |                         5.48 |
# | de       | fastqc        | hu26      | powersave   |          0.63 |                      0.028 |                       13.45 |                        18.46 |
# | de       | trimgalore    | gpg13     | performance |          1.5  |                      0.032 |                       15.44 |                        70.36 |
# | de       | trimgalore    | gpg13     | powersave   |          1.79 |                      0.045 |                       21.66 |                        75.57 |
# | de       | trimgalore    | gpg14     | performance |          1.49 |                      0.032 |                       15.26 |                        70.64 |
# | de       | trimgalore    | gpg14     | powersave   |          1.79 |                      0.046 |                       21.93 |                        76.54 |
# | de       | trimgalore    | gpg15     | performance |          1.56 |                      0.039 |                       18.38 |                        78.63 |
# | de       | trimgalore    | gpg15     | powersave   |          1.79 |                      0.05  |                       23.85 |                        83.22 |
# | de       | trimgalore    | gpg22     | performance |          0.86 |                      0.168 |                       78.18 |                       121.31 |
# | de       | trimgalore    | gpg22     | powersave   |          0.86 |                      0.158 |                       76.87 |                       117.38 |
# | de       | trimgalore    | hu26      | performance |          1.05 |                      0.004 |                        2    |                        66.71 |
# | de       | trimgalore    | hu26      | powersave   |          4.27 |                      0.145 |                       67.69 |                       137.8  |
# | ca       | bowtie2_build | gpg13     | performance |          0.25 |                      0.016 |                        4.42 |                         4.83 |
# | ca       | bowtie2_build | gpg13     | powersave   |          0.31 |                      0.017 |                        4.88 |                         5.83 |
# | ca       | bowtie2_build | gpg14     | performance |          0.25 |                      0.016 |                        4.51 |                         4.93 |
# | ca       | bowtie2_build | gpg14     | powersave   |          0.31 |                      0.018 |                        4.97 |                         5.95 |
# | ca       | bowtie2_build | gpg15     | performance |          0.25 |                      0.017 |                        4.84 |                         5.32 |
# | ca       | bowtie2_build | gpg15     | powersave   |          0.31 |                      0.019 |                        5.37 |                         6.42 |
# | ca       | bowtie2_build | gpg22     | performance |          0.15 |                      0.029 |                        8.05 |                         5.68 |
# | ca       | bowtie2_build | gpg22     | powersave   |          0.15 |                      0.027 |                        7.52 |                         5.32 |
# | ca       | bowtie2_build | hu26      | performance |          0.16 |                      0.014 |                        4.04 |                         3.18 |
# | ca       | bowtie2_build | hu26      | powersave   |          0.64 |                      0.028 |                        7.9  |                        11.29 |
# | ca       | fastp         | gpg13     | performance |          0.14 |                      0.009 |                        2.58 |                         1.78 |
# | ca       | fastp         | gpg13     | powersave   |          0.17 |                      0.01  |                        2.71 |                         2.21 |
# | ca       | fastp         | gpg14     | performance |          0.16 |                      0.01  |                        2.95 |                         2.32 |
# | ca       | fastp         | gpg14     | powersave   |          0.15 |                      0.009 |                        2.57 |                         1.94 |
# | ca       | fastp         | gpg15     | performance |          0.17 |                      0.012 |                        3.29 |                         3    |
# | ca       | fastp         | gpg15     | powersave   |          0.15 |                      0.01  |                        2.75 |                         2.06 |
# | ca       | fastp         | gpg22     | performance |          0.11 |                      0.022 |                        6.16 |                         2.61 |
# | ca       | fastp         | gpg22     | powersave   |          0.11 |                      0.021 |                        5.86 |                         2.84 |
# | ca       | fastp         | hu26      | performance |          0.05 |                      0.005 |                        1.28 |                         2.06 |
# | ca       | fastp         | hu26      | powersave   |          0.2  |                      0.009 |                        2.48 |                         2.28 |
# | ca       | fastqc        | gpg13     | performance |          0.26 |                      0.016 |                        4.89 |                         5.03 |
# | ca       | fastqc        | gpg13     | powersave   |          0.31 |                      0.018 |                        5.33 |                         5.96 |
# | ca       | fastqc        | gpg14     | performance |          0.26 |                      0.017 |                        4.98 |                         5.15 |
# | ca       | fastqc        | gpg14     | powersave   |          0.31 |                      0.018 |                        5.36 |                         5.99 |
# | ca       | fastqc        | gpg15     | performance |          0.26 |                      0.018 |                        5.3  |                         5.48 |
# | ca       | fastqc        | gpg15     | powersave   |          0.31 |                      0.019 |                        5.82 |                         6.49 |
# | ca       | fastqc        | gpg22     | performance |          0.13 |                      0.025 |                        7.37 |                         3.81 |
# | ca       | fastqc        | gpg22     | powersave   |          0.13 |                      0.023 |                        6.85 |                         8.24 |
# | ca       | fastqc        | hu26      | performance |          0.16 |                      0.015 |                        4.36 |                         3.24 |
# | ca       | fastqc        | hu26      | powersave   |          0.63 |                      0.028 |                        8.28 |                        10.93 |
# | ca       | trimgalore    | gpg13     | performance |          1.5  |                      0.032 |                        9.91 |                        40.43 |
# | ca       | trimgalore    | gpg13     | powersave   |          1.79 |                      0.045 |                       13.9  |                        43.39 |
# | ca       | trimgalore    | gpg14     | performance |          1.49 |                      0.032 |                        9.79 |                        40.59 |
# | ca       | trimgalore    | gpg14     | powersave   |          1.79 |                      0.046 |                       14.08 |                        43.95 |
# | ca       | trimgalore    | gpg15     | performance |          1.56 |                      0.039 |                       11.8  |                        45.17 |
# | ca       | trimgalore    | gpg15     | powersave   |          1.79 |                      0.05  |                       15.31 |                        47.78 |
# | ca       | trimgalore    | gpg22     | performance |          0.86 |                      0.168 |                       49.89 |                        70.7  |
# | ca       | trimgalore    | gpg22     | powersave   |          0.86 |                      0.158 |                       47.82 |                        67.42 |
# | ca       | trimgalore    | hu26      | performance |          1.05 |                      0.004 |                        1.28 |                        38.41 |
# | ca       | trimgalore    | hu26      | powersave   |          4.27 |                      0.145 |                       44.33 |                        81.8  |
# | tx       | bowtie2_build | gpg13     | performance |          0.25 |                      0.016 |                        5.54 |                         0.01 |
# | tx       | bowtie2_build | gpg13     | powersave   |          0.31 |                      0.017 |                        6.11 |                         0.02 |
# | tx       | bowtie2_build | gpg14     | performance |          0.25 |                      0.016 |                        5.65 |                         0.01 |
# | tx       | bowtie2_build | gpg14     | powersave   |          0.31 |                      0.018 |                        6.23 |                         0.02 |
# | tx       | bowtie2_build | gpg15     | performance |          0.25 |                      0.017 |                        6.07 |                         0.02 |
# | tx       | bowtie2_build | gpg15     | powersave   |          0.31 |                      0.019 |                        6.73 |                         0.02 |
# | tx       | bowtie2_build | gpg22     | performance |          0.15 |                      0.029 |                       10.09 |                         0.02 |
# | tx       | bowtie2_build | gpg22     | powersave   |          0.15 |                      0.027 |                        9.42 |                         0.02 |
# | tx       | bowtie2_build | hu26      | performance |          0.16 |                      0.014 |                        5.07 |                         0.01 |
# | tx       | bowtie2_build | hu26      | powersave   |          0.64 |                      0.028 |                        9.9  |                         0.04 |
# | tx       | fastp         | gpg13     | performance |          0.14 |                      0.009 |                        3.08 |                         0.02 |
# | tx       | fastp         | gpg13     | powersave   |          0.17 |                      0.01  |                        3.24 |                         0.02 |
# | tx       | fastp         | gpg14     | performance |          0.16 |                      0.01  |                        3.53 |                         0.02 |
# | tx       | fastp         | gpg14     | powersave   |          0.15 |                      0.009 |                        3.07 |                         0.02 |
# | tx       | fastp         | gpg15     | performance |          0.17 |                      0.012 |                        3.94 |                         0.03 |
# | tx       | fastp         | gpg15     | powersave   |          0.15 |                      0.01  |                        3.29 |                         0.02 |
# | tx       | fastp         | gpg22     | performance |          0.11 |                      0.022 |                        7.37 |                         0.03 |
# | tx       | fastp         | gpg22     | powersave   |          0.11 |                      0.021 |                        7.02 |                         0.03 |
# | tx       | fastp         | hu26      | performance |          0.05 |                      0.005 |                        1.53 |                         0.02 |
# | tx       | fastp         | hu26      | powersave   |          0.2  |                      0.009 |                        2.96 |                         0.02 |
# | tx       | fastqc        | gpg13     | performance |          0.26 |                      0.016 |                        5.93 |                         5.77 |
# | tx       | fastqc        | gpg13     | powersave   |          0.31 |                      0.018 |                        6.46 |                         6.82 |
# | tx       | fastqc        | gpg14     | performance |          0.26 |                      0.017 |                        6.04 |                         5.9  |
# | tx       | fastqc        | gpg14     | powersave   |          0.31 |                      0.018 |                        6.51 |                         6.85 |
# | tx       | fastqc        | gpg15     | performance |          0.26 |                      0.018 |                        6.43 |                         6.28 |
# | tx       | fastqc        | gpg15     | powersave   |          0.31 |                      0.019 |                        7.06 |                         7.44 |
# | tx       | fastqc        | gpg22     | performance |          0.13 |                      0.025 |                        8.94 |                         4.37 |
# | tx       | fastqc        | gpg22     | powersave   |          0.13 |                      0.023 |                        8.17 |                         9.57 |
# | tx       | fastqc        | hu26      | performance |          0.16 |                      0.015 |                        5.29 |                         3.72 |
# | tx       | fastqc        | hu26      | powersave   |          0.63 |                      0.028 |                       10.05 |                        12.49 |
# | tx       | trimgalore    | gpg13     | performance |          1.5  |                      0.032 |                       12.88 |                        46.59 |
# | tx       | trimgalore    | gpg13     | powersave   |          1.79 |                      0.045 |                       18.06 |                        49.91 |
# | tx       | trimgalore    | gpg14     | performance |          1.49 |                      0.032 |                       12.72 |                        46.79 |
# | tx       | trimgalore    | gpg14     | powersave   |          1.79 |                      0.046 |                       18.29 |                        50.55 |
# | tx       | trimgalore    | gpg15     | performance |          1.56 |                      0.039 |                       15.33 |                        52.04 |
# | tx       | trimgalore    | gpg15     | powersave   |          1.79 |                      0.05  |                       19.89 |                        54.96 |
# | tx       | trimgalore    | gpg22     | performance |          0.86 |                      0.168 |                       62.94 |                        52.23 |
# | tx       | trimgalore    | gpg22     | powersave   |          0.86 |                      0.158 |                       60.17 |                        79.38 |
# | tx       | trimgalore    | hu26      | performance |          1.05 |                      0.004 |                        1.67 |                        44.48 |
# | tx       | trimgalore    | hu26      | powersave   |          4.27 |                      0.145 |                       58.77 |                        92.95 |
# | zaf      | bowtie2_build | gpg13     | performance |          0.25 |                      0.016 |                       10.25 |                         7.89 |
# | zaf      | bowtie2_build | gpg13     | powersave   |          0.31 |                      0.017 |                       11.3  |                         9.54 |
# | zaf      | bowtie2_build | gpg14     | performance |          0.25 |                      0.016 |                       10.44 |                         8.06 |
# | zaf      | bowtie2_build | gpg14     | powersave   |          0.31 |                      0.018 |                       11.51 |                         9.73 |
# | zaf      | bowtie2_build | gpg15     | performance |          0.25 |                      0.017 |                       11.22 |                         8.71 |
# | zaf      | bowtie2_build | gpg15     | powersave   |          0.31 |                      0.019 |                       12.43 |                        10.49 |
# | zaf      | bowtie2_build | gpg22     | performance |          0.15 |                      0.029 |                       18.64 |                         9.29 |
# | zaf      | bowtie2_build | gpg22     | powersave   |          0.15 |                      0.027 |                       17.41 |                         8.7  |
# | zaf      | bowtie2_build | hu26      | performance |          0.16 |                      0.014 |                        9.36 |                         5.21 |
# | zaf      | bowtie2_build | hu26      | powersave   |          0.64 |                      0.028 |                       18.29 |                        18.44 |
# | zaf      | fastp         | gpg13     | performance |          0.14 |                      0.009 |                        5.83 |                         3    |
# | zaf      | fastp         | gpg13     | powersave   |          0.17 |                      0.01  |                        6.13 |                         3.71 |
# | zaf      | fastp         | gpg14     | performance |          0.16 |                      0.01  |                        6.67 |                         3.91 |
# | zaf      | fastp         | gpg14     | powersave   |          0.15 |                      0.009 |                        5.81 |                         3.26 |
# | zaf      | fastp         | gpg15     | performance |          0.17 |                      0.012 |                        7.44 |                         5.04 |
# | zaf      | fastp         | gpg15     | powersave   |          0.15 |                      0.01  |                        6.23 |                         3.46 |
# | zaf      | fastp         | gpg22     | performance |          0.11 |                      0.022 |                       13.93 |                         4.39 |
# | zaf      | fastp         | gpg22     | powersave   |          0.11 |                      0.021 |                       13.26 |                         4.77 |
# | zaf      | fastp         | hu26      | performance |          0.05 |                      0.005 |                        2.89 |                         3.42 |
# | zaf      | fastp         | hu26      | powersave   |          0.2  |                      0.009 |                        5.6  |                         3.84 |
# | zaf      | fastqc        | gpg13     | performance |          0.26 |                      0.016 |                        9.88 |                        10.22 |
# | zaf      | fastqc        | gpg13     | powersave   |          0.31 |                      0.018 |                       10.77 |                        12.09 |
# | zaf      | fastqc        | gpg14     | performance |          0.26 |                      0.017 |                       10.07 |                        10.44 |
# | zaf      | fastqc        | gpg14     | powersave   |          0.31 |                      0.018 |                       10.84 |                        12.15 |
# | zaf      | fastqc        | gpg15     | performance |          0.26 |                      0.018 |                       10.72 |                        11.11 |
# | zaf      | fastqc        | gpg15     | powersave   |          0.31 |                      0.019 |                       11.77 |                        13.18 |
# | zaf      | fastqc        | gpg22     | performance |          0.13 |                      0.025 |                       14.89 |                         7.74 |
# | zaf      | fastqc        | gpg22     | powersave   |          0.13 |                      0.023 |                       14.32 |                        16.9  |
# | zaf      | fastqc        | hu26      | performance |          0.16 |                      0.015 |                        8.82 |                         6.58 |
# | zaf      | fastqc        | hu26      | powersave   |          0.63 |                      0.028 |                       16.75 |                        22.2  |
# | zaf      | trimgalore    | gpg13     | performance |          1.5  |                      0.032 |                       19.28 |                        84    |
# | zaf      | trimgalore    | gpg13     | powersave   |          1.79 |                      0.045 |                       27.04 |                        90.17 |
# | zaf      | trimgalore    | gpg14     | performance |          1.49 |                      0.032 |                       19.04 |                        84.35 |
# | zaf      | trimgalore    | gpg14     | powersave   |          1.79 |                      0.046 |                       27.38 |                        91.33 |
# | zaf      | trimgalore    | gpg15     | performance |          1.56 |                      0.039 |                       22.94 |                        93.86 |
# | zaf      | trimgalore    | gpg15     | powersave   |          1.79 |                      0.05  |                       29.77 |                        99.29 |
# | zaf      | trimgalore    | gpg22     | performance |          0.86 |                      0.168 |                      103.6  |                       135.84 |
# | zaf      | trimgalore    | gpg22     | powersave   |          0.86 |                      0.158 |                       94.65 |                       140.84 |
# | zaf      | trimgalore    | hu26      | performance |          1.05 |                      0.004 |                        2.49 |                        79.8  |
# | zaf      | trimgalore    | hu26      | powersave   |          4.27 |                      0.145 |                       85.93 |                       170.46 |
# | tyo      | bowtie2_build | gpg13     | performance |          0.25 |                      0.016 |                        5.93 |                         5.59 |
# | tyo      | bowtie2_build | gpg13     | powersave   |          0.31 |                      0.017 |                        6.54 |                         6.76 |
# | tyo      | bowtie2_build | gpg14     | performance |          0.25 |                      0.016 |                        6.04 |                         5.71 |
# | tyo      | bowtie2_build | gpg14     | powersave   |          0.31 |                      0.018 |                        6.66 |                         6.9  |
# | tyo      | bowtie2_build | gpg15     | performance |          0.25 |                      0.017 |                        6.49 |                         6.17 |
# | tyo      | bowtie2_build | gpg15     | powersave   |          0.31 |                      0.019 |                        7.19 |                         7.44 |
# | tyo      | bowtie2_build | gpg22     | performance |          0.15 |                      0.029 |                       10.79 |                         6.58 |
# | tyo      | bowtie2_build | gpg22     | powersave   |          0.15 |                      0.027 |                       10.07 |                         6.16 |
# | tyo      | bowtie2_build | hu26      | performance |          0.16 |                      0.014 |                        5.42 |                         3.69 |
# | tyo      | bowtie2_build | hu26      | powersave   |          0.64 |                      0.028 |                       10.58 |                        13.07 |
# | tyo      | fastp         | gpg13     | performance |          0.14 |                      0.009 |                        3.5  |                         2.12 |
# | tyo      | fastp         | gpg13     | powersave   |          0.17 |                      0.01  |                        3.68 |                         2.63 |
# | tyo      | fastp         | gpg14     | performance |          0.16 |                      0.01  |                        4    |                         2.77 |
# | tyo      | fastp         | gpg14     | powersave   |          0.15 |                      0.009 |                        3.49 |                         2.31 |
# | tyo      | fastp         | gpg15     | performance |          0.17 |                      0.012 |                        4.46 |                         3.57 |
# | tyo      | fastp         | gpg15     | powersave   |          0.15 |                      0.01  |                        3.73 |                         2.45 |
# | tyo      | fastp         | gpg22     | performance |          0.11 |                      0.022 |                        8.36 |                         3.11 |
# | tyo      | fastp         | gpg22     | powersave   |          0.11 |                      0.021 |                        7.95 |                         3.38 |
# | tyo      | fastp         | hu26      | performance |          0.05 |                      0.005 |                        1.73 |                         2.42 |
# | tyo      | fastp         | hu26      | powersave   |          0.2  |                      0.009 |                        3.36 |                         2.72 |
# | tyo      | fastqc        | gpg13     | performance |          0.26 |                      0.016 |                        7.32 |                         5.95 |
# | tyo      | fastqc        | gpg13     | powersave   |          0.31 |                      0.018 |                        7.98 |                         7.04 |
# | tyo      | fastqc        | gpg14     | performance |          0.26 |                      0.017 |                        7.46 |                         6.08 |
# | tyo      | fastqc        | gpg14     | powersave   |          0.31 |                      0.018 |                        8.03 |                         7.08 |
# | tyo      | fastqc        | gpg15     | performance |          0.26 |                      0.018 |                        7.94 |                         6.47 |
# | tyo      | fastqc        | gpg15     | powersave   |          0.31 |                      0.019 |                        8.72 |                         7.68 |
# | tyo      | fastqc        | gpg22     | performance |          0.13 |                      0.025 |                       11.03 |                         4.51 |
# | tyo      | fastqc        | gpg22     | powersave   |          0.13 |                      0.023 |                        9.8  |                         9.84 |
# | tyo      | fastqc        | hu26      | performance |          0.16 |                      0.015 |                        6.53 |                         3.83 |
# | tyo      | fastqc        | hu26      | powersave   |          0.63 |                      0.028 |                       12.4  |                        12.93 |
# | tyo      | trimgalore    | gpg13     | performance |          1.5  |                      0.032 |                       16.12 |                        48.94 |
# | tyo      | trimgalore    | gpg13     | powersave   |          1.79 |                      0.045 |                       22.61 |                        52.53 |
# | tyo      | trimgalore    | gpg14     | performance |          1.49 |                      0.032 |                       15.93 |                        49.14 |
# | tyo      | trimgalore    | gpg14     | powersave   |          1.79 |                      0.046 |                       22.9  |                        53.2  |
# | tyo      | trimgalore    | gpg15     | performance |          1.56 |                      0.039 |                       19.19 |                        54.68 |
# | tyo      | trimgalore    | gpg15     | powersave   |          1.79 |                      0.05  |                       24.9  |                        57.84 |
# | tyo      | trimgalore    | gpg22     | performance |          0.86 |                      0.168 |                       76.88 |                        84.51 |
# | tyo      | trimgalore    | gpg22     | powersave   |          0.86 |                      0.158 |                       77.59 |                        82.05 |
# | tyo      | trimgalore    | hu26      | performance |          1.05 |                      0.004 |                        2.09 |                        46.49 |
# | tyo      | trimgalore    | hu26      | powersave   |          4.27 |                      0.145 |                       71.93 |                        99.3  |
# | nsw      | bowtie2_build | gpg13     | performance |          0.25 |                      0.016 |                        5.67 |                         8.52 |
# | nsw      | bowtie2_build | gpg13     | powersave   |          0.31 |                      0.017 |                        6.25 |                        10.3  |
# | nsw      | bowtie2_build | gpg14     | performance |          0.25 |                      0.016 |                        5.77 |                         8.71 |
# | nsw      | bowtie2_build | gpg14     | powersave   |          0.31 |                      0.018 |                        6.37 |                        10.52 |
# | nsw      | bowtie2_build | gpg15     | performance |          0.25 |                      0.017 |                        6.21 |                         9.41 |
# | nsw      | bowtie2_build | gpg15     | powersave   |          0.31 |                      0.019 |                        6.88 |                        11.34 |
# | nsw      | bowtie2_build | gpg22     | performance |          0.15 |                      0.029 |                       10.31 |                        10.03 |
# | nsw      | bowtie2_build | gpg22     | powersave   |          0.15 |                      0.027 |                        9.63 |                         9.4  |
# | nsw      | bowtie2_build | hu26      | performance |          0.16 |                      0.014 |                        5.18 |                         5.62 |
# | nsw      | bowtie2_build | hu26      | powersave   |          0.64 |                      0.028 |                       10.12 |                        20.01 |
# | nsw      | fastp         | gpg13     | performance |          0.14 |                      0.009 |                        3.41 |                         3.16 |
# | nsw      | fastp         | gpg13     | powersave   |          0.17 |                      0.01  |                        3.59 |                         3.91 |
# | nsw      | fastp         | gpg14     | performance |          0.16 |                      0.01  |                        3.9  |                         4.12 |
# | nsw      | fastp         | gpg14     | powersave   |          0.15 |                      0.009 |                        3.4  |                         3.44 |
# | nsw      | fastp         | gpg15     | performance |          0.17 |                      0.012 |                        4.35 |                         5.32 |
# | nsw      | fastp         | gpg15     | powersave   |          0.15 |                      0.01  |                        3.64 |                         3.65 |
# | nsw      | fastp         | gpg22     | performance |          0.11 |                      0.022 |                        8.16 |                         4.64 |
# | nsw      | fastp         | gpg22     | powersave   |          0.11 |                      0.021 |                        7.76 |                         5.04 |
# | nsw      | fastp         | hu26      | performance |          0.05 |                      0.005 |                        1.69 |                         3.96 |
# | nsw      | fastp         | hu26      | powersave   |          0.2  |                      0.009 |                        3.28 |                         4.06 |
# | nsw      | fastqc        | gpg13     | performance |          0.26 |                      0.016 |                        7.56 |                         9.17 |
# | nsw      | fastqc        | gpg13     | powersave   |          0.31 |                      0.018 |                        8.24 |                        10.86 |
# | nsw      | fastqc        | gpg14     | performance |          0.26 |                      0.017 |                        7.7  |                         9.38 |
# | nsw      | fastqc        | gpg14     | powersave   |          0.31 |                      0.018 |                        8.29 |                        10.91 |
# | nsw      | fastqc        | gpg15     | performance |          0.26 |                      0.018 |                        8.2  |                         9.98 |
# | nsw      | fastqc        | gpg15     | powersave   |          0.31 |                      0.019 |                        9    |                        11.83 |
# | nsw      | fastqc        | gpg22     | performance |          0.13 |                      0.025 |                       11.39 |                         6.95 |
# | nsw      | fastqc        | gpg22     | powersave   |          0.13 |                      0.023 |                       10.32 |                        14.83 |
# | nsw      | fastqc        | hu26      | performance |          0.16 |                      0.015 |                        6.74 |                         5.91 |
# | nsw      | fastqc        | hu26      | powersave   |          0.63 |                      0.028 |                       12.81 |                        19.93 |
# | nsw      | trimgalore    | gpg13     | performance |          1.5  |                      0.032 |                       19.41 |                        64.55 |
# | nsw      | trimgalore    | gpg13     | powersave   |          1.79 |                      0.045 |                       27.22 |                        70.86 |
# | nsw      | trimgalore    | gpg14     | performance |          1.49 |                      0.032 |                       19.17 |                        64.74 |
# | nsw      | trimgalore    | gpg14     | powersave   |          1.79 |                      0.046 |                       27.56 |                        71.77 |
# | nsw      | trimgalore    | gpg15     | performance |          1.56 |                      0.039 |                       23.1  |                        72.47 |
# | nsw      | trimgalore    | gpg15     | powersave   |          1.79 |                      0.05  |                       29.97 |                        78.03 |
# | nsw      | trimgalore    | gpg22     | performance |          0.86 |                      0.168 |                       82.63 |                       115.7  |
# | nsw      | trimgalore    | gpg22     | powersave   |          0.86 |                      0.158 |                       82.57 |                       118.4  |
# | nsw      | trimgalore    | hu26      | performance |          1.05 |                      0.004 |                        2.51 |                        60.62 |
# | nsw      | trimgalore    | hu26      | powersave   |          4.27 |                      0.145 |                       87.02 |                       146.4  |
#
# feb
# Comparison of Tasks @ Varied Frequencies using Average CI Data
# | region   | task          | machine   | governor    |   runtime (h) |   energy consumption (kWh) |   average emissions (gCO2e) |   marginal emissions (gCO2e) |
# |----------+---------------+-----------+-------------+---------------+----------------------------+-----------------------------+------------------------------|
# | gb       | bowtie2_build | gpg13     | performance |          0.25 |                      0.016 |                        1.15 |                         4.22 |
# | gb       | bowtie2_build | gpg13     | powersave   |          0.31 |                      0.017 |                        1.26 |                         5.1  |
# | gb       | bowtie2_build | gpg14     | performance |          0.25 |                      0.016 |                        1.17 |                         4.31 |
# | gb       | bowtie2_build | gpg14     | powersave   |          0.31 |                      0.018 |                        1.29 |                         5.2  |
# | gb       | bowtie2_build | gpg15     | performance |          0.25 |                      0.017 |                        1.26 |                         4.65 |
# | gb       | bowtie2_build | gpg15     | powersave   |          0.31 |                      0.019 |                        1.39 |                         5.61 |
# | gb       | bowtie2_build | gpg22     | performance |          0.15 |                      0.029 |                        2.09 |                         4.96 |
# | gb       | bowtie2_build | gpg22     | powersave   |          0.15 |                      0.027 |                        1.95 |                         4.65 |
# | gb       | bowtie2_build | hu26      | performance |          0.16 |                      0.014 |                        1.05 |                         2.78 |
# | gb       | bowtie2_build | hu26      | powersave   |          0.64 |                      0.028 |                        2.05 |                         9.87 |
# | gb       | fastp         | gpg13     | performance |          0.14 |                      0.009 |                        0.74 |                         1.66 |
# | gb       | fastp         | gpg13     | powersave   |          0.17 |                      0.01  |                        0.77 |                         2.05 |
# | gb       | fastp         | gpg14     | performance |          0.16 |                      0.01  |                        0.84 |                         2.16 |
# ...
# | zaf      | fastqc        | gpg13     | powersave   |          0.31 |                      0.018 |                       11.68 |                        12.09 |
# | zaf      | fastqc        | gpg14     | performance |          0.26 |                      0.017 |                       10.92 |                        10.44 |
# | zaf      | fastqc        | gpg14     | powersave   |          0.31 |                      0.018 |                       11.76 |                        12.15 |
# | zaf      | fastqc        | gpg15     | performance |          0.26 |                      0.018 |                       11.62 |                        11.11 |
# | zaf      | fastqc        | gpg15     | powersave   |          0.31 |                      0.019 |                       12.76 |                        13.18 |
# | zaf      | fastqc        | gpg22     | performance |          0.13 |                      0.025 |                       16.15 |                         7.74 |
# | zaf      | fastqc        | gpg22     | powersave   |          0.13 |                      0.023 |                       15.43 |                        16.9  |
# | zaf      | fastqc        | hu26      | performance |          0.16 |                      0.015 |                        9.56 |                         6.58 |
# | zaf      | fastqc        | hu26      | powersave   |          0.63 |                      0.028 |                       18.15 |                        22.2  |
# | zaf      | trimgalore    | gpg13     | performance |          1.5  |                      0.032 |                       20.38 |                        84.01 |
# | zaf      | trimgalore    | gpg13     | powersave   |          1.79 |                      0.045 |                       28.58 |                        90.18 |
# | zaf      | trimgalore    | gpg14     | performance |          1.49 |                      0.032 |                       20.13 |                        84.35 |
# | zaf      | trimgalore    | gpg14     | powersave   |          1.79 |                      0.046 |                       28.94 |                        91.33 |
# | zaf      | trimgalore    | gpg15     | performance |          1.56 |                      0.039 |                       24.25 |                        93.87 |
# | zaf      | trimgalore    | gpg15     | powersave   |          1.79 |                      0.05  |                       31.46 |                        99.3  |
# | zaf      | trimgalore    | gpg22     | performance |          0.86 |                      0.168 |                      110.96 |                       135.85 |
# | zaf      | trimgalore    | gpg22     | powersave   |          0.86 |                      0.158 |                      101.43 |                       140.84 |
# | zaf      | trimgalore    | hu26      | performance |          1.05 |                      0.004 |                        2.64 |                        79.8  |
# | zaf      | trimgalore    | hu26      | powersave   |          4.27 |                      0.145 |                       88.88 |                       170.47 |
# | tyo      | bowtie2_build | gpg13     | performance |          0.25 |                      0.016 |                        5.28 |                         5.59 |
# | tyo      | bowtie2_build | gpg13     | powersave   |          0.31 |                      0.017 |                        5.82 |                         6.76 |
# | tyo      | bowtie2_build | gpg14     | performance |          0.25 |                      0.016 |                        5.38 |                         5.71 |
# | tyo      | bowtie2_build | gpg14     | powersave   |          0.31 |                      0.018 |                        5.93 |                         6.9  |
# | tyo      | bowtie2_build | gpg15     | performance |          0.25 |                      0.017 |                        5.78 |                         6.17 |
# | tyo      | bowtie2_build | gpg15     | powersave   |          0.31 |                      0.019 |                        6.4  |                         7.44 |
# | tyo      | bowtie2_build | gpg22     | performance |          0.15 |                      0.029 |                        9.6  |                         6.58 |
# | tyo      | bowtie2_build | gpg22     | powersave   |          0.15 |                      0.027 |                        8.97 |                         6.16 |
# | tyo      | bowtie2_build | hu26      | performance |          0.16 |                      0.014 |                        4.82 |                         3.69 |
# | tyo      | bowtie2_build | hu26      | powersave   |          0.64 |                      0.028 |                        9.42 |                        13.07 |
# | tyo      | fastp         | gpg13     | performance |          0.14 |                      0.009 |                        3.33 |                         2.12 |
# | tyo      | fastp         | gpg13     | powersave   |          0.17 |                      0.01  |                        3.5  |                         2.63 |
# | tyo      | fastp         | gpg14     | performance |          0.16 |                      0.01  |                        3.81 |                         2.77 |
# | tyo      | fastp         | gpg14     | powersave   |          0.15 |                      0.009 |                        3.32 |                         2.31 |
# | tyo      | fastp         | gpg15     | performance |          0.17 |                      0.012 |                        4.25 |                         3.57 |
# | tyo      | fastp         | gpg15     | powersave   |          0.15 |                      0.01  |                        3.56 |                         2.45 |
# | tyo      | fastp         | gpg22     | performance |          0.11 |                      0.022 |                        7.97 |                         3.11 |
# | tyo      | fastp         | gpg22     | powersave   |          0.11 |                      0.021 |                        7.58 |                         3.38 |
# | tyo      | fastp         | hu26      | performance |          0.05 |                      0.005 |                        1.65 |                         2.42 |
# | tyo      | fastp         | hu26      | powersave   |          0.2  |                      0.009 |                        3.2  |                         2.72 |
# | tyo      | fastqc        | gpg13     | performance |          0.26 |                      0.016 |                        7.6  |                         5.95 |
# | tyo      | fastqc        | gpg13     | powersave   |          0.31 |                      0.018 |                        8.28 |                         7.04 |
# | tyo      | fastqc        | gpg14     | performance |          0.26 |                      0.017 |                        7.74 |                         6.08 |
# | tyo      | fastqc        | gpg14     | powersave   |          0.31 |                      0.018 |                        8.34 |                         7.08 |
# | tyo      | fastqc        | gpg15     | performance |          0.26 |                      0.018 |                        8.24 |                         6.47 |
# | tyo      | fastqc        | gpg15     | powersave   |          0.31 |                      0.019 |                        9.05 |                         7.68 |
# | tyo      | fastqc        | gpg22     | performance |          0.13 |                      0.025 |                       11.45 |                         4.51 |
# | tyo      | fastqc        | gpg22     | powersave   |          0.13 |                      0.023 |                       10.01 |                         9.84 |
# | tyo      | fastqc        | hu26      | performance |          0.16 |                      0.015 |                        6.78 |                         3.83 |
# | tyo      | fastqc        | hu26      | powersave   |          0.63 |                      0.028 |                       12.88 |                        12.93 |
# | tyo      | trimgalore    | gpg13     | performance |          1.5  |                      0.032 |                       16.32 |                        48.96 |
# | tyo      | trimgalore    | gpg13     | powersave   |          1.79 |                      0.045 |                       22.89 |                        52.56 |
# | tyo      | trimgalore    | gpg14     | performance |          1.49 |                      0.032 |                       16.12 |                        49.16 |
# | tyo      | trimgalore    | gpg14     | powersave   |          1.79 |                      0.046 |                       23.18 |                        53.23 |
# | tyo      | trimgalore    | gpg15     | performance |          1.56 |                      0.039 |                       19.42 |                        54.71 |
# | tyo      | trimgalore    | gpg15     | powersave   |          1.79 |                      0.05  |                       25.2  |                        57.87 |
# | tyo      | trimgalore    | gpg22     | performance |          0.86 |                      0.168 |                       75.33 |                        84.51 |
# | tyo      | trimgalore    | gpg22     | powersave   |          0.86 |                      0.158 |                       79.31 |                        82.07 |
# | tyo      | trimgalore    | hu26      | performance |          1.05 |                      0.004 |                        2.11 |                        46.51 |
# | tyo      | trimgalore    | hu26      | powersave   |          4.27 |                      0.145 |                       72.84 |                        99.33 |
# | nsw      | bowtie2_build | gpg13     | performance |          0.25 |                      0.016 |                        4.31 |                         8.58 |
# | nsw      | bowtie2_build | gpg13     | powersave   |          0.31 |                      0.017 |                        4.75 |                        10.37 |
# | nsw      | bowtie2_build | gpg14     | performance |          0.25 |                      0.016 |                        4.39 |                         8.76 |
# | nsw      | bowtie2_build | gpg14     | powersave   |          0.31 |                      0.018 |                        4.84 |                        10.58 |
# | nsw      | bowtie2_build | gpg15     | performance |          0.25 |                      0.017 |                        4.72 |                         9.46 |
# | nsw      | bowtie2_build | gpg15     | powersave   |          0.31 |                      0.019 |                        5.23 |                        11.4  |
# | nsw      | bowtie2_build | gpg22     | performance |          0.15 |                      0.029 |                        7.84 |                        10.09 |
# | nsw      | bowtie2_build | gpg22     | powersave   |          0.15 |                      0.027 |                        7.32 |                         9.45 |
# | nsw      | bowtie2_build | hu26      | performance |          0.16 |                      0.014 |                        3.94 |                         5.66 |
# | nsw      | bowtie2_build | hu26      | powersave   |          0.64 |                      0.028 |                        7.69 |                        20    |
# | nsw      | fastp         | gpg13     | performance |          0.14 |                      0.009 |                        2.97 |                         3.25 |
# | nsw      | fastp         | gpg13     | powersave   |          0.17 |                      0.01  |                        3.12 |                         4.03 |
# | nsw      | fastp         | gpg14     | performance |          0.16 |                      0.01  |                        3.4  |                         4.24 |
# | nsw      | fastp         | gpg14     | powersave   |          0.15 |                      0.009 |                        2.96 |                         3.54 |
# | nsw      | fastp         | gpg15     | performance |          0.17 |                      0.012 |                        3.79 |                         5.48 |
# | nsw      | fastp         | gpg15     | powersave   |          0.15 |                      0.01  |                        3.17 |                         3.76 |
# | nsw      | fastp         | gpg22     | performance |          0.11 |                      0.022 |                        7.1  |                         4.77 |
# | nsw      | fastp         | gpg22     | powersave   |          0.11 |                      0.021 |                        6.76 |                         5.18 |
# | nsw      | fastp         | hu26      | performance |          0.05 |                      0.005 |                        1.47 |                         3.71 |
# | nsw      | fastp         | hu26      | powersave   |          0.2  |                      0.009 |                        2.86 |                         4.18 |
# | nsw      | fastqc        | gpg13     | performance |          0.26 |                      0.016 |                        6.23 |                         8.64 |
# | nsw      | fastqc        | gpg13     | powersave   |          0.31 |                      0.018 |                        6.8  |                        10.23 |
# | nsw      | fastqc        | gpg14     | performance |          0.26 |                      0.017 |                        6.35 |                         8.83 |
# | nsw      | fastqc        | gpg14     | powersave   |          0.31 |                      0.018 |                        6.84 |                        10.27 |
# | nsw      | fastqc        | gpg15     | performance |          0.26 |                      0.018 |                        6.76 |                         9.4  |
# | nsw      | fastqc        | gpg15     | powersave   |          0.31 |                      0.019 |                        7.42 |                        11.14 |
# | nsw      | fastqc        | gpg22     | performance |          0.13 |                      0.025 |                        9.4  |                         6.54 |
# | nsw      | fastqc        | gpg22     | powersave   |          0.13 |                      0.023 |                        8.45 |                        14.29 |
# | nsw      | fastqc        | hu26      | performance |          0.16 |                      0.015 |                        5.56 |                         5.57 |
# | nsw      | fastqc        | hu26      | powersave   |          0.63 |                      0.028 |                       10.57 |                        18.77 |
# | nsw      | trimgalore    | gpg13     | performance |          1.5  |                      0.032 |                       16.81 |                        65.67 |
# | nsw      | trimgalore    | gpg13     | powersave   |          1.79 |                      0.045 |                       23.57 |                        70.6  |
# | nsw      | trimgalore    | gpg14     | performance |          1.49 |                      0.032 |                       16.6  |                        65.93 |
# | nsw      | trimgalore    | gpg14     | powersave   |          1.79 |                      0.046 |                       23.86 |                        71.51 |
# | nsw      | trimgalore    | gpg15     | performance |          1.56 |                      0.039 |                       20    |                        73.39 |
# | nsw      | trimgalore    | gpg15     | powersave   |          1.79 |                      0.05  |                       25.95 |                        77.74 |
# | nsw      | trimgalore    | gpg22     | performance |          0.86 |                      0.168 |                       69.5  |                       118.59 |
# | nsw      | trimgalore    | gpg22     | powersave   |          0.86 |                      0.158 |                       67.86 |                       113.43 |
# | nsw      | trimgalore    | hu26      | performance |          1.05 |                      0.004 |                        2.17 |                        62.17 |
# | nsw      | trimgalore    | hu26      | powersave   |          4.27 |                      0.145 |                       79.42 |                       139.23 |

# %%
headers = ['region', 'task', 'machine', 'governor', 'runtime (h)', 'energy consumption (kWh)', 'average emissions (gCO2e)', 'marginal emissions (gCO2e)']
mean_data = []

for machine in machines:
    for task in tasks:
        for gov in governors:
            entry = all_ra_data[machine][task][gov]
            mean_avg_ems = sum(entry['avg emissions']) / len(entry['avg emissions'])
            mean_marg_ems = sum(entry['marg emissions']) / len(entry['marg emissions'])
            mean_data.append([entry['region'], task, machine, gov, entry['runtime'], entry['energy'], round(mean_avg_ems, 2), round(mean_marg_ems, 2)])

print(tabulate(mean_data, headers, tablefmt='orgtbl'))

with open('../data/results/resource-scaling/tasks/table_mean_data.csv', 'w') as f:
    f.write(','.join(headers) + '\n')

    for row in mean_data: 
        f.write(','.join([str(v) for v in row]) + '\n')
# Out:
# | region   | task          | machine   | governor    |   runtime (h) |   energy consumption (kWh) |   average emissions (gCO2e) |   marginal emissions (gCO2e) |
# |----------+---------------+-----------+-------------+---------------+----------------------------+-----------------------------+------------------------------|
# | gb       | bowtie2_build | gpg13     | performance |          0.25 |                      0.016 |                        5.06 |                         6.17 |
# | gb       | bowtie2_build | gpg13     | powersave   |          0.31 |                      0.017 |                        5.58 |                         7.41 |
# | gb       | fastp         | gpg13     | performance |          0.14 |                      0.009 |                        3.01 |                         2.32 |
# | gb       | fastp         | gpg13     | powersave   |          0.17 |                      0.01  |                        3.16 |                         2.88 |
# | gb       | fastqc        | gpg13     | performance |          0.26 |                      0.016 |                        5.74 |                         6.86 |
# | gb       | fastqc        | gpg13     | powersave   |          0.31 |                      0.018 |                        6.26 |                         8.1  |
# | gb       | trimgalore    | gpg13     | performance |          1.5  |                      0.032 |                       11.71 |                        53.44 |
# | gb       | trimgalore    | gpg13     | powersave   |          1.79 |                      0.045 |                       16.42 |                        57.29 |
# | gb       | bowtie2_build | gpg14     | performance |          0.25 |                      0.016 |                        5.15 |                         6.3  |
# | gb       | bowtie2_build | gpg14     | powersave   |          0.31 |                      0.018 |                        5.68 |                         7.56 |
# | gb       | fastp         | gpg14     | performance |          0.16 |                      0.01  |                        3.44 |                         3.03 |
# | gb       | fastp         | gpg14     | powersave   |          0.15 |                      0.009 |                        3    |                         2.53 |
# | gb       | fastqc        | gpg14     | performance |          0.26 |                      0.017 |                        5.85 |                         7.01 |
# | gb       | fastqc        | gpg14     | powersave   |          0.31 |                      0.018 |                        6.3  |                         8.14 |
# | gb       | trimgalore    | gpg14     | performance |          1.49 |                      0.032 |                       11.56 |                        53.66 |
# | gb       | trimgalore    | gpg14     | powersave   |          1.79 |                      0.046 |                       16.62 |                        58.02 |
# | gb       | bowtie2_build | gpg15     | performance |          0.25 |                      0.017 |                        5.54 |                         6.81 |
# | gb       | bowtie2_build | gpg15     | powersave   |          0.31 |                      0.019 |                        6.14 |                         8.15 |
# | gb       | fastp         | gpg15     | performance |          0.17 |                      0.012 |                        3.83 |                         3.91 |
# | gb       | fastp         | gpg15     | powersave   |          0.15 |                      0.01  |                        3.21 |                         2.68 |
# | gb       | fastqc        | gpg15     | performance |          0.26 |                      0.018 |                        6.23 |                         7.46 |
# | gb       | fastqc        | gpg15     | powersave   |          0.31 |                      0.019 |                        6.84 |                         8.83 |
# | gb       | trimgalore    | gpg15     | performance |          1.56 |                      0.039 |                       13.93 |                        59.68 |
# | gb       | trimgalore    | gpg15     | powersave   |          1.79 |                      0.05  |                       18.07 |                        63.08 |
# | gb       | bowtie2_build | gpg22     | performance |          0.15 |                      0.029 |                        9.21 |                         7.25 |
# | gb       | bowtie2_build | gpg22     | powersave   |          0.15 |                      0.027 |                        8.6  |                         6.79 |
# | gb       | fastp         | gpg22     | performance |          0.11 |                      0.022 |                        7.18 |                         3.41 |
# | gb       | fastp         | gpg22     | powersave   |          0.11 |                      0.021 |                        6.84 |                         3.7  |
# | gb       | fastqc        | gpg22     | performance |          0.13 |                      0.025 |                        8.66 |                         5.17 |
# | gb       | fastqc        | gpg22     | powersave   |          0.13 |                      0.023 |                        8    |                        11.32 |
# | gb       | trimgalore    | gpg22     | performance |          0.86 |                      0.168 |                       58.76 |                        91.88 |
# | gb       | trimgalore    | gpg22     | powersave   |          0.86 |                      0.158 |                       56.82 |                        91.86 |
# | gb       | bowtie2_build | hu26      | performance |          0.16 |                      0.014 |                        4.62 |                         4.07 |
# | gb       | bowtie2_build | hu26      | powersave   |          0.64 |                      0.028 |                        9.03 |                        14.27 |
# | gb       | fastp         | hu26      | performance |          0.05 |                      0.005 |                        1.49 |                         2.66 |
# | gb       | fastp         | hu26      | powersave   |          0.2  |                      0.009 |                        2.89 |                         2.98 |
# | gb       | fastqc        | hu26      | performance |          0.16 |                      0.015 |                        5.12 |                         4.39 |
# | gb       | fastqc        | hu26      | powersave   |          0.63 |                      0.028 |                        9.73 |                        14.82 |
# | gb       | trimgalore    | hu26      | performance |          1.05 |                      0.004 |                        1.51 |                        51.08 |
# | gb       | trimgalore    | hu26      | powersave   |          4.27 |                      0.145 |                       52.69 |                       108.31 |

# %% [markdown]
# **Workflow Resource Scaling -- Processor Governor (8 nodes)**

# %%
workflows = ['chipseq', 'rnaseq']
wf_stats_avg = {}
wf_stats_marg = {} 

for region in short_regions:
    wf_stats_avg[region] = {}
    wf_stats_marg[region] = {}
    for wf in workflows:
        wf_stats_avg[region][wf] = {}
        wf_stats_marg[region][wf] = {}
        for gov in governors:
            temp_f = [f'../data/results/resource-scaling/workflows/out/{wf}-{gov}-{iteration}-{region}-2024-wf-scale-hu26_{gov}_linear-summary.txt' for iteration in range(1, 4)]
            wf_stats_avg[region][wf][gov] = report_summary_for(temp_f[0], temp_f[1], temp_f[2])
            
            temp_f2 = [f'../data/results/resource-scaling/workflows/out/{wf}-{gov}-{iteration}-{region}-2024-wf-scale-marg-hu26_{gov}_linear-summary.txt' for iteration in range(1, 4)]
            wf_stats_marg[region][wf][gov] = report_summary_for(temp_f2[0], temp_f2[1], temp_f2[2])
            

headers = ['workflow', 'governor', 'region', 'energy consumption (kWh)', 'average emissions (gCO2e)', 'marginal emissions (gCO2e)']
mean_data = []

for region in short_regions:
    for wf in workflows:
        for gov in governors:
            entry_avg = wf_stats_avg[region][wf][gov]
            entry_marg = wf_stats_marg[region][wf][gov]
            mean_data.append([region, wf, gov, entry_avg[ENERGY_CONSUMPTION], entry_avg[CARBON_EMISSIONS], entry_marg[CARBON_EMISSIONS]])

print(wf_stats_avg)

print(tabulate(mean_data, headers, tablefmt='orgtbl'))

with open('../data/results/resource-scaling/workflows/table_mean_data.csv', 'w') as f:
    f.write(','.join(headers) + '\n')

    for row in mean_data: 
        f.write(','.join([str(v) for v in row]) + '\n')
# Out:
# {'gb': {'chipseq': {'performance': {'Energy Consumption (exc. PUE)': 15.325366289047475, 'Memory Energy Consumption (exc. PUE)': 0.08621989247557209, 'Operational Carbon Emissions': 780.6798238805613, 'Embodied Carbon Emissions': 78.35105412325386, 'Total Carbon Emissions': 859.0308780038152}, 'powersave': {'Energy Consumption (exc. PUE)': 21.88665381505049, 'Memory Energy Consumption (exc. PUE)': 0.18664198596138362, 'Operational Carbon Emissions': 2313.2603686580296, 'Embodied Carbon Emissions': 231.36708755418616, 'Total Carbon Emissions': 2544.6274562122157}}, 'rnaseq': {'performance': {'Energy Consumption (exc. PUE)': 8.457312757894043, 'Memory Energy Consumption (exc. PUE)': 0.07387434759618454, 'Operational Carbon Emissions': 331.42443510779884, 'Embodied Carbon Emissions': 43.76241183740219, 'Total Carbon Emissions': 375.186846945201}, 'powersave': {'Energy Consumption (exc. PUE)': 11.197552860338371, 'Memory Energy Consumption (exc. PUE)': 0.13743071802470905, 'Operational Carbon Emissions': 687.6286970724605, 'Embodied Carbon Emissions': 119.68602488782399, 'Total Carbon Emissions': 807.3147219602846}}}, 'de': {'chipseq': {'performance': {'Energy Consumption (exc. PUE)': 15.325366289047475, 'Memory Energy Consumption (exc. PUE)': 0.08621989247557209, 'Operational Carbon Emissions': 3484.2457907923126, 'Embodied Carbon Emissions': 78.35105412325386, 'Total Carbon Emissions': 3562.596844915566}, 'powersave': {'Energy Consumption (exc. PUE)': 21.88665381505049, 'Memory Energy Consumption (exc. PUE)': 0.18664198596138362, 'Operational Carbon Emissions': 4582.5285288536, 'Embodied Carbon Emissions': 231.36708755418616, 'Total Carbon Emissions': 4813.895616407786}}, 'rnaseq': {'performance': {'Energy Consumption (exc. PUE)': 8.457312757894043, 'Memory Energy Consumption (exc. PUE)': 0.07387434759618454, 'Operational Carbon Emissions': 1438.312737238782, 'Embodied Carbon Emissions': 43.76241183740219, 'Total Carbon Emissions': 1482.0751490761843}, 'powersave': {'Energy Consumption (exc. PUE)': 11.197552860338371, 'Memory Energy Consumption (exc. PUE)': 0.13743071802470905, 'Operational Carbon Emissions': 2223.6231684561403, 'Embodied Carbon Emissions': 119.68602488782399, 'Total Carbon Emissions': 2343.3091933439646}}}, 'ca': {'chipseq': {'performance': {'Energy Consumption (exc. PUE)': 15.325366289047475, 'Memory Energy Consumption (exc. PUE)': 0.08621989247557209, 'Operational Carbon Emissions': 3079.9702637270007, 'Embodied Carbon Emissions': 78.35105412325386, 'Total Carbon Emissions': 3158.321317850255}, 'powersave': {'Energy Consumption (exc. PUE)': 21.88665381505049, 'Memory Energy Consumption (exc. PUE)': 0.18664198596138362, 'Operational Carbon Emissions': 2909.2115391916846, 'Embodied Carbon Emissions': 231.36708755418616, 'Total Carbon Emissions': 3140.57862674587}}, 'rnaseq': {'performance': {'Energy Consumption (exc. PUE)': 8.457312757894043, 'Memory Energy Consumption (exc. PUE)': 0.07387434759618454, 'Operational Carbon Emissions': 666.7169667053438, 'Embodied Carbon Emissions': 43.76241183740219, 'Total Carbon Emissions': 710.479378542746}, 'powersave': {'Energy Consumption (exc. PUE)': 11.197552860338371, 'Memory Energy Consumption (exc. PUE)': 0.13743071802470905, 'Operational Carbon Emissions': 1119.7425880121157, 'Embodied Carbon Emissions': 119.68602488782399, 'Total Carbon Emissions': 1239.4286128999397}}}, 'tx': {'chipseq': {'performance': {'Energy Consumption (exc. PUE)': 15.325366289047475, 'Memory Energy Consumption (exc. PUE)': 0.08621989247557209, 'Operational Carbon Emissions': 4839.219514233474, 'Embodied Carbon Emissions': 78.35105412325386, 'Total Carbon Emissions': 4917.570568356728}, 'powersave': {'Energy Consumption (exc. PUE)': 21.88665381505049, 'Memory Energy Consumption (exc. PUE)': 0.18664198596138362, 'Operational Carbon Emissions': 7572.870213758516, 'Embodied Carbon Emissions': 231.36708755418616, 'Total Carbon Emissions': 7804.237301312701}}, 'rnaseq': {'performance': {'Energy Con ...
# | workflow   | governor   | region      |   energy consumption (kWh) |   average emissions (gCO2e) |   marginal emissions (gCO2e) |
# |------------+------------+-------------+----------------------------+-----------------------------+------------------------------|
# | gb         | chipseq    | performance |                   15.3254  |                     780.68  |                      5955.6  |
# | gb         | chipseq    | powersave   |                   21.8867  |                    2313.26  |                      8802.37 |
# | gb         | rnaseq     | performance |                    8.45731 |                     331.424 |                      3319.3  |
# | gb         | rnaseq     | powersave   |                   11.1976  |                     687.629 |                      4529.89 |
# | de         | chipseq    | performance |                   15.3254  |                    3484.25  |                     11696.1  |
# | de         | chipseq    | powersave   |                   21.8867  |                    4582.53  |                     15738.6  |
# | de         | rnaseq     | performance |                    8.45731 |                    1438.31  |                      6022.21 |
# | de         | rnaseq     | powersave   |                   11.1976  |                    2223.62  |                      7041.53 |
# | ca         | chipseq    | performance |                   15.3254  |                    3079.97  |                      6620.19 |
# | ca         | chipseq    | powersave   |                   21.8867  |                    2909.21  |                      9136.56 |
# | ca         | rnaseq     | performance |                    8.45731 |                     666.717 |                      2063.13 |
# | ca         | rnaseq     | powersave   |                   11.1976  |                    1119.74  |                      3566.54 |
# | tx         | chipseq    | performance |                   15.3254  |                    4839.22  |                      7920.63 |
# | tx         | chipseq    | powersave   |                   21.8867  |                    7572.87  |                     11450.1  |
# | tx         | rnaseq     | performance |                    8.45731 |                    2273.1   |                      4586.78 |
# | tx         | rnaseq     | powersave   |                   11.1976  |                    3753.44  |                      5894.26 |
# | zaf        | chipseq    | performance |                   15.3254  |                   10012.6   |                     13927.9  |
# | zaf        | chipseq    | powersave   |                   21.8867  |                   14300.9   |                     20166.9  |
# | zaf        | rnaseq     | performance |                    8.45731 |                    5570.98  |                      7852    |
# | zaf        | rnaseq     | powersave   |                   11.1976  |                    7468.06  |                      9988.24 |
# | tyo        | chipseq    | performance |                   15.3254  |                    6421.12  |                      8268.86 |
# | tyo        | chipseq    | powersave   |                   21.8867  |                   10365.2   |                     11837    |
# | tyo        | rnaseq     | performance |                    8.45731 |                    4137.8   |                      4570.95 |
# | tyo        | rnaseq     | powersave   |                   11.1976  |                    4845.66  |                      6070.67 |
# | nsw        | chipseq    | performance |                   15.3254  |                    8867.67  |                     11706.9  |
# | nsw        | chipseq    | powersave   |                   21.8867  |                   12017.6   |                     16642.3  |
# | nsw        | rnaseq     | performance |                    8.45731 |                    5347.54  |                      6665.61 |
# | nsw        | rnaseq     | powersave   |                   11.1976  |                    6163.67  |                      8863.4  |
