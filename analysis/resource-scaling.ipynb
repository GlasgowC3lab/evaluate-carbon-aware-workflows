# %%
# Imports
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl
from tabulate import tabulate

# %%
# Constants
regions = ['Great Britain', 'Germany', 'California', 'Texas', 'South Africa', 'Tokyo', 'New South Wales']
short_regions = ['gb', 'de', 'ca', 'tx', 'zaf', 'tyo', 'nsw']
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
short_months = ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec'] 
tasks=['bowtie2_build', 'fastp', 'fastqc', 'trimgalore']
machines=['gpg13', 'gpg14', 'gpg15', 'gpg22', 'hu26', 'server']
governors=['performance', 'powersave']

# %%
# Constants
ENERGY_CONSUMPTION = "Energy Consumption (exc. PUE)"
ENERGY_CONSUMPTION_PUE = "Energy Consumption (inc. PUE)"
MEMORY_CONSUMPTION = "Memory Energy Consumption (exc. PUE)"
MEMORY_CONSUMPTION_PUE = "Memory Energy Consumption (inc. PUE)"
CARBON_EMISSIONS = "Operational Carbon Emissions"
EMBODIED_CARBON_EMISSIONS = "Embodied Carbon Emissions"
TOTAL_CARBON_EMISSIONS = "Total Carbon Emissions"
RES_MEM_ENERGY_CONSUMPTION = "Reserved Memory Energy Consumption"
RES_MEM_CARBON_EMISSIONS = "Reserved Memory Carbon Emissions"

# %%
# Parse Key Details from Summary Files
def get_data(lines):
    data = {}

    for line in lines:
        parts = line.strip().split(':')
        parts[0] = parts[0][2:].strip()
        data[parts[0]] = parts[1].replace('kWh', '').replace('gCO2e', '').strip()

    return data


def get_bonus_data(lines):
    data = {}

    for line in lines:
        if ':' in line: 
            parts = line.strip().split(':')

            if parts[0] == 'Task Runtime':
                continue

            data[parts[0]] = parts[1].replace('kWh', '').replace('gCO2e', '').strip()

    return data


def parse_summary(filename, bonus):
    with open(filename, 'r') as file:
        lines = file.readlines()

    info = get_data(lines[2:5])
    data = get_data(lines[7:14])

    if bonus:
        bonus = get_bonus_data(lines[14:])
    else:
        bonus = None

    return (info, data, bonus)


def get_average(first, second, third):
    data = {}

    for key in first.keys():
        data[key] = (float(first[key]) + float(second[key]) + float(third[key])) / 3

    return data


def print_summary(data):
    return {
        ENERGY_CONSUMPTION: data[ENERGY_CONSUMPTION],
        MEMORY_CONSUMPTION: data[MEMORY_CONSUMPTION],
        CARBON_EMISSIONS: data[CARBON_EMISSIONS],
        EMBODIED_CARBON_EMISSIONS: data[EMBODIED_CARBON_EMISSIONS],
        TOTAL_CARBON_EMISSIONS: data[TOTAL_CARBON_EMISSIONS]
    }


def print_info(data_1, data_2, data_3):
    matches = data_1 == data_2 == data_3

    if not matches:
        print("[ERROR] Workflow Data does not match ...")
        return

def print_bonus(data):
    # print(f"{RES_MEM_ENERGY_CONSUMPTION}: {data[RES_MEM_ENERGY_CONSUMPTION]:.2f}kWh")
    # print(f"{RES_MEM_CARBON_EMISSIONS}: {data[RES_MEM_CARBON_EMISSIONS]:.2f}gCO2e")
    # print(f"CPU [{data['cpu']:.2f}% | {data['mem']:.2f}%] Memory")

    return {
        RES_MEM_ENERGY_CONSUMPTION: data[RES_MEM_ENERGY_CONSUMPTION],
        RES_MEM_CARBON_EMISSIONS: data[RES_MEM_CARBON_EMISSIONS]
    }

def report_summary_for(filename_1, filename_2, filename_3, bonus=False):
    (info_1, data_1, bonus_1) = parse_summary(filename_1, bonus)
    (info_2, data_2, bonus_2) = parse_summary(filename_2, bonus)
    (info_3, data_3, bonus_3) = parse_summary(filename_3, bonus)
    avg_data = get_average(data_1, data_2, data_3)

    if bonus:
        avg_bonus = get_average(bonus_1, bonus_2, bonus_3)
        print_info(info_1, info_2, info_3)
        summary = print_summary(avg_data)
        bonus = print_bonus(avg_bonus)
        summary.update(bonus)
    else:
        summary = print_summary(avg_data)

    return summary

# %% [markdown]
# **Workflow Task Resource Scaling -- Processor Governor**

# %%
# Process Data for each task on each machine, in each month of the year, for each region 
task_stats_avg = {}

for region in short_regions:
    task_stats_avg[region] = {}
    for month in short_months:
        task_stats_avg[region][month] = {}
        for task in tasks:
            task_stats_avg[region][month][task] = {}
            for machine in machines:
                task_stats_avg[region][month][task][machine] = {}
                for gov in governors:
                    temp_f = [f'../data/results/resource-scaling/tasks/out/{region}/{machine}-{gov}-{task}-{iteration}-{month}-{region}-2024-{month}-mid-{gov}_linear-summary.txt' for iteration in range(1, 4)]
                    task_stats_avg[region][month][task][machine][gov] = report_summary_for(temp_f[0], temp_f[1], temp_f[2], bonus=True)

# %%
# Process Data for each task on each machine, in each month of the year, for each region 
task_stats_marg = {}

for region in short_regions:
    task_stats_marg[region] = {}
    for month in short_months:
        task_stats_marg[region][month] = {}
        for task in tasks:
            task_stats_marg[region][month][task] = {}
            for machine in machines:
                task_stats_marg[region][month][task][machine] = {}
                for gov in governors:
                    temp_f = [f'../data/results/resource-scaling/tasks/out/{region}/{machine}-{gov}-{task}-{iteration}-{month}-{region}-2024-{month}-mid-marg-{gov}_linear-summary.txt' for iteration in range(1, 4)]
                    task_stats_marg[region][month][task][machine][gov] = report_summary_for(temp_f[0], temp_f[1], temp_f[2], bonus=True)

# %%
def print_stats_for_month(month, all_data_avg, all_data_marg, task_runtimes):
    headers = ['region', 'task', 'machine', 'governor', 'runtime (h)', 'energy consumption (kWh)', 'average emissions (gCO2e)', 'marginal emissions (gCO2e)']
    table_data = []

    for region in short_regions:
        for task in tasks:
            for machine in machines:
                for gov in governors:
                    curr = task_stats_avg[region][month][task][machine][gov]
                    curr_energy = round(curr[ENERGY_CONSUMPTION] + curr[MEMORY_CONSUMPTION] + curr[RES_MEM_ENERGY_CONSUMPTION], 3)
                    curr_emissions = round(curr[CARBON_EMISSIONS], 2)
                    curr_runtime = round(task_runtimes[task][machine][gov], 2)
                    curr_marg = task_stats_marg[region][month][task][machine][gov]
                    curr_marg_emissions = round(curr_marg[CARBON_EMISSIONS], 2)
                    table_data.append([region, task, machine, gov, curr_runtime, curr_energy, curr_emissions, curr_marg_emissions])

    print("Comparison of Tasks @ Varied Frequencies using Average CI Data")
    print(tabulate(table_data, headers, tablefmt='orgtbl'))

    return table_data

# %%
def get_runtime(filename):
    with open(filename, 'r') as f:
        lines = f.readlines()

    parts = lines[1].split(',')
    return int(parts[19])

all_task_runtimes = {}

for task in tasks:
    all_task_runtimes[task] = {}
    for machine in machines:
        all_task_runtimes[task][machine] = {}
        for gov in governors:
            filebase = f'../data/traces/tasks/{task}/{machine}-{gov}-{task}-ITER.csv'
            runtime_1 = get_runtime(filebase.replace('ITER', '1'))
            runtime_2 = get_runtime(filebase.replace('ITER', '2'))
            runtime_3 = get_runtime(filebase.replace('ITER', '3'))
            avg_runtime = (runtime_1 + runtime_2 + runtime_3) / 3
            all_task_runtimes[task][machine][gov] = avg_runtime / 1000 / 3600

# %%
all_ra_data = {}

for month in short_months:
    print('\n' + month)
    month_data = print_stats_for_month(month, task_stats_avg, task_stats_marg, all_task_runtimes)

    for row in month_data:
        c_region = row[0]
        c_task = row[1]
        c_mach = row[2]
        c_gov = row[3]

        if c_region in all_ra_data:
            if c_mach in all_ra_data[c_region]:
                if c_task in all_ra_data[c_region][c_mach]:
                    if c_gov in all_ra_data[c_region][c_mach][c_task]:
                        all_ra_data[c_region][c_mach][c_task][c_gov]['avg emissions'].append(row[6])
                        all_ra_data[c_region][c_mach][c_task][c_gov]['marg emissions'].append(row[7])
                    else:
                        all_ra_data[c_region][c_mach][c_task][c_gov] = {
                            'runtime': row[4],
                            'energy': row[5],
                            'avg emissions': [row[6]],
                            'marg emissions': [row[7]]
                        }
                else:
                    all_ra_data[c_region][c_mach][c_task] = {}
                    all_ra_data[c_region][c_mach][c_task][c_gov] = {
                        'runtime': row[4],
                        'energy': row[5],
                        'avg emissions': [row[6]],
                        'marg emissions': [row[7]]
                    }
            else: 
                all_ra_data[c_region][c_mach] = {}
                all_ra_data[c_region][c_mach][c_task] = {}
                all_ra_data[c_region][c_mach][c_task][c_gov] = {
                    'runtime': row[4],
                    'energy': row[5],
                    'avg emissions': [row[6]],
                    'marg emissions': [row[7]]
                }
        else: 
            all_ra_data[c_region] = {}
            all_ra_data[c_region][c_mach] = {}
            all_ra_data[c_region][c_mach][c_task] = {}
            all_ra_data[c_region][c_mach][c_task][c_gov] = {
                'runtime': row[4],
                'energy': row[5],
                'avg emissions': [row[6]],
                'marg emissions': [row[7]]
            }
# Out:
# jan
# Comparison of Tasks @ Varied Frequencies using Average CI Data
# | region   | task          | machine   | governor    |   runtime (h) |   energy consumption (kWh) |   average emissions (gCO2e) |   marginal emissions (gCO2e) |
# |----------+---------------+-----------+-------------+---------------+----------------------------+-----------------------------+------------------------------|
# | gb       | bowtie2_build | gpg13     | performance |          0.25 |                      0.022 |                        5.1  |                         7.17 |
# | gb       | bowtie2_build | gpg13     | powersave   |          0.31 |                      0.025 |                        2.59 |                        10.97 |
# | gb       | bowtie2_build | gpg14     | performance |          0.25 |                      0.022 |                        5    |                         7.04 |
# ...

# %%
headers = ['region', 'task', 'machine', 'governor', 'runtime (h)', 'energy consumption (kWh)', 'average emissions (gCO2e)', 'marginal emissions (gCO2e)']
mean_data = []

for region in short_regions:
    for machine in machines:
        for task in tasks:
            for gov in governors:
                entry = all_ra_data[region][machine][task][gov]
                mean_avg_ems = sum(entry['avg emissions']) / len(entry['avg emissions'])
                mean_marg_ems = sum(entry['marg emissions']) / len(entry['marg emissions'])
                mean_data.append([region, task, machine, gov, entry['runtime'], entry['energy'], round(mean_avg_ems, 2), round(mean_marg_ems, 2)])

print(tabulate(mean_data, headers, tablefmt='orgtbl'))

with open('../data/results/resource-scaling/tasks/table_mean_data.csv', 'w') as f:
    f.write(','.join(headers) + '\n')

    for row in mean_data: 
        f.write(','.join([str(v) for v in row]) + '\n')
# Out:
# | region   | task          | machine   | governor    |   runtime (h) |   energy consumption (kWh) |   average emissions (gCO2e) |   marginal emissions (gCO2e) |
# |----------+---------------+-----------+-------------+---------------+----------------------------+-----------------------------+------------------------------|
# | gb       | bowtie2_build | gpg13     | performance |          0.25 |                      0.022 |                        2.51 |                         6.06 |
# | gb       | bowtie2_build | gpg13     | powersave   |          0.31 |                      0.025 |                        2.71 |                        10.69 |
# | gb       | fastp         | gpg13     | performance |          0.14 |                      0.013 |                        1.3  |                         2.24 |
# | gb       | fastp         | gpg13     | powersave   |          0.17 |                      0.014 |                        1.49 |                         5.58 |
# ...

# %% [markdown]
# **Workflow Resource Scaling -- Processor Governor (8 nodes)**

# %%
workflows = ['chipseq', 'rnaseq']
wf_stats_avg = {}
wf_stats_marg = {} 

for region in short_regions:
    wf_stats_avg[region] = {}
    wf_stats_marg[region] = {}
    for wf in workflows:
        wf_stats_avg[region][wf] = {}
        wf_stats_marg[region][wf] = {}
        for gov in governors:
            temp_f = [f'../data/results/resource-scaling/workflows/out/{wf}-{gov}-{iteration}-{region}-2024-wf-scale-{gov}_linear-summary.txt' for iteration in range(1, 4)]
            wf_stats_avg[region][wf][gov] = report_summary_for(temp_f[0], temp_f[1], temp_f[2], bonus=True)
            
            temp_f2 = [f'../data/results/resource-scaling/workflows/out/{wf}-{gov}-{iteration}-{region}-2024-wf-scale-marg-{gov}_linear-summary.txt' for iteration in range(1, 4)]
            wf_stats_marg[region][wf][gov] = report_summary_for(temp_f2[0], temp_f2[1], temp_f2[2], bonus=True)

headers = ['workflow', 'governor', 'region', 'energy consumption (kWh)', 'average emissions (gCO2e)', 'marginal emissions (gCO2e)']
mean_data = []

for region in short_regions:
    for wf in workflows:
        for gov in governors:
            entry_avg = wf_stats_avg[region][wf][gov]
            entry_marg = wf_stats_marg[region][wf][gov]
            mean_data.append([region, wf, gov, entry_avg[ENERGY_CONSUMPTION] + entry_avg[MEMORY_CONSUMPTION] + entry_avg[RES_MEM_ENERGY_CONSUMPTION], entry_avg[CARBON_EMISSIONS], entry_marg[CARBON_EMISSIONS]])

print(wf_stats_avg)

print(tabulate(mean_data, headers, tablefmt='orgtbl'))

with open('../data/results/resource-scaling/workflows/table_mean_data.csv', 'w') as f:
    f.write(','.join(headers) + '\n')

    for row in mean_data: 
        f.write(','.join([str(v) for v in row]) + '\n')
# Out:
# {'gb': {'chipseq': {'performance': {'Energy Consumption (exc. PUE)': 3.2273151415225527, 'Memory Energy Consumption (exc. PUE)': 0.08661207449931525, 'Operational Carbon Emissions': 190.08697012431784, 'Embodied Carbon Emissions': 0.0, 'Total Carbon Emissions': 190.08697012431784, 'Reserved Memory Energy Consumption': 0.4486348302469137, 'Reserved Memory Carbon Emissions': 22.63553564292438}, 'powersave': {'Energy Consumption (exc. PUE)': 4.179753280848963, 'Memory Energy Consumption (exc. PUE)': 0.18708548437042197, 'Operational Carbon Emissions': 538.0596133290334, 'Embodied Carbon Emissions': 0.0, 'Total Carbon Emissions': 538.0596133290334, 'Reserved Memory Energy Consumption': 1.0059042, 'Reserved Memory Carbon Emissions': 100.26921056799999}}, 'rnaseq': {'performance': {'Energy Consumption (exc. PUE)': 1.9849963694835104, 'Memory Energy Consumption (exc. PUE)': 0.07417765500360644, 'Operational Carbon Emissions': 92.0974289930478, 'Embodied Carbon Emissions': 0.0, 'Total Carbon
# ...

# %% [markdown]
# ## Workflow Scaling on Cluster Size 2,4,8

# %%
avg_data_rows = []
data_head = ['workflow', 'nodes', 'cpu_energy', 'mem_energy', 'static_mem_energy', 'total_energy', 'total_ems']

for cluster_size in [2,4,8]:
    run_1_fp = f'../data/traces/wf-cluster-scale/nodes-{cluster_size}/results/chipseq-1-de-01102023-31122023-default_minmax-summary.txt'
    run_2_fp = f'../data/traces/wf-cluster-scale/nodes-{cluster_size}/results/chipseq-2-de-01102023-31122023-default_minmax-summary.txt'
    run_3_fp = f'../data/traces/wf-cluster-scale/nodes-{cluster_size}/results/chipseq-3-de-01102023-31122023-default_minmax-summary.txt'
    wf_data = report_summary_for(run_1_fp, run_2_fp, run_3_fp, bonus=True)
    total_e = wf_data[ENERGY_CONSUMPTION] + wf_data[MEMORY_CONSUMPTION] + wf_data[RES_MEM_ENERGY_CONSUMPTION]
    row = ['chipseq', cluster_size, wf_data[ENERGY_CONSUMPTION], wf_data[MEMORY_CONSUMPTION], wf_data[RES_MEM_ENERGY_CONSUMPTION], total_e, wf_data[CARBON_EMISSIONS]]
    avg_data_rows.append(row)

print('avg emissions')
print(tabulate(avg_data_rows, data_head, tablefmt='orgtbl'))
# Out:
# avg emissions
# | workflow   |   nodes |   cpu_energy |   mem_energy |   static_mem_energy |   total_energy |   total_ems |
# |------------+---------+--------------+--------------+---------------------+----------------+-------------|
# | chipseq    |       2 |      5.08138 |     0.51378  |             1.18596 |        6.78112 |     2341.01 |
# | chipseq    |       4 |      5.10949 |     0.516463 |             1.19514 |        6.8211  |     1913.76 |
# | chipseq    |       8 |      5.19615 |     0.514529 |             1.23237 |        6.94305 |     1376.98 |

# %%
marg_data_rows = []
data_head = ['workflow', 'nodes', 'cpu_energy', 'mem_energy', 'static_mem_energy', 'total_energy', 'total_ems']

for cluster_size in [2,4,8]:
    run_1_fp = f'../data/traces/wf-cluster-scale/nodes-{cluster_size}/results/chipseq-1-de-01102023-31122023-marg-default_minmax-summary.txt'
    run_2_fp = f'../data/traces/wf-cluster-scale/nodes-{cluster_size}/results/chipseq-2-de-01102023-31122023-marg-default_minmax-summary.txt'
    run_3_fp = f'../data/traces/wf-cluster-scale/nodes-{cluster_size}/results/chipseq-3-de-01102023-31122023-marg-default_minmax-summary.txt'
    wf_data = report_summary_for(run_1_fp, run_2_fp, run_3_fp, bonus=True)
    total_e = wf_data[ENERGY_CONSUMPTION] + wf_data[MEMORY_CONSUMPTION] + wf_data[RES_MEM_ENERGY_CONSUMPTION]
    row = ['chipseq', cluster_size, wf_data[ENERGY_CONSUMPTION], wf_data[MEMORY_CONSUMPTION], wf_data[RES_MEM_ENERGY_CONSUMPTION], total_e, wf_data[CARBON_EMISSIONS]]
    marg_data_rows.append(row)

print('marg emissions')
print(tabulate(marg_data_rows, data_head, tablefmt='orgtbl'))
# Out:
# marg emissions
# | workflow   |   nodes |   cpu_energy |   mem_energy |   static_mem_energy |   total_energy |   total_ems |
# |------------+---------+--------------+--------------+---------------------+----------------+-------------|
# | chipseq    |       2 |      5.07897 |     0.513243 |             1.18596 |        6.77817 |     5054.35 |
# | chipseq    |       4 |      5.10384 |     0.514204 |             1.19514 |        6.81318 |     5132.89 |
# | chipseq    |       8 |      5.19201 |     0.513674 |             1.23237 |        6.93806 |     4425.68 |
