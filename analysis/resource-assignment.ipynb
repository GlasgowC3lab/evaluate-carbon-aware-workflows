# %%
# Imports
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl
from tabulate import tabulate

# %%
# Constants
regions = ['Great Britain', 'Germany', 'California', 'Texas', 'South Africa', 'Tokyo', 'New South Wales']
short_regions = ['gb', 'de', 'ca', 'tx', 'zaf', 'tyo', 'nsw']
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
short_months = ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec'] 
tasks=['bowtie2_build', 'fastp', 'fastqc', 'trimgalore']
machines=['gcpc2', 'gcpn2', 'gcpn1', 'gpg13', 'gpg14', 'gpg15', 'gpg22', 'hu26', 'server']
exp_machines=['gcpc2', 'gcpn2', 'gcpn1', 'gpg13-performance', 'gpg14-performance', 'gpg15-performance', 'gpg22-performance', 'hu26-performance', 'server-performance']
models=['default_minmax', 'default_minmax', 'default_minmax', 'performance_linear', 'performance_linear', 'performance_linear', 'performance_linear', 'performance_linear', 'performance_linear']

# %%
# Constants
ENERGY_CONSUMPTION = "Energy Consumption (exc. PUE)"
ENERGY_CONSUMPTION_PUE = "Energy Consumption (inc. PUE)"
MEMORY_CONSUMPTION = "Memory Energy Consumption (exc. PUE)"
MEMORY_CONSUMPTION_PUE = "Memory Energy Consumption (inc. PUE)"
CARBON_EMISSIONS = "Operational Carbon Emissions"
EMBODIED_CARBON_EMISSIONS = "Embodied Carbon Emissions"
TOTAL_CARBON_EMISSIONS = "Total Carbon Emissions"
RES_MEM_ENERGY_CONSUMPTION = "Reserved Memory Energy Consumption"
RES_MEM_CARBON_EMISSIONS = "Reserved Memory Carbon Emissions"

# %%
# Parse Key Details from Summary Files
def get_data(lines):
    data = {}

    for line in lines:
        parts = line.strip().split(':')
        parts[0] = parts[0][2:].strip()
        data[parts[0]] = parts[1].replace('kWh', '').replace('gCO2e', '').strip()

    return data

def get_bonus_data(lines):
    data = {}

    for line in lines:
        if ':' in line: 
            parts = line.strip().split(':')

            if parts[0] == 'Task Runtime':
                continue

            data[parts[0]] = parts[1].replace('kWh', '').replace('gCO2e', '').strip()
        else:
            if '|' in line:
                cpu_mem_split = line.split('|')
                cpu = cpu_mem_split[0].strip()
                mem = cpu_mem_split[1].strip()

    data['cpu'] = cpu.replace('% CPU [', '').replace('%]', '')
    data['mem'] = mem.replace('% Memory [', '').replace('%]', '')

    return data

def parse_summary(filename, bonus):
    with open(filename, 'r') as file:
        lines = file.readlines()

    info = get_data(lines[2:5])
    data = get_data(lines[7:14])

    if bonus:
        bonus = get_bonus_data(lines[14:])
    else:
        bonus = None

    return (info, data, bonus)


def get_average(first, second, third):
    data = {}

    for key in first.keys():
        data[key] = (float(first[key]) + float(second[key]) + float(third[key])) / 3

    return data


def print_summary(data):
    return {
        ENERGY_CONSUMPTION: data[ENERGY_CONSUMPTION],
        MEMORY_CONSUMPTION: data[MEMORY_CONSUMPTION],
        CARBON_EMISSIONS: data[CARBON_EMISSIONS],
        EMBODIED_CARBON_EMISSIONS: data[EMBODIED_CARBON_EMISSIONS],
        TOTAL_CARBON_EMISSIONS: data[TOTAL_CARBON_EMISSIONS]
    }


def print_info(data_1, data_2, data_3):
    matches = data_1 == data_2 == data_3

    if not matches:
        print("[ERROR] Workflow Data does not match ...")
        return

def report_summary_for(filename_1, filename_2, filename_3):
    (_, data_1) = parse_summary(filename_1)
    (_, data_2) = parse_summary(filename_2)
    (_, data_3) = parse_summary(filename_3)
    avg_data = get_average(data_1, data_2, data_3)
    summary = print_summary(avg_data)

    return summary

def get_bonus(data):
    print(f"{RES_MEM_ENERGY_CONSUMPTION}: {data[RES_MEM_ENERGY_CONSUMPTION]:.2f}kWh")
    print(f"{RES_MEM_CARBON_EMISSIONS}: {data[RES_MEM_CARBON_EMISSIONS]:.2f}gCO2e")
    print(f"CPU [{data['cpu']:.2f}% | {data['mem']:.2f}%] Memory")

    return {
        RES_MEM_ENERGY_CONSUMPTION: data[RES_MEM_ENERGY_CONSUMPTION],
        RES_MEM_CARBON_EMISSIONS: data[RES_MEM_CARBON_EMISSIONS]
    }

def report_summary_for(filename_1, filename_2, filename_3, bonus=False):
    (info_1, data_1, bonus_1) = parse_summary(filename_1, bonus)
    (info_2, data_2, bonus_2) = parse_summary(filename_2, bonus)
    (info_3, data_3, bonus_3) = parse_summary(filename_3, bonus)
    avg_data = get_average(data_1, data_2, data_3)

    if bonus:
        avg_bonus = get_average(bonus_1, bonus_2, bonus_3)
        print_info(info_1, info_2, info_3)
        summary = print_summary(avg_data)
        bonus = get_bonus(avg_bonus)
        summary.update(bonus)
    else:
        summary = print_summary(avg_data)

    return summary

# %%
# Process Data for each task on each machine, in each month of the year, for each region 
task_stats_avg = {}

for region in short_regions:
    task_stats_avg[region] = {}
    for month in short_months:
        task_stats_avg[region][month] = {}
        for task in tasks:
            task_stats_avg[region][month][task] = {}
            for machine, model in zip(machines, models):
                temp_f = [f'../data/results/resource-assignment/out/{region}/{machine}-{task}-{iteration}-{month}-{region}-2024-{month}-mid-{model}-summary.txt' for iteration in range(1, 4)]
                task_stats_avg[region][month][task][machine] = report_summary_for(temp_f[0], temp_f[1], temp_f[2], bonus=True)
# Out:
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.46gCO2e
# CPU [15.62% | 40.44%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.53gCO2e
# CPU [16.61% | 69.27%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.17gCO2e
# CPU [43.62% | 39.19%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 1.49gCO2e
# CPU [2.54% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 1.33gCO2e
# CPU [2.56% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 1.51gCO2e
# CPU [2.74% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.07gCO2e
# CPU [1.30% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.64gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.06gCO2e
# CPU [1.74% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.15gCO2e
# CPU [30.56% | 33.28%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.20gCO2e
# CPU [32.31% | 56.23%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.09gCO2e
# CPU [55.09% | 31.22%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.80gCO2e
# CPU [3.60% | 28.93%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.80gCO2e
# CPU [3.17% | 26.45%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.99gCO2e
# CPU [3.27% | 27.55%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [0.99% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.18gCO2e
# CPU [3.86% | 15.99%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.02gCO2e
# CPU [3.69% | 5.68%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.46gCO2e
# CPU [15.66% | 40.43%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.53gCO2e
# CPU [16.69% | 69.21%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.16gCO2e
# CPU [43.92% | 38.98%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 1.39gCO2e
# CPU [2.56% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 1.24gCO2e
# CPU [2.58% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 1.39gCO2e
# CPU [2.76% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.06gCO2e
# CPU [1.31% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.58gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.06gCO2e
# CPU [1.75% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.20gCO2e
# CPU [23.02% | 36.90%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.76gCO2e
# CPU [23.45% | 63.59%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.58gCO2e
# CPU [56.37% | 30.33%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 2.84gCO2e
# CPU [3.31% | 29.01%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 2.45gCO2e
# CPU [3.34% | 26.40%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 3.12gCO2e
# CPU [3.46% | 27.50%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.40gCO2e
# CPU [1.45% | 1.09%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.17gCO2e
# CPU [2.07% | 16.29%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.26gCO2e
# CPU [2.32% | 5.77%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.25gCO2e
# CPU [15.62% | 40.44%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.29gCO2e
# CPU [16.61% | 69.27%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.09gCO2e
# CPU [43.62% | 39.19%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.81gCO2e
# CPU [2.54% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.73gCO2e
# CPU [2.56% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.82gCO2e
# CPU [2.74% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [1.30% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.35gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.03gCO2e
# CPU [1.74% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.08gCO2e
# CPU [30.56% | 33.28%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.11gCO2e
# CPU [32.31% | 56.23%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [55.09% | 31.22%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.43gCO2e
# CPU [3.60% | 28.93%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.43gCO2e
# CPU [3.17% | 26.45%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.53gCO2e
# CPU [3.27% | 27.55%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.03gCO2e
# CPU [0.99% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.10gCO2e
# CPU [3.86% | 15.99%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.01gCO2e
# CPU [3.69% | 5.68%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.26gCO2e
# CPU [15.66% | 40.43%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.30gCO2e
# CPU [16.69% | 69.21%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.09gCO2e
# CPU [43.92% | 38.98%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.78gCO2e
# CPU [2.56% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.70gCO2e
# CPU [2.58% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.78gCO2e
# CPU [2.76% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.03gCO2e
# CPU [1.31% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.33gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.03gCO2e
# CPU [1.75% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.15gCO2e
# CPU [23.02% | 36.90%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.56gCO2e
# CPU [23.45% | 63.59%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.43gCO2e
# CPU [56.37% | 30.33%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 2.10gCO2e
# CPU [3.31% | 29.01%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 1.82gCO2e
# CPU [3.34% | 26.40%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 2.31gCO2e
# CPU [3.46% | 27.50%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.27gCO2e
# CPU [1.45% | 1.09%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.13gCO2e
# CPU [2.07% | 16.29%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.19gCO2e
# CPU [2.32% | 5.77%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.22gCO2e
# CPU [15.62% | 40.44%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.25gCO2e
# CPU [16.61% | 69.27%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.08gCO2e
# CPU [43.62% | 39.19%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.71gCO2e
# CPU [2.54% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.63gCO2e
# CPU [2.56% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.72gCO2e
# CPU [2.74% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.03gCO2e
# CPU [1.30% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.30gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.03gCO2e
# CPU [1.74% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.07gCO2e
# CPU [30.56% | 33.28%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.09gCO2e
# CPU [32.31% | 56.23%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [55.09% | 31.22%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.36gCO2e
# CPU [3.60% | 28.93%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.36gCO2e
# CPU [3.17% | 26.45%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.45gCO2e
# CPU [3.27% | 27.55%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.02gCO2e
# CPU [0.99% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.08gCO2e
# CPU [3.86% | 15.99%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.01gCO2e
# CPU [3.69% | 5.68%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.23gCO2e
# CPU [15.66% | 40.43%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.26gCO2e
# CPU [16.69% | 69.21%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.08gCO2e
# CPU [43.92% | 38.98%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.68gCO2e
# CPU [2.56% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.61gCO2e
# CPU [2.58% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.68gCO2e
# CPU [2.76% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.03gCO2e
# CPU [1.31% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.29gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.03gCO2e
# CPU [1.75% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.10gCO2e
# CPU [23.02% | 36.90%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.38gCO2e
# CPU [23.45% | 63.59%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.30gCO2e
# CPU [56.37% | 30.33%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 1.44gCO2e
# CPU [3.31% | 29.01%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 1.24gCO2e
# CPU [3.34% | 26.40%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 1.58gCO2e
# CPU [3.46% | 27.50%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.19gCO2e
# CPU [1.45% | 1.09%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.09gCO2e
# CPU [2.07% | 16.29%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.13gCO2e
# CPU [2.32% | 5.77%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [15.62% | 40.44%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.06gCO2e
# CPU [16.61% | 69.27%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.02gCO2e
# CPU [43.62% | 39.19%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.16gCO2e
# CPU [2.54% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.14gCO2e
# CPU [2.56% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.16gCO2e
# CPU [2.74% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.01gCO2e
# CPU [1.30% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.07gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.01gCO2e
# CPU [1.74% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.01gCO2e
# CPU [30.56% | 33.28%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.02gCO2e
# CPU [32.31% | 56.23%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.01gCO2e
# CPU [55.09% | 31.22%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.06gCO2e
# CPU [3.60% | 28.93%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.06gCO2e
# CPU [3.17% | 26.45%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.08gCO2e
# CPU [3.27% | 27.55%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.00gCO2e
# CPU [0.99% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.01gCO2e
# CPU [3.86% | 15.99%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.00gCO2e
# CPU [3.69% | 5.68%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [15.66% | 40.43%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [16.69% | 69.21%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.01gCO2e
# CPU [43.92% | 38.98%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.11gCO2e
# CPU [2.56% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.09gCO2e
# CPU [2.58% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.11gCO2e
# CPU [2.76% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.00gCO2e
# CPU [1.31% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.00gCO2e
# CPU [1.75% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.02gCO2e
# CPU [23.02% | 36.90%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.06gCO2e
# CPU [23.45% | 63.59%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [56.37% | 30.33%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.23gCO2e
# CPU [3.31% | 29.01%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.20gCO2e
# CPU [3.34% | 26.40%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.25gCO2e
# CPU [3.46% | 27.50%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.03gCO2e
# CPU [1.45% | 1.09%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.01gCO2e
# CPU [2.07% | 16.29%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.02gCO2e
# CPU [2.32% | 5.77%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.34gCO2e
# CPU [15.62% | 40.44%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.39gCO2e
# CPU [16.61% | 69.27%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.12gCO2e
# CPU [43.62% | 39.19%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 1.10gCO2e
# CPU [2.54% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.98gCO2e
# CPU [2.56% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 1.11gCO2e
# CPU [2.74% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [1.30% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.47gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [1.74% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.11gCO2e
# CPU [30.56% | 33.28%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.15gCO2e
# CPU [32.31% | 56.23%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.07gCO2e
# CPU [55.09% | 31.22%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.57gCO2e
# CPU [3.60% | 28.93%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.57gCO2e
# CPU [3.17% | 26.45%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.71gCO2e
# CPU [3.27% | 27.55%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [0.99% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.13gCO2e
# CPU [3.86% | 15.99%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.01gCO2e
# CPU [3.69% | 5.68%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.30gCO2e
# CPU [15.66% | 40.43%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.35gCO2e
# CPU [16.69% | 69.21%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.10gCO2e
# CPU [43.92% | 38.98%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.91gCO2e
# CPU [2.56% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.82gCO2e
# CPU [2.58% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.91gCO2e
# CPU [2.76% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [1.31% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.38gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [1.75% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.12gCO2e
# CPU [23.02% | 36.90%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.45gCO2e
# CPU [23.45% | 63.59%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.35gCO2e
# CPU [56.37% | 30.33%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 1.70gCO2e
# CPU [3.31% | 29.01%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 1.47gCO2e
# CPU [3.34% | 26.40%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 1.87gCO2e
# CPU [3.46% | 27.50%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.25gCO2e
# CPU [1.45% | 1.09%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.10gCO2e
# CPU [2.07% | 16.29%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.15gCO2e
# CPU [2.32% | 5.77%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.15gCO2e
# CPU [15.62% | 40.44%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.17gCO2e
# CPU [16.61% | 69.27%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [43.62% | 39.19%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.48gCO2e
# CPU [2.54% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.43gCO2e
# CPU [2.56% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.49gCO2e
# CPU [2.74% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.02gCO2e
# CPU [1.30% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.21gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.02gCO2e
# CPU [1.74% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [30.56% | 33.28%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.06gCO2e
# CPU [32.31% | 56.23%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.03gCO2e
# CPU [55.09% | 31.22%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.24gCO2e
# CPU [3.60% | 28.93%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.24gCO2e
# CPU [3.17% | 26.45%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.30gCO2e
# CPU [3.27% | 27.55%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.02gCO2e
# CPU [0.99% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.06gCO2e
# CPU [3.86% | 15.99%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.01gCO2e
# CPU [3.69% | 5.68%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.15gCO2e
# CPU [15.66% | 40.43%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.17gCO2e
# CPU [16.69% | 69.21%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [43.92% | 38.98%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.44gCO2e
# CPU [2.56% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.40gCO2e
# CPU [2.58% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.44gCO2e
# CPU [2.76% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.02gCO2e
# CPU [1.31% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.19gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.02gCO2e
# CPU [1.75% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.06gCO2e
# CPU [23.02% | 36.90%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.22gCO2e
# CPU [23.45% | 63.59%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.17gCO2e
# CPU [56.37% | 30.33%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.83gCO2e
# CPU [3.31% | 29.01%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.72gCO2e
# CPU [3.34% | 26.40%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.91gCO2e
# CPU [3.46% | 27.50%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.10gCO2e
# CPU [1.45% | 1.09%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [2.07% | 16.29%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.06gCO2e
# CPU [2.32% | 5.77%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.30gCO2e
# CPU [15.62% | 40.44%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.34gCO2e
# CPU [16.61% | 69.27%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.11gCO2e
# CPU [43.62% | 39.19%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.96gCO2e
# CPU [2.54% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.86gCO2e
# CPU [2.56% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.97gCO2e
# CPU [2.74% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [1.30% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.41gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [1.74% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.09gCO2e
# CPU [30.56% | 33.28%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.12gCO2e
# CPU [32.31% | 56.23%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.06gCO2e
# CPU [55.09% | 31.22%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.48gCO2e
# CPU [3.60% | 28.93%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.48gCO2e
# CPU [3.17% | 26.45%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.60gCO2e
# CPU [3.27% | 27.55%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.03gCO2e
# CPU [0.99% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.11gCO2e
# CPU [3.86% | 15.99%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.01gCO2e
# CPU [3.69% | 5.68%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.22gCO2e
# CPU [15.66% | 40.43%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.25gCO2e
# CPU [16.69% | 69.21%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.07gCO2e
# CPU [43.92% | 38.98%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.65gCO2e
# CPU [2.56% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.58gCO2e
# CPU [2.58% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.65gCO2e
# CPU [2.76% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.03gCO2e
# CPU [1.31% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.27gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.03gCO2e
# CPU [1.75% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.08gCO2e
# CPU [23.02% | 36.90%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.32gCO2e
# CPU [23.45% | 63.59%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.25gCO2e
# CPU [56.37% | 30.33%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 1.20gCO2e
# CPU [3.31% | 29.01%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 1.03gCO2e
# CPU [3.34% | 26.40%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 1.31gCO2e
# CPU [3.46% | 27.50%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.19gCO2e
# CPU [1.45% | 1.09%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.07gCO2e
# CPU [2.07% | 16.29%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.10gCO2e
# CPU [2.32% | 5.77%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.14gCO2e
# CPU [15.62% | 40.44%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.16gCO2e
# CPU [16.61% | 69.27%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [43.62% | 39.19%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.46gCO2e
# CPU [2.54% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.41gCO2e
# CPU [2.56% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.46gCO2e
# CPU [2.74% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.02gCO2e
# CPU [1.30% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.20gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.02gCO2e
# CPU [1.74% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.03gCO2e
# CPU [30.56% | 33.28%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [32.31% | 56.23%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.02gCO2e
# CPU [55.09% | 31.22%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.16gCO2e
# CPU [3.60% | 28.93%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.16gCO2e
# CPU [3.17% | 26.45%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.20gCO2e
# CPU [3.27% | 27.55%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.01gCO2e
# CPU [0.99% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [3.86% | 15.99%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.00gCO2e
# CPU [3.69% | 5.68%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.08gCO2e
# CPU [15.66% | 40.43%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.09gCO2e
# CPU [16.69% | 69.21%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.03gCO2e
# CPU [43.92% | 38.98%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.25gCO2e
# CPU [2.56% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.22gCO2e
# CPU [2.58% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.25gCO2e
# CPU [2.76% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.01gCO2e
# CPU [1.31% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.10gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.01gCO2e
# CPU [1.75% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [23.02% | 36.90%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.14gCO2e
# CPU [23.45% | 63.59%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.11gCO2e
# CPU [56.37% | 30.33%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.54gCO2e
# CPU [3.31% | 29.01%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.47gCO2e
# CPU [3.34% | 26.40%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.59gCO2e
# CPU [3.46% | 27.50%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.08gCO2e
# CPU [1.45% | 1.09%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.03gCO2e
# CPU [2.07% | 16.29%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [2.32% | 5.77%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.11gCO2e
# CPU [15.62% | 40.44%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.12gCO2e
# CPU [16.61% | 69.27%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [43.62% | 39.19%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.35gCO2e
# CPU [2.54% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.31gCO2e
# CPU [2.56% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.35gCO2e
# CPU [2.74% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.02gCO2e
# CPU [1.30% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.15gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.01gCO2e
# CPU [1.74% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.03gCO2e
# CPU [30.56% | 33.28%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [32.31% | 56.23%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.02gCO2e
# CPU [55.09% | 31.22%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.17gCO2e
# CPU [3.60% | 28.93%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.17gCO2e
# CPU [3.17% | 26.45%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.21gCO2e
# CPU [3.27% | 27.55%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.01gCO2e
# CPU [0.99% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [3.86% | 15.99%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.00gCO2e
# CPU [3.69% | 5.68%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.11gCO2e
# CPU [15.66% | 40.43%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.13gCO2e
# CPU [16.69% | 69.21%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [43.92% | 38.98%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.33gCO2e
# CPU [2.56% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.30gCO2e
# CPU [2.58% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.33gCO2e
# CPU [2.76% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.01gCO2e
# CPU [1.31% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.14gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.01gCO2e
# CPU [1.75% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.08gCO2e
# CPU [23.02% | 36.90%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.29gCO2e
# CPU [23.45% | 63.59%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.23gCO2e
# CPU [56.37% | 30.33%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 1.10gCO2e
# CPU [3.31% | 29.01%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.95gCO2e
# CPU [3.34% | 26.40%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 1.21gCO2e
# CPU [3.46% | 27.50%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.11gCO2e
# CPU [1.45% | 1.09%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.07gCO2e
# CPU [2.07% | 16.29%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.08gCO2e
# CPU [2.32% | 5.77%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.21gCO2e
# CPU [15.62% | 40.44%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.24gCO2e
# CPU [16.61% | 69.27%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.08gCO2e
# CPU [43.62% | 39.19%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.67gCO2e
# CPU [2.54% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.60gCO2e
# CPU [2.56% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.68gCO2e
# CPU [2.74% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.03gCO2e
# CPU [1.30% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.29gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.03gCO2e
# CPU [1.74% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.08gCO2e
# CPU [30.56% | 33.28%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.11gCO2e
# CPU [32.31% | 56.23%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [55.09% | 31.22%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.43gCO2e
# CPU [3.60% | 28.93%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.43gCO2e
# CPU [3.17% | 26.45%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.53gCO2e
# CPU [3.27% | 27.55%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.03gCO2e
# CPU [0.99% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.10gCO2e
# CPU [3.86% | 15.99%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.01gCO2e
# CPU [3.69% | 5.68%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.28gCO2e
# CPU [15.66% | 40.43%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.32gCO2e
# CPU [16.69% | 69.21%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.09gCO2e
# CPU [43.92% | 38.98%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.84gCO2e
# CPU [2.56% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.75gCO2e
# CPU [2.58% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.84gCO2e
# CPU [2.76% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.03gCO2e
# CPU [1.31% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.35gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [1.75% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.13gCO2e
# CPU [23.02% | 36.90%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.51gCO2e
# CPU [23.45% | 63.59%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.39gCO2e
# CPU [56.37% | 30.33%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 1.91gCO2e
# CPU [3.31% | 29.01%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 1.65gCO2e
# CPU [3.34% | 26.40%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 2.10gCO2e
# CPU [3.46% | 27.50%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.23gCO2e
# CPU [1.45% | 1.09%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.12gCO2e
# CPU [2.07% | 16.29%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.16gCO2e
# CPU [2.32% | 5.77%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.35gCO2e
# CPU [15.62% | 40.44%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.40gCO2e
# CPU [16.61% | 69.27%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.13gCO2e
# CPU [43.62% | 39.19%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 1.14gCO2e
# CPU [2.54% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 1.02gCO2e
# CPU [2.56% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 1.15gCO2e
# CPU [2.74% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.06gCO2e
# CPU [1.30% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.49gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [1.74% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.11gCO2e
# CPU [30.56% | 33.28%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.15gCO2e
# CPU [32.31% | 56.23%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.07gCO2e
# CPU [55.09% | 31.22%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.60gCO2e
# CPU [3.60% | 28.93%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.60gCO2e
# CPU [3.17% | 26.45%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.74gCO2e
# CPU [3.27% | 27.55%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [0.99% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.14gCO2e
# CPU [3.86% | 15.99%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.02gCO2e
# CPU [3.69% | 5.68%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.36gCO2e
# CPU [15.66% | 40.43%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.41gCO2e
# CPU [16.69% | 69.21%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.12gCO2e
# CPU [43.92% | 38.98%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 1.08gCO2e
# CPU [2.56% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.96gCO2e
# CPU [2.58% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 1.08gCO2e
# CPU [2.76% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [1.31% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.45gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [1.75% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.15gCO2e
# CPU [23.02% | 36.90%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.59gCO2e
# CPU [23.45% | 63.59%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.45gCO2e
# CPU [56.37% | 30.33%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 2.21gCO2e
# CPU [3.31% | 29.01%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 1.91gCO2e
# CPU [3.34% | 26.40%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 2.43gCO2e
# CPU [3.46% | 27.50%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.30gCO2e
# CPU [1.45% | 1.09%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.14gCO2e
# CPU [2.07% | 16.29%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.20gCO2e
# CPU [2.32% | 5.77%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.15gCO2e
# CPU [15.62% | 40.44%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.17gCO2e
# CPU [16.61% | 69.27%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [43.62% | 39.19%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.48gCO2e
# CPU [2.54% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.43gCO2e
# CPU [2.56% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 0.48gCO2e
# CPU [2.74% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.02gCO2e
# CPU [1.30% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.21gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.02gCO2e
# CPU [1.74% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [30.56% | 33.28%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [32.31% | 56.23%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.02gCO2e
# CPU [55.09% | 31.22%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.21gCO2e
# CPU [3.60% | 28.93%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.21gCO2e
# CPU [3.17% | 26.45%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.26gCO2e
# CPU [3.27% | 27.55%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.01gCO2e
# CPU [0.99% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [3.86% | 15.99%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# ...
# Reserved Memory Carbon Emissions: 0.16gCO2e
# CPU [1.30% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.45gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.13gCO2e
# CPU [1.74% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.40gCO2e
# CPU [30.56% | 33.28%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.54gCO2e
# CPU [32.31% | 56.23%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.25gCO2e
# CPU [55.09% | 31.22%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 2.12gCO2e
# CPU [3.60% | 28.93%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 2.11gCO2e
# CPU [3.17% | 26.45%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 2.62gCO2e
# CPU [3.27% | 27.55%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.14gCO2e
# CPU [0.99% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.48gCO2e
# CPU [3.86% | 15.99%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [3.69% | 5.68%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.34gCO2e
# CPU [15.66% | 40.43%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.53gCO2e
# CPU [16.69% | 69.21%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.45gCO2e
# CPU [43.92% | 38.98%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 4.02gCO2e
# CPU [2.56% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 3.59gCO2e
# CPU [2.58% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 4.02gCO2e
# CPU [2.76% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.16gCO2e
# CPU [1.31% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.69gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.17gCO2e
# CPU [1.75% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.58gCO2e
# CPU [23.02% | 36.90%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 2.24gCO2e
# CPU [23.45% | 63.59%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.72gCO2e
# CPU [56.37% | 30.33%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 8.41gCO2e
# CPU [3.31% | 29.01%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 7.28gCO2e
# CPU [3.34% | 26.40%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 9.25gCO2e
# CPU [3.46% | 27.50%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.10gCO2e
# CPU [1.45% | 1.09%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.52gCO2e
# CPU [2.07% | 16.29%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.76gCO2e
# CPU [2.32% | 5.77%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.23gCO2e
# CPU [15.62% | 40.44%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.40gCO2e
# CPU [16.61% | 69.27%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.44gCO2e
# CPU [43.62% | 39.19%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 3.97gCO2e
# CPU [2.54% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 3.54gCO2e
# CPU [2.56% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 4.00gCO2e
# CPU [2.74% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.19gCO2e
# CPU [1.30% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.70gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.15gCO2e
# CPU [1.74% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.47gCO2e
# CPU [30.56% | 33.28%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.62gCO2e
# CPU [32.31% | 56.23%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.29gCO2e
# CPU [55.09% | 31.22%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 2.45gCO2e
# CPU [3.60% | 28.93%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 2.45gCO2e
# CPU [3.17% | 26.45%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 3.03gCO2e
# CPU [3.27% | 27.55%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.16gCO2e
# CPU [0.99% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.56gCO2e
# CPU [3.86% | 15.99%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.06gCO2e
# CPU [3.69% | 5.68%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.43gCO2e
# CPU [15.66% | 40.43%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.64gCO2e
# CPU [16.69% | 69.21%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.48gCO2e
# CPU [43.92% | 38.98%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 4.30gCO2e
# CPU [2.56% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 3.84gCO2e
# CPU [2.58% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 4.30gCO2e
# CPU [2.76% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.17gCO2e
# CPU [1.31% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.80gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.18gCO2e
# CPU [1.75% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.59gCO2e
# CPU [23.02% | 36.90%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 2.29gCO2e
# CPU [23.45% | 63.59%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.76gCO2e
# CPU [56.37% | 30.33%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 8.59gCO2e
# CPU [3.31% | 29.01%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 7.43gCO2e
# CPU [3.34% | 26.40%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 9.44gCO2e
# CPU [3.46% | 27.50%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.17gCO2e
# CPU [1.45% | 1.09%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.53gCO2e
# CPU [2.07% | 16.29%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.78gCO2e
# CPU [2.32% | 5.77%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.96gCO2e
# CPU [15.62% | 40.44%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.09gCO2e
# CPU [16.61% | 69.27%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.35gCO2e
# CPU [43.62% | 39.19%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 3.08gCO2e
# CPU [2.54% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 2.75gCO2e
# CPU [2.56% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 3.11gCO2e
# CPU [2.74% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.15gCO2e
# CPU [1.30% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.32gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.12gCO2e
# CPU [1.74% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.36gCO2e
# CPU [30.56% | 33.28%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.49gCO2e
# CPU [32.31% | 56.23%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.22gCO2e
# CPU [55.09% | 31.22%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.91gCO2e
# CPU [3.60% | 28.93%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.91gCO2e
# CPU [3.17% | 26.45%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 2.37gCO2e
# CPU [3.27% | 27.55%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.12gCO2e
# CPU [0.99% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.43gCO2e
# CPU [3.86% | 15.99%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [3.69% | 5.68%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.16gCO2e
# CPU [15.66% | 40.43%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.33gCO2e
# CPU [16.69% | 69.21%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.39gCO2e
# CPU [43.92% | 38.98%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 3.49gCO2e
# CPU [2.56% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 3.12gCO2e
# CPU [2.58% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 3.49gCO2e
# CPU [2.76% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.14gCO2e
# CPU [1.31% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.47gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.15gCO2e
# CPU [1.75% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.47gCO2e
# CPU [23.02% | 36.90%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.79gCO2e
# CPU [23.45% | 63.59%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.38gCO2e
# CPU [56.37% | 30.33%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 6.73gCO2e
# CPU [3.31% | 29.01%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 5.82gCO2e
# CPU [3.34% | 26.40%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 7.40gCO2e
# CPU [3.46% | 27.50%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.97gCO2e
# CPU [1.45% | 1.09%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.41gCO2e
# CPU [2.07% | 16.29%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.65gCO2e
# CPU [2.32% | 5.77%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.05gCO2e
# CPU [15.62% | 40.44%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.20gCO2e
# CPU [16.61% | 69.27%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.38gCO2e
# CPU [43.62% | 39.19%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 3.39gCO2e
# CPU [2.54% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 3.02gCO2e
# CPU [2.56% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 3.42gCO2e
# CPU [2.74% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.16gCO2e
# CPU [1.30% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.45gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.13gCO2e
# CPU [1.74% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.41gCO2e
# CPU [30.56% | 33.28%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.55gCO2e
# CPU [32.31% | 56.23%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.25gCO2e
# CPU [55.09% | 31.22%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 2.17gCO2e
# CPU [3.60% | 28.93%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 2.16gCO2e
# CPU [3.17% | 26.45%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 2.68gCO2e
# CPU [3.27% | 27.55%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.14gCO2e
# CPU [0.99% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.49gCO2e
# CPU [3.86% | 15.99%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.06gCO2e
# CPU [3.69% | 5.68%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.34gCO2e
# CPU [15.66% | 40.43%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.53gCO2e
# CPU [16.69% | 69.21%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.45gCO2e
# CPU [43.92% | 38.98%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 4.01gCO2e
# CPU [2.56% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 3.58gCO2e
# CPU [2.58% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 4.01gCO2e
# CPU [2.76% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.16gCO2e
# CPU [1.31% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.68gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.17gCO2e
# CPU [1.75% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.52gCO2e
# CPU [23.02% | 36.90%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.99gCO2e
# CPU [23.45% | 63.59%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.53gCO2e
# CPU [56.37% | 30.33%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 7.47gCO2e
# CPU [3.31% | 29.01%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 6.46gCO2e
# CPU [3.34% | 26.40%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 8.21gCO2e
# CPU [3.46% | 27.50%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.06gCO2e
# CPU [1.45% | 1.09%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.46gCO2e
# CPU [2.07% | 16.29%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.71gCO2e
# CPU [2.32% | 5.77%] Memory

# %%
# Process Data for each task on each machine, in each month of the year, for each region 
task_stats_marg = {}

for region in short_regions:
    task_stats_marg[region] = {}
    for month in short_months:
        task_stats_marg[region][month] = {}
        for task in tasks:
            task_stats_marg[region][month][task] = {}
            for machine, model in zip(machines, models):
                temp_f = [f'../data/results/resource-assignment/out/{region}/{machine}-{task}-{iteration}-{month}-{region}-2024-{month}-mid-marg-{model}-summary.txt' for iteration in range(1, 4)]
                task_stats_marg[region][month][task][machine] = report_summary_for(temp_f[0], temp_f[1], temp_f[2], bonus=True)
# Out:
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.47gCO2e
# CPU [15.62% | 40.44%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.61gCO2e
# CPU [16.61% | 69.27%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.24gCO2e
# CPU [43.62% | 39.19%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 2.10gCO2e
# CPU [2.54% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.87gCO2e
# CPU [2.56% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 2.13gCO2e
# CPU [2.74% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.07gCO2e
# CPU [1.30% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.65gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [1.74% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.35gCO2e
# CPU [30.56% | 33.28%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.47gCO2e
# CPU [32.31% | 56.23%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.09gCO2e
# CPU [55.09% | 31.22%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.74gCO2e
# CPU [3.60% | 28.93%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.85gCO2e
# CPU [3.17% | 26.45%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.15gCO2e
# CPU [3.27% | 27.55%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.03gCO2e
# CPU [0.99% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.42gCO2e
# CPU [3.86% | 15.99%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [3.69% | 5.68%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.59gCO2e
# CPU [15.66% | 40.43%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.75gCO2e
# CPU [16.69% | 69.21%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.25gCO2e
# CPU [43.92% | 38.98%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 2.24gCO2e
# CPU [2.56% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 2.01gCO2e
# CPU [2.58% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 2.25gCO2e
# CPU [2.76% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [1.31% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.68gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.07gCO2e
# CPU [1.75% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 5.81gCO2e
# CPU [23.02% | 36.90%] Memory
# Reserved Memory Energy Consumption: 0.02kWh
# Reserved Memory Carbon Emissions: 7.09gCO2e
# CPU [23.45% | 63.59%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 2.59gCO2e
# CPU [56.37% | 30.33%] Memory
# Reserved Memory Energy Consumption: 0.04kWh
# Reserved Memory Carbon Emissions: 17.77gCO2e
# CPU [3.31% | 29.01%] Memory
# Reserved Memory Energy Consumption: 0.03kWh
# Reserved Memory Carbon Emissions: 15.62gCO2e
# CPU [3.34% | 26.40%] Memory
# Reserved Memory Energy Consumption: 0.04kWh
# Reserved Memory Carbon Emissions: 18.35gCO2e
# CPU [3.46% | 27.50%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.82gCO2e
# CPU [1.45% | 1.09%] Memory
# Reserved Memory Energy Consumption: 0.02kWh
# Reserved Memory Carbon Emissions: 7.88gCO2e
# CPU [2.07% | 16.29%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.79gCO2e
# CPU [2.32% | 5.77%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.45gCO2e
# CPU [15.62% | 40.44%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.58gCO2e
# CPU [16.61% | 69.27%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.22gCO2e
# CPU [43.62% | 39.19%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.98gCO2e
# CPU [2.54% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.77gCO2e
# CPU [2.56% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 2.02gCO2e
# CPU [2.74% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.06gCO2e
# CPU [1.30% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.61gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [1.74% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.30gCO2e
# CPU [30.56% | 33.28%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.40gCO2e
# CPU [32.31% | 56.23%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.08gCO2e
# CPU [55.09% | 31.22%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.67gCO2e
# CPU [3.60% | 28.93%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.77gCO2e
# CPU [3.17% | 26.45%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.05gCO2e
# CPU [3.27% | 27.55%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.03gCO2e
# CPU [0.99% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.36gCO2e
# CPU [3.86% | 15.99%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [3.69% | 5.68%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.51gCO2e
# CPU [15.66% | 40.43%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.65gCO2e
# CPU [16.69% | 69.21%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.22gCO2e
# CPU [43.92% | 38.98%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.93gCO2e
# CPU [2.56% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.72gCO2e
# CPU [2.58% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.93gCO2e
# CPU [2.76% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [1.31% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.58gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.06gCO2e
# CPU [1.75% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 5.76gCO2e
# CPU [23.02% | 36.90%] Memory
# Reserved Memory Energy Consumption: 0.02kWh
# Reserved Memory Carbon Emissions: 6.92gCO2e
# CPU [23.45% | 63.59%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 2.47gCO2e
# CPU [56.37% | 30.33%] Memory
# Reserved Memory Energy Consumption: 0.04kWh
# Reserved Memory Carbon Emissions: 17.13gCO2e
# CPU [3.31% | 29.01%] Memory
# Reserved Memory Energy Consumption: 0.03kWh
# Reserved Memory Carbon Emissions: 15.06gCO2e
# CPU [3.34% | 26.40%] Memory
# Reserved Memory Energy Consumption: 0.04kWh
# Reserved Memory Carbon Emissions: 17.65gCO2e
# CPU [3.46% | 27.50%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.78gCO2e
# CPU [1.45% | 1.09%] Memory
# Reserved Memory Energy Consumption: 0.02kWh
# Reserved Memory Carbon Emissions: 7.82gCO2e
# CPU [2.07% | 16.29%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.78gCO2e
# CPU [2.32% | 5.77%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.39gCO2e
# CPU [15.62% | 40.44%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.51gCO2e
# CPU [16.61% | 69.27%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.20gCO2e
# CPU [43.62% | 39.19%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.74gCO2e
# CPU [2.54% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.55gCO2e
# CPU [2.56% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.77gCO2e
# CPU [2.74% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [1.30% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.54gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [1.74% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.29gCO2e
# CPU [30.56% | 33.28%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.39gCO2e
# CPU [32.31% | 56.23%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.08gCO2e
# CPU [55.09% | 31.22%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.64gCO2e
# CPU [3.60% | 28.93%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.73gCO2e
# CPU [3.17% | 26.45%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.00gCO2e
# CPU [3.27% | 27.55%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.03gCO2e
# CPU [0.99% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.35gCO2e
# CPU [3.86% | 15.99%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [3.69% | 5.68%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.52gCO2e
# CPU [15.66% | 40.43%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.66gCO2e
# CPU [16.69% | 69.21%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.22gCO2e
# CPU [43.92% | 38.98%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.97gCO2e
# CPU [2.56% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.77gCO2e
# CPU [2.58% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.98gCO2e
# CPU [2.76% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [1.31% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.60gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.06gCO2e
# CPU [1.75% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 5.28gCO2e
# CPU [23.02% | 36.90%] Memory
# Reserved Memory Energy Consumption: 0.02kWh
# Reserved Memory Carbon Emissions: 6.46gCO2e
# CPU [23.45% | 63.59%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 2.40gCO2e
# CPU [56.37% | 30.33%] Memory
# Reserved Memory Energy Consumption: 0.04kWh
# Reserved Memory Carbon Emissions: 16.31gCO2e
# CPU [3.31% | 29.01%] Memory
# Reserved Memory Energy Consumption: 0.03kWh
# Reserved Memory Carbon Emissions: 14.33gCO2e
# CPU [3.34% | 26.40%] Memory
# Reserved Memory Energy Consumption: 0.04kWh
# Reserved Memory Carbon Emissions: 16.87gCO2e
# CPU [3.46% | 27.50%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.73gCO2e
# CPU [1.45% | 1.09%] Memory
# Reserved Memory Energy Consumption: 0.02kWh
# Reserved Memory Carbon Emissions: 7.18gCO2e
# CPU [2.07% | 16.29%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.72gCO2e
# CPU [2.32% | 5.77%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.44gCO2e
# CPU [15.62% | 40.44%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.56gCO2e
# CPU [16.61% | 69.27%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.22gCO2e
# CPU [43.62% | 39.19%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.93gCO2e
# CPU [2.54% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.72gCO2e
# CPU [2.56% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.96gCO2e
# CPU [2.74% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.06gCO2e
# CPU [1.30% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.60gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [1.74% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.28gCO2e
# CPU [30.56% | 33.28%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.37gCO2e
# CPU [32.31% | 56.23%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.08gCO2e
# CPU [55.09% | 31.22%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.62gCO2e
# CPU [3.60% | 28.93%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.72gCO2e
# CPU [3.17% | 26.45%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.98gCO2e
# CPU [3.27% | 27.55%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.02gCO2e
# CPU [0.99% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.33gCO2e
# CPU [3.86% | 15.99%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [3.69% | 5.68%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.47gCO2e
# CPU [15.66% | 40.43%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.60gCO2e
# CPU [16.69% | 69.21%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.20gCO2e
# CPU [43.92% | 38.98%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.78gCO2e
# CPU [2.56% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.59gCO2e
# CPU [2.58% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.79gCO2e
# CPU [2.76% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [1.31% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.54gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [1.75% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 4.80gCO2e
# CPU [23.02% | 36.90%] Memory
# Reserved Memory Energy Consumption: 0.02kWh
# Reserved Memory Carbon Emissions: 5.82gCO2e
# CPU [23.45% | 63.59%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 2.10gCO2e
# CPU [56.37% | 30.33%] Memory
# Reserved Memory Energy Consumption: 0.04kWh
# Reserved Memory Carbon Emissions: 14.49gCO2e
# CPU [3.31% | 29.01%] Memory
# Reserved Memory Energy Consumption: 0.03kWh
# Reserved Memory Carbon Emissions: 12.74gCO2e
# CPU [3.34% | 26.40%] Memory
# Reserved Memory Energy Consumption: 0.04kWh
# Reserved Memory Carbon Emissions: 14.95gCO2e
# CPU [3.46% | 27.50%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.68gCO2e
# CPU [1.45% | 1.09%] Memory
# Reserved Memory Energy Consumption: 0.02kWh
# Reserved Memory Carbon Emissions: 6.52gCO2e
# CPU [2.07% | 16.29%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.65gCO2e
# CPU [2.32% | 5.77%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.38gCO2e
# CPU [15.62% | 40.44%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.49gCO2e
# CPU [16.61% | 69.27%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.19gCO2e
# CPU [43.62% | 39.19%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.68gCO2e
# CPU [2.54% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.50gCO2e
# CPU [2.56% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.71gCO2e
# CPU [2.74% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [1.30% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.52gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [1.74% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.28gCO2e
# CPU [30.56% | 33.28%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.37gCO2e
# CPU [32.31% | 56.23%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.08gCO2e
# CPU [55.09% | 31.22%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.62gCO2e
# CPU [3.60% | 28.93%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.72gCO2e
# CPU [3.17% | 26.45%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.98gCO2e
# CPU [3.27% | 27.55%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.02gCO2e
# CPU [0.99% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.33gCO2e
# CPU [3.86% | 15.99%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [3.69% | 5.68%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.47gCO2e
# CPU [15.66% | 40.43%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.60gCO2e
# CPU [16.69% | 69.21%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.20gCO2e
# CPU [43.92% | 38.98%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.78gCO2e
# CPU [2.56% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.59gCO2e
# CPU [2.58% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.79gCO2e
# CPU [2.76% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [1.31% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.54gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [1.75% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 4.91gCO2e
# CPU [23.02% | 36.90%] Memory
# Reserved Memory Energy Consumption: 0.02kWh
# Reserved Memory Carbon Emissions: 5.92gCO2e
# CPU [23.45% | 63.59%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 2.12gCO2e
# CPU [56.37% | 30.33%] Memory
# Reserved Memory Energy Consumption: 0.04kWh
# Reserved Memory Carbon Emissions: 14.71gCO2e
# CPU [3.31% | 29.01%] Memory
# Reserved Memory Energy Consumption: 0.03kWh
# Reserved Memory Carbon Emissions: 12.93gCO2e
# CPU [3.34% | 26.40%] Memory
# Reserved Memory Energy Consumption: 0.04kWh
# Reserved Memory Carbon Emissions: 15.16gCO2e
# CPU [3.46% | 27.50%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.69gCO2e
# CPU [1.45% | 1.09%] Memory
# Reserved Memory Energy Consumption: 0.02kWh
# Reserved Memory Carbon Emissions: 6.67gCO2e
# CPU [2.07% | 16.29%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.67gCO2e
# CPU [2.32% | 5.77%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.37gCO2e
# CPU [15.62% | 40.44%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.48gCO2e
# CPU [16.61% | 69.27%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.18gCO2e
# CPU [43.62% | 39.19%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.65gCO2e
# CPU [2.54% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.47gCO2e
# CPU [2.56% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.67gCO2e
# CPU [2.74% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [1.30% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.51gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [1.74% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.28gCO2e
# CPU [30.56% | 33.28%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.37gCO2e
# CPU [32.31% | 56.23%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.08gCO2e
# CPU [55.09% | 31.22%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.61gCO2e
# CPU [3.60% | 28.93%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.70gCO2e
# CPU [3.17% | 26.45%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.96gCO2e
# CPU [3.27% | 27.55%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.02gCO2e
# CPU [0.99% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.33gCO2e
# CPU [3.86% | 15.99%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [3.69% | 5.68%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.46gCO2e
# CPU [15.66% | 40.43%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.58gCO2e
# CPU [16.69% | 69.21%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.20gCO2e
# CPU [43.92% | 38.98%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.74gCO2e
# CPU [2.56% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.56gCO2e
# CPU [2.58% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.75gCO2e
# CPU [2.76% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [1.31% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.53gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [1.75% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 4.80gCO2e
# CPU [23.02% | 36.90%] Memory
# Reserved Memory Energy Consumption: 0.02kWh
# Reserved Memory Carbon Emissions: 5.82gCO2e
# CPU [23.45% | 63.59%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 2.12gCO2e
# CPU [56.37% | 30.33%] Memory
# Reserved Memory Energy Consumption: 0.04kWh
# Reserved Memory Carbon Emissions: 14.49gCO2e
# CPU [3.31% | 29.01%] Memory
# Reserved Memory Energy Consumption: 0.03kWh
# Reserved Memory Carbon Emissions: 12.74gCO2e
# CPU [3.34% | 26.40%] Memory
# Reserved Memory Energy Consumption: 0.04kWh
# Reserved Memory Carbon Emissions: 14.97gCO2e
# CPU [3.46% | 27.50%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.67gCO2e
# CPU [1.45% | 1.09%] Memory
# Reserved Memory Energy Consumption: 0.02kWh
# Reserved Memory Carbon Emissions: 6.52gCO2e
# CPU [2.07% | 16.29%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.65gCO2e
# CPU [2.32% | 5.77%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.38gCO2e
# CPU [15.62% | 40.44%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.49gCO2e
# CPU [16.61% | 69.27%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.19gCO2e
# CPU [43.62% | 39.19%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.68gCO2e
# CPU [2.54% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.50gCO2e
# CPU [2.56% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.71gCO2e
# CPU [2.74% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [1.30% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.52gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [1.74% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.28gCO2e
# CPU [30.56% | 33.28%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.37gCO2e
# CPU [32.31% | 56.23%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.08gCO2e
# CPU [55.09% | 31.22%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.62gCO2e
# CPU [3.60% | 28.93%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.72gCO2e
# CPU [3.17% | 26.45%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.98gCO2e
# CPU [3.27% | 27.55%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.02gCO2e
# CPU [0.99% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.33gCO2e
# CPU [3.86% | 15.99%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [3.69% | 5.68%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.47gCO2e
# CPU [15.66% | 40.43%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.60gCO2e
# CPU [16.69% | 69.21%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.20gCO2e
# CPU [43.92% | 38.98%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.78gCO2e
# CPU [2.56% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.59gCO2e
# CPU [2.58% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.79gCO2e
# CPU [2.76% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [1.31% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.54gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [1.75% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 4.91gCO2e
# CPU [23.02% | 36.90%] Memory
# Reserved Memory Energy Consumption: 0.02kWh
# Reserved Memory Carbon Emissions: 5.92gCO2e
# CPU [23.45% | 63.59%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 2.12gCO2e
# CPU [56.37% | 30.33%] Memory
# Reserved Memory Energy Consumption: 0.04kWh
# Reserved Memory Carbon Emissions: 14.71gCO2e
# CPU [3.31% | 29.01%] Memory
# Reserved Memory Energy Consumption: 0.03kWh
# Reserved Memory Carbon Emissions: 12.93gCO2e
# CPU [3.34% | 26.40%] Memory
# Reserved Memory Energy Consumption: 0.04kWh
# Reserved Memory Carbon Emissions: 15.16gCO2e
# CPU [3.46% | 27.50%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.69gCO2e
# CPU [1.45% | 1.09%] Memory
# Reserved Memory Energy Consumption: 0.02kWh
# Reserved Memory Carbon Emissions: 6.67gCO2e
# CPU [2.07% | 16.29%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.67gCO2e
# CPU [2.32% | 5.77%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.38gCO2e
# CPU [15.62% | 40.44%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.49gCO2e
# CPU [16.61% | 69.27%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.19gCO2e
# CPU [43.62% | 39.19%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.68gCO2e
# CPU [2.54% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.50gCO2e
# CPU [2.56% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.71gCO2e
# CPU [2.74% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [1.30% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.52gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [1.74% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.28gCO2e
# CPU [30.56% | 33.28%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.37gCO2e
# CPU [32.31% | 56.23%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.08gCO2e
# CPU [55.09% | 31.22%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.62gCO2e
# CPU [3.60% | 28.93%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.72gCO2e
# CPU [3.17% | 26.45%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.98gCO2e
# CPU [3.27% | 27.55%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.02gCO2e
# CPU [0.99% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.33gCO2e
# CPU [3.86% | 15.99%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [3.69% | 5.68%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.47gCO2e
# CPU [15.66% | 40.43%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.60gCO2e
# CPU [16.69% | 69.21%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.20gCO2e
# CPU [43.92% | 38.98%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.78gCO2e
# CPU [2.56% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.59gCO2e
# CPU [2.58% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.79gCO2e
# CPU [2.76% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [1.31% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.54gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [1.75% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 4.48gCO2e
# CPU [23.02% | 36.90%] Memory
# Reserved Memory Energy Consumption: 0.02kWh
# Reserved Memory Carbon Emissions: 5.46gCO2e
# CPU [23.45% | 63.59%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 2.02gCO2e
# CPU [56.37% | 30.33%] Memory
# Reserved Memory Energy Consumption: 0.04kWh
# Reserved Memory Carbon Emissions: 13.67gCO2e
# CPU [3.31% | 29.01%] Memory
# Reserved Memory Energy Consumption: 0.03kWh
# Reserved Memory Carbon Emissions: 12.02gCO2e
# CPU [3.34% | 26.40%] Memory
# Reserved Memory Energy Consumption: 0.04kWh
# Reserved Memory Carbon Emissions: 14.13gCO2e
# CPU [3.46% | 27.50%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.65gCO2e
# CPU [1.45% | 1.09%] Memory
# Reserved Memory Energy Consumption: 0.02kWh
# Reserved Memory Carbon Emissions: 6.10gCO2e
# CPU [2.07% | 16.29%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.61gCO2e
# CPU [2.32% | 5.77%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.38gCO2e
# CPU [15.62% | 40.44%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.49gCO2e
# CPU [16.61% | 69.27%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.19gCO2e
# CPU [43.62% | 39.19%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.68gCO2e
# CPU [2.54% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.50gCO2e
# CPU [2.56% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.71gCO2e
# CPU [2.74% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [1.30% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.52gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [1.74% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.28gCO2e
# CPU [30.56% | 33.28%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.37gCO2e
# CPU [32.31% | 56.23%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.08gCO2e
# CPU [55.09% | 31.22%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.62gCO2e
# CPU [3.60% | 28.93%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.72gCO2e
# CPU [3.17% | 26.45%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.98gCO2e
# CPU [3.27% | 27.55%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.02gCO2e
# CPU [0.99% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.33gCO2e
# CPU [3.86% | 15.99%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [3.69% | 5.68%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.47gCO2e
# CPU [15.66% | 40.43%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.60gCO2e
# CPU [16.69% | 69.21%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.20gCO2e
# CPU [43.92% | 38.98%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.78gCO2e
# CPU [2.56% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.59gCO2e
# CPU [2.58% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.79gCO2e
# CPU [2.76% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [1.31% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.54gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [1.75% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 4.80gCO2e
# CPU [23.02% | 36.90%] Memory
# Reserved Memory Energy Consumption: 0.02kWh
# Reserved Memory Carbon Emissions: 5.82gCO2e
# CPU [23.45% | 63.59%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 2.10gCO2e
# CPU [56.37% | 30.33%] Memory
# Reserved Memory Energy Consumption: 0.04kWh
# Reserved Memory Carbon Emissions: 14.49gCO2e
# CPU [3.31% | 29.01%] Memory
# Reserved Memory Energy Consumption: 0.03kWh
# Reserved Memory Carbon Emissions: 12.74gCO2e
# CPU [3.34% | 26.40%] Memory
# Reserved Memory Energy Consumption: 0.04kWh
# Reserved Memory Carbon Emissions: 14.95gCO2e
# CPU [3.46% | 27.50%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.67gCO2e
# CPU [1.45% | 1.09%] Memory
# Reserved Memory Energy Consumption: 0.02kWh
# Reserved Memory Carbon Emissions: 6.52gCO2e
# CPU [2.07% | 16.29%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.65gCO2e
# CPU [2.32% | 5.77%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.36gCO2e
# CPU [15.62% | 40.44%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.47gCO2e
# CPU [16.61% | 69.27%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.18gCO2e
# CPU [43.62% | 39.19%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.60gCO2e
# CPU [2.54% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.43gCO2e
# CPU [2.56% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.63gCO2e
# CPU [2.74% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [1.30% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.50gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [1.74% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.28gCO2e
# CPU [30.56% | 33.28%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.37gCO2e
# CPU [32.31% | 56.23%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.08gCO2e
# CPU [55.09% | 31.22%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.62gCO2e
# CPU [3.60% | 28.93%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.72gCO2e
# CPU [3.17% | 26.45%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.98gCO2e
# CPU [3.27% | 27.55%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.02gCO2e
# CPU [0.99% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.33gCO2e
# CPU [3.86% | 15.99%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [3.69% | 5.68%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.53gCO2e
# CPU [15.66% | 40.43%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.67gCO2e
# CPU [16.69% | 69.21%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.22gCO2e
# CPU [43.92% | 38.98%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.99gCO2e
# CPU [2.56% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.78gCO2e
# CPU [2.58% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.99gCO2e
# CPU [2.76% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [1.31% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.60gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.06gCO2e
# CPU [1.75% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 5.64gCO2e
# CPU [23.02% | 36.90%] Memory
# Reserved Memory Energy Consumption: 0.02kWh
# Reserved Memory Carbon Emissions: 6.84gCO2e
# CPU [23.45% | 63.59%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 2.47gCO2e
# CPU [56.37% | 30.33%] Memory
# Reserved Memory Energy Consumption: 0.04kWh
# Reserved Memory Carbon Emissions: 17.03gCO2e
# CPU [3.31% | 29.01%] Memory
# Reserved Memory Energy Consumption: 0.03kWh
# Reserved Memory Carbon Emissions: 14.98gCO2e
# CPU [3.34% | 26.40%] Memory
# Reserved Memory Energy Consumption: 0.04kWh
# Reserved Memory Carbon Emissions: 17.57gCO2e
# CPU [3.46% | 27.50%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.78gCO2e
# CPU [1.45% | 1.09%] Memory
# Reserved Memory Energy Consumption: 0.02kWh
# Reserved Memory Carbon Emissions: 7.66gCO2e
# CPU [2.07% | 16.29%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.77gCO2e
# CPU [2.32% | 5.77%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.39gCO2e
# CPU [15.62% | 40.44%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.51gCO2e
# CPU [16.61% | 69.27%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.20gCO2e
# CPU [43.62% | 39.19%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.74gCO2e
# CPU [2.54% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.56gCO2e
# CPU [2.56% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.77gCO2e
# CPU [2.74% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [1.30% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.54gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [1.74% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.33gCO2e
# CPU [30.56% | 33.28%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.44gCO2e
# CPU [32.31% | 56.23%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.09gCO2e
# CPU [55.09% | 31.22%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.73gCO2e
# CPU [3.60% | 28.93%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.84gCO2e
# CPU [3.17% | 26.45%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.14gCO2e
# CPU [3.27% | 27.55%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.03gCO2e
# CPU [0.99% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.39gCO2e
# CPU [3.86% | 15.99%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [3.69% | 5.68%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.53gCO2e
# CPU [15.66% | 40.43%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.68gCO2e
# CPU [16.69% | 69.21%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.23gCO2e
# CPU [43.92% | 38.98%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 2.02gCO2e
# CPU [2.56% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.81gCO2e
# CPU [2.58% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 2.02gCO2e
# CPU [2.76% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [1.31% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.61gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.06gCO2e
# CPU [1.75% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 5.96gCO2e
# CPU [23.02% | 36.90%] Memory
# Reserved Memory Energy Consumption: 0.02kWh
# Reserved Memory Carbon Emissions: 7.22gCO2e
# CPU [23.45% | 63.59%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 2.60gCO2e
# CPU [56.37% | 30.33%] Memory
# Reserved Memory Energy Consumption: 0.04kWh
# Reserved Memory Carbon Emissions: 17.98gCO2e
# CPU [3.31% | 29.01%] Memory
# Reserved Memory Energy Consumption: 0.03kWh
# Reserved Memory Carbon Emissions: 15.81gCO2e
# CPU [3.34% | 26.40%] Memory
# Reserved Memory Energy Consumption: 0.04kWh
# Reserved Memory Carbon Emissions: 18.55gCO2e
# CPU [3.46% | 27.50%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.79gCO2e
# CPU [1.45% | 1.09%] Memory
# Reserved Memory Energy Consumption: 0.02kWh
# Reserved Memory Carbon Emissions: 8.09gCO2e
# CPU [2.07% | 16.29%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.81gCO2e
# CPU [2.32% | 5.77%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.41gCO2e
# CPU [15.62% | 40.44%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.53gCO2e
# CPU [16.61% | 69.27%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.20gCO2e
# CPU [43.62% | 39.19%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.81gCO2e
# CPU [2.54% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.62gCO2e
# CPU [2.56% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.85gCO2e
# CPU [2.74% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.06gCO2e
# CPU [1.30% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.56gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.04gCO2e
# CPU [1.74% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.29gCO2e
# CPU [30.56% | 33.28%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.38gCO2e
# CPU [32.31% | 56.23%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.08gCO2e
# CPU [55.09% | 31.22%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.64gCO2e
# CPU [3.60% | 28.93%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.73gCO2e
# CPU [3.17% | 26.45%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.00gCO2e
# CPU [3.27% | 27.55%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.03gCO2e
# CPU [0.99% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.34gCO2e
# CPU [3.86% | 15.99%] Memory
# ...
# CPU [1.30% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.01gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.08gCO2e
# CPU [1.74% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.55gCO2e
# CPU [30.56% | 33.28%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.73gCO2e
# CPU [32.31% | 56.23%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.15gCO2e
# CPU [55.09% | 31.22%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.22gCO2e
# CPU [3.60% | 28.93%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.40gCO2e
# CPU [3.17% | 26.45%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.90gCO2e
# CPU [3.27% | 27.55%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [0.99% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.65gCO2e
# CPU [3.86% | 15.99%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.07gCO2e
# CPU [3.69% | 5.68%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.00gCO2e
# CPU [15.66% | 40.43%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.26gCO2e
# CPU [16.69% | 69.21%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.42gCO2e
# CPU [43.92% | 38.98%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 3.76gCO2e
# CPU [2.56% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 3.36gCO2e
# CPU [2.58% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 3.77gCO2e
# CPU [2.76% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.08gCO2e
# CPU [1.31% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.14gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.11gCO2e
# CPU [1.75% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 10.24gCO2e
# CPU [23.02% | 36.90%] Memory
# Reserved Memory Energy Consumption: 0.02kWh
# Reserved Memory Carbon Emissions: 12.37gCO2e
# CPU [23.45% | 63.59%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 4.44gCO2e
# CPU [56.37% | 30.33%] Memory
# Reserved Memory Energy Consumption: 0.04kWh
# Reserved Memory Carbon Emissions: 30.77gCO2e
# CPU [3.31% | 29.01%] Memory
# Reserved Memory Energy Consumption: 0.03kWh
# Reserved Memory Carbon Emissions: 27.05gCO2e
# CPU [3.34% | 26.40%] Memory
# Reserved Memory Energy Consumption: 0.04kWh
# Reserved Memory Carbon Emissions: 31.73gCO2e
# CPU [3.46% | 27.50%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.41gCO2e
# CPU [1.45% | 1.09%] Memory
# Reserved Memory Energy Consumption: 0.02kWh
# Reserved Memory Carbon Emissions: 13.90gCO2e
# CPU [2.07% | 16.29%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.39gCO2e
# CPU [2.32% | 5.77%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.77gCO2e
# CPU [15.62% | 40.44%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.00gCO2e
# CPU [16.61% | 69.27%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.38gCO2e
# CPU [43.62% | 39.19%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 3.42gCO2e
# CPU [2.54% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 3.06gCO2e
# CPU [2.56% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 3.48gCO2e
# CPU [2.74% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.11gCO2e
# CPU [1.30% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.06gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.08gCO2e
# CPU [1.74% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.58gCO2e
# CPU [30.56% | 33.28%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.77gCO2e
# CPU [32.31% | 56.23%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.16gCO2e
# CPU [55.09% | 31.22%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.29gCO2e
# CPU [3.60% | 28.93%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.48gCO2e
# CPU [3.17% | 26.45%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 2.02gCO2e
# CPU [3.27% | 27.55%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [0.99% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.69gCO2e
# CPU [3.86% | 15.99%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.08gCO2e
# CPU [3.69% | 5.68%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.99gCO2e
# CPU [15.66% | 40.43%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.25gCO2e
# CPU [16.69% | 69.21%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.42gCO2e
# CPU [43.92% | 38.98%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 3.73gCO2e
# CPU [2.56% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 3.34gCO2e
# CPU [2.58% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 3.75gCO2e
# CPU [2.76% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.08gCO2e
# CPU [1.31% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.13gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.11gCO2e
# CPU [1.75% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 10.00gCO2e
# CPU [23.02% | 36.90%] Memory
# Reserved Memory Energy Consumption: 0.02kWh
# Reserved Memory Carbon Emissions: 12.14gCO2e
# CPU [23.45% | 63.59%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 4.39gCO2e
# CPU [56.37% | 30.33%] Memory
# Reserved Memory Energy Consumption: 0.04kWh
# Reserved Memory Carbon Emissions: 30.29gCO2e
# CPU [3.31% | 29.01%] Memory
# Reserved Memory Energy Consumption: 0.03kWh
# Reserved Memory Carbon Emissions: 26.63gCO2e
# CPU [3.34% | 26.40%] Memory
# Reserved Memory Energy Consumption: 0.04kWh
# Reserved Memory Carbon Emissions: 31.26gCO2e
# CPU [3.46% | 27.50%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.40gCO2e
# CPU [1.45% | 1.09%] Memory
# Reserved Memory Energy Consumption: 0.02kWh
# Reserved Memory Carbon Emissions: 13.58gCO2e
# CPU [2.07% | 16.29%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.36gCO2e
# CPU [2.32% | 5.77%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.79gCO2e
# CPU [15.62% | 40.44%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.01gCO2e
# CPU [16.61% | 69.27%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.39gCO2e
# CPU [43.62% | 39.19%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 3.47gCO2e
# CPU [2.54% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 3.10gCO2e
# CPU [2.56% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 3.53gCO2e
# CPU [2.74% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.11gCO2e
# CPU [1.30% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.07gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.08gCO2e
# CPU [1.74% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.59gCO2e
# CPU [30.56% | 33.28%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.78gCO2e
# CPU [32.31% | 56.23%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.16gCO2e
# CPU [55.09% | 31.22%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.30gCO2e
# CPU [3.60% | 28.93%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.50gCO2e
# CPU [3.17% | 26.45%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 2.04gCO2e
# CPU [3.27% | 27.55%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [0.99% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.70gCO2e
# CPU [3.86% | 15.99%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.08gCO2e
# CPU [3.69% | 5.68%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.98gCO2e
# CPU [15.66% | 40.43%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.24gCO2e
# CPU [16.69% | 69.21%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.42gCO2e
# CPU [43.92% | 38.98%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 3.71gCO2e
# CPU [2.56% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 3.32gCO2e
# CPU [2.58% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 3.72gCO2e
# CPU [2.76% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.08gCO2e
# CPU [1.31% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.12gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.11gCO2e
# CPU [1.75% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 10.40gCO2e
# CPU [23.02% | 36.90%] Memory
# Reserved Memory Energy Consumption: 0.02kWh
# Reserved Memory Carbon Emissions: 12.70gCO2e
# CPU [23.45% | 63.59%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 4.64gCO2e
# CPU [56.37% | 30.33%] Memory
# Reserved Memory Energy Consumption: 0.04kWh
# Reserved Memory Carbon Emissions: 31.81gCO2e
# CPU [3.31% | 29.01%] Memory
# Reserved Memory Energy Consumption: 0.03kWh
# Reserved Memory Carbon Emissions: 27.96gCO2e
# CPU [3.34% | 26.40%] Memory
# Reserved Memory Energy Consumption: 0.04kWh
# Reserved Memory Carbon Emissions: 32.86gCO2e
# CPU [3.46% | 27.50%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.44gCO2e
# CPU [1.45% | 1.09%] Memory
# Reserved Memory Energy Consumption: 0.02kWh
# Reserved Memory Carbon Emissions: 14.11gCO2e
# CPU [2.07% | 16.29%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.41gCO2e
# CPU [2.32% | 5.77%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.71gCO2e
# CPU [15.62% | 40.44%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.92gCO2e
# CPU [16.61% | 69.27%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.35gCO2e
# CPU [43.62% | 39.19%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 3.14gCO2e
# CPU [2.54% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 2.81gCO2e
# CPU [2.56% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 3.20gCO2e
# CPU [2.74% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.10gCO2e
# CPU [1.30% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.97gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.07gCO2e
# CPU [1.74% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.57gCO2e
# CPU [30.56% | 33.28%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.76gCO2e
# CPU [32.31% | 56.23%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.16gCO2e
# CPU [55.09% | 31.22%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.27gCO2e
# CPU [3.60% | 28.93%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.46gCO2e
# CPU [3.17% | 26.45%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.99gCO2e
# CPU [3.27% | 27.55%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.05gCO2e
# CPU [0.99% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.68gCO2e
# CPU [3.86% | 15.99%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.08gCO2e
# CPU [3.69% | 5.68%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.96gCO2e
# CPU [15.66% | 40.43%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.22gCO2e
# CPU [16.69% | 69.21%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.41gCO2e
# CPU [43.92% | 38.98%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 3.63gCO2e
# CPU [2.56% | 29.24%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 3.25gCO2e
# CPU [2.58% | 26.61%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 3.64gCO2e
# CPU [2.76% | 27.70%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.07gCO2e
# CPU [1.31% | 1.10%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.10gCO2e
# CPU [1.82% | 16.33%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 0.11gCO2e
# CPU [1.75% | 5.80%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 10.34gCO2e
# CPU [23.02% | 36.90%] Memory
# Reserved Memory Energy Consumption: 0.02kWh
# Reserved Memory Carbon Emissions: 12.53gCO2e
# CPU [23.45% | 63.59%] Memory
# Reserved Memory Energy Consumption: 0.01kWh
# Reserved Memory Carbon Emissions: 4.52gCO2e
# CPU [56.37% | 30.33%] Memory
# Reserved Memory Energy Consumption: 0.04kWh
# Reserved Memory Carbon Emissions: 31.22gCO2e
# CPU [3.31% | 29.01%] Memory
# Reserved Memory Energy Consumption: 0.03kWh
# Reserved Memory Carbon Emissions: 27.45gCO2e
# CPU [3.34% | 26.40%] Memory
# Reserved Memory Energy Consumption: 0.04kWh
# Reserved Memory Carbon Emissions: 32.21gCO2e
# CPU [3.46% | 27.50%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.41gCO2e
# CPU [1.45% | 1.09%] Memory
# Reserved Memory Energy Consumption: 0.02kWh
# Reserved Memory Carbon Emissions: 14.04gCO2e
# CPU [2.07% | 16.29%] Memory
# Reserved Memory Energy Consumption: 0.00kWh
# Reserved Memory Carbon Emissions: 1.41gCO2e
# CPU [2.32% | 5.77%] Memory

# %%
def print_stats_for_month(month, all_data_avg, all_data_marg, task_runtimes):
    headers = ['task', 'machine', 'runtime (h)', 'energy consumption (kWh)', 'average emissions (gCO2e)', 'marginal emissions (gCO2e)']
    table_data = []

    for region in short_regions:
        for task in tasks:
            for machine in machines:
                curr = task_stats_avg[region][month][task][machine]
                curr_energy = round(curr[ENERGY_CONSUMPTION] + curr[MEMORY_CONSUMPTION] + curr[RES_MEM_ENERGY_CONSUMPTION], 3)
                curr_emissions = round(curr[CARBON_EMISSIONS], 2)
                # curr_emb_emissions = round(curr[EMBODIED_CARBON_EMISSIONS], 2)
                curr_runtime = round(task_runtimes[task][machine], 2)
                curr_marg = task_stats_marg[region][month][task][machine]
                # curr_marg_energy = round(curr_marg[ENERGY_CONSUMPTION] + curr_marg[MEMORY_CONSUMPTION], 2)
                curr_marg_emissions = round(curr_marg[CARBON_EMISSIONS], 2)
                # curr_marg_emb_emissions = round(curr_marg[EMBODIED_CARBON_EMISSIONS], 2)

                table_data.append([task, machine, curr_runtime, curr_energy, curr_emissions, curr_marg_emissions])

    print("Comparison of Tasks @ Varied Frequencies using Average CI Data")
    print(tabulate(table_data, headers, tablefmt='orgtbl'))

    return table_data

# %%
def get_runtime(filename):
    with open(filename, 'r') as f:
        lines = f.readlines()

    parts = lines[1].split(',')
    return int(parts[19])

all_task_runtimes = {}

for task in tasks:
    all_task_runtimes[task] = {}
    for machine, exp_machine in zip(machines, exp_machines):
        filebase = f'../data/traces/tasks/{task}/{exp_machine}-{task}-ITER.csv'
        runtime_1 = get_runtime(filebase.replace('ITER', '1'))
        runtime_2 = get_runtime(filebase.replace('ITER', '2'))
        runtime_3 = get_runtime(filebase.replace('ITER', '3'))
        avg_runtime = (runtime_1 + runtime_2 + runtime_3) / 3
        all_task_runtimes[task][machine] = avg_runtime / 1000 / 3600

# %%
all_ra_data = {}

for month in short_months:
    print('\n' + month)
    month_data = print_stats_for_month(month, task_stats_avg, task_stats_marg, all_task_runtimes)

    for row in month_data:
        c_task = row[0]
        c_mach = row[1]

        if c_task in all_ra_data:
            if c_mach in all_ra_data[c_task]: 
                all_ra_data[c_task][c_mach]['avg emissions'].append(row[4])
                all_ra_data[c_task][c_mach]['marg emissions'].append(row[5])
            else: 
                all_ra_data[c_task][c_mach] = {
                    'runtime': row[2],
                    'energy': row[3],
                    'avg emissions': [row[4]],
                    'marg emissions': [row[5]]
                }
        else:
            all_ra_data[c_task] = {} 
            all_ra_data[c_task][c_mach] = {
                    'runtime': row[2],
                    'energy': row[3],
                    'avg emissions': [row[4]],
                    'marg emissions': [row[5]]
                }
# Out:
# jan
# Comparison of Tasks @ Varied Frequencies using Average CI Data
# | task          | machine   |   runtime (h) |   energy consumption (kWh) |   average emissions (gCO2e) |   marginal emissions (gCO2e) |
# |---------------+-----------+---------------+----------------------------+-----------------------------+------------------------------|
# | bowtie2_build | gcpc2     |          0.16 |                      0.005 |                        1.15 |                         1.17 |
# | bowtie2_build | gcpn2     |          0.18 |                      0.003 |                        0.76 |                         0.88 |
# | bowtie2_build | gcpn1     |          0.25 |                      0.002 |                        0.43 |                         0.6  |
# | bowtie2_build | gpg13     |          0.25 |                      0.022 |                        5.1  |                         7.17 |
# | bowtie2_build | gpg14     |          0.25 |                      0.022 |                        5    |                         7.04 |
# | bowtie2_build | gpg15     |          0.25 |                      0.024 |                        5.44 |                         7.7  |
# | bowtie2_build | gpg22     |          0.15 |                      0.029 |                        6.6  |                         6    |
# | bowtie2_build | hu26      |          0.16 |                      0.017 |                        3.92 |                         3.98 |
# | bowtie2_build | server    |          0.14 |                      0.004 |                        1    |                         0.83 |
# | fastp         | gcpc2     |          0.06 |                      0.002 |                        0.46 |                         1.06 |
# | fastp         | gcpn2     |          0.08 |                      0.002 |                        0.36 |                         0.84 |
# | fastp         | gcpn1     |          0.15 |                      0.001 |                        0.3  |                         0.29 |
# | fastp         | gpg13     |          0.14 |                      0.013 |                        2.78 |                         2.55 |
# | fastp         | gpg14     |          0.16 |                      0.014 |                        3.04 |                         3.21 |
# | fastp         | gpg15     |          0.17 |                      0.017 |                        3.61 |                         4.18 |
# | fastp         | gpg22     |          0.11 |                      0.022 |                        4.71 |                         2.69 |
# | fastp         | hu26      |          0.05 |                      0.005 |                        1.14 |                         2.63 |
# | fastp         | server    |          0.05 |                      0.002 |                        0.36 |                         0.84 |
# | fastqc        | gcpc2     |          0.18 |                      0.006 |                        1.15 |                         1.47 |
# | fastqc        | gcpn2     |          0.21 |                      0.004 |                        0.77 |                         1.09 |
# | fastqc        | gcpn1     |          0.26 |                      0.002 |                        0.4  |                         0.65 |
# | fastqc        | gpg13     |          0.26 |                      0.023 |                        4.76 |                         7.67 |
# | fastqc        | gpg14     |          0.26 |                      0.023 |                        4.67 |                         7.54 |
# | fastqc        | gpg15     |          0.26 |                      0.025 |                        5.03 |                         8.12 |
# | fastqc        | gpg22     |          0.13 |                      0.025 |                        5.11 |                         4.14 |
# | fastqc        | hu26      |          0.16 |                      0.017 |                        3.58 |                         4.16 |
# | fastqc        | server    |          0.16 |                      0.005 |                        1.02 |                         1.13 |
# | trimgalore    | gcpc2     |          1.07 |                      0.002 |                        0.53 |                        15.75 |
# | trimgalore    | gcpn2     |          1.28 |                      0.006 |                        1.19 |                        11.16 |
# | trimgalore    | gcpn1     |          1.93 |                      0.009 |                        1.92 |                         8.53 |
# | trimgalore    | gpg13     |          1.5  |                      0.046 |                        9.78 |                        61.24 |
# | trimgalore    | gpg14     |          1.49 |                      0.044 |                        9.3  |                        59.16 |
# | trimgalore    | gpg15     |          1.56 |                      0.053 |                       11.34 |                        66.73 |
# | trimgalore    | gpg22     |          0.86 |                      0.17  |                       36.14 |                        75.3  |
# | trimgalore    | hu26      |          1.05 |                      0.005 |                        1.07 |                        48.41 |
# | trimgalore    | server    |          1    |                      0.021 |                        4.47 |                        13.68 |
# | bowtie2_build | gcpc2     |          0.16 |                      0.005 |                        2.39 |                         1.88 |
# | bowtie2_build | gcpn2     |          0.18 |                      0.003 |                        1.59 |                         1.41 |
# | bowtie2_build | gcpn1     |          0.25 |                      0.002 |                        0.89 |                         0.96 |
# | bowtie2_build | gpg13     |          0.25 |                      0.022 |                       10.65 |                        11.48 |
# | bowtie2_build | gpg14     |          0.25 |                      0.022 |                       10.44 |                        11.28 |
# | bowtie2_build | gpg15     |          0.25 |                      0.024 |                       11.36 |                        12.33 |
# | bowtie2_build | gpg22     |          0.15 |                      0.029 |                       13.78 |                         9.61 |
# | bowtie2_build | hu26      |          0.16 |                      0.017 |                        8.18 |                         6.37 |
# | bowtie2_build | server    |          0.14 |                      0.004 |                        2.09 |                         1.34 |
# | fastp         | gcpc2     |          0.06 |                      0.002 |                        1    |                         1.58 |
# | fastp         | gcpn2     |          0.08 |                      0.002 |                        0.79 |                         1.25 |
# | fastp         | gcpn1     |          0.15 |                      0.001 |                        0.65 |                         0.46 |
# | fastp         | gpg13     |          0.14 |                      0.013 |                        6.04 |                         4.02 |
# | fastp         | gpg14     |          0.16 |                      0.014 |                        6.59 |                         5.06 |
# | fastp         | gpg15     |          0.17 |                      0.017 |                        7.83 |                         6.6  |
# | fastp         | gpg22     |          0.11 |                      0.022 |                       10.24 |                         4.24 |
# | fastp         | hu26      |          0.05 |                      0.005 |                        2.48 |                         3.92 |
# | fastp         | server    |          0.05 |                      0.002 |                        0.79 |                         1.25 |
# | fastqc        | gcpc2     |          0.18 |                      0.006 |                        2.58 |                         2.2  |
# | fastqc        | gcpn2     |          0.21 |                      0.004 |                        1.73 |                         1.62 |
# | fastqc        | gcpn1     |          0.26 |                      0.002 |                        0.9  |                         0.96 |
# | fastqc        | gpg13     |          0.26 |                      0.023 |                       10.73 |                        11.45 |
# | fastqc        | gpg14     |          0.26 |                      0.023 |                       10.52 |                        11.26 |
# | fastqc        | gpg15     |          0.26 |                      0.025 |                       11.33 |                        12.13 |
# | fastqc        | gpg22     |          0.13 |                      0.025 |                       11.53 |                         6.18 |
# | fastqc        | hu26      |          0.16 |                      0.017 |                        8.06 |                         6.21 |
# | fastqc        | server    |          0.16 |                      0.005 |                        2.3  |                         1.69 |
# | trimgalore    | gcpc2     |          1.07 |                      0.002 |                        1.2  |                        25.31 |
# | trimgalore    | gcpn2     |          1.28 |                      0.006 |                        2.7  |                        17.84 |
# | trimgalore    | gcpn1     |          1.93 |                      0.009 |                        4.34 |                        13.53 |
# | trimgalore    | gpg13     |          1.5  |                      0.046 |                       22.12 |                        97.48 |
# | trimgalore    | gpg14     |          1.49 |                      0.044 |                       21.02 |                        94.19 |
# | trimgalore    | gpg15     |          1.56 |                      0.053 |                       25.64 |                       106.14 |
# | trimgalore    | gpg22     |          0.86 |                      0.17  |                       81.93 |                       117.92 |
# | trimgalore    | hu26      |          1.05 |                      0.005 |                        2.41 |                        77.85 |
# | trimgalore    | server    |          1    |                      0.021 |                       10.35 |                        22.01 |
# | bowtie2_build | gcpc2     |          0.16 |                      0.005 |                        1.53 |                         1.07 |
# | bowtie2_build | gcpn2     |          0.18 |                      0.003 |                        1.02 |                         0.81 |
# | bowtie2_build | gcpn1     |          0.25 |                      0.002 |                        0.57 |                         0.55 |
# | bowtie2_build | gpg13     |          0.25 |                      0.022 |                        6.84 |                         6.57 |
# | bowtie2_build | gpg14     |          0.25 |                      0.022 |                        6.7  |                         6.45 |
# | bowtie2_build | gpg15     |          0.25 |                      0.024 |                        7.29 |                         7.05 |
# | bowtie2_build | gpg22     |          0.15 |                      0.029 |                        8.85 |                         5.49 |
# | bowtie2_build | hu26      |          0.16 |                      0.017 |                        5.25 |                         3.64 |
# | bowtie2_build | server    |          0.14 |                      0.004 |                        1.34 |                         0.76 |
# | fastp         | gcpc2     |          0.06 |                      0.002 |                        0.67 |                         0.96 |
# | fastp         | gcpn2     |          0.08 |                      0.002 |                        0.53 |                         0.76 |
# | fastp         | gcpn1     |          0.15 |                      0.001 |                        0.44 |                         0.28 |
# | fastp         | gpg13     |          0.14 |                      0.013 |                        4.03 |                         2.46 |
# | fastp         | gpg14     |          0.16 |                      0.014 |                        4.41 |                         3.09 |
# | fastp         | gpg15     |          0.17 |                      0.017 |                        5.23 |                         4.03 |
# | fastp         | gpg22     |          0.11 |                      0.022 |                        6.84 |                         2.59 |
# | fastp         | hu26      |          0.05 |                      0.005 |                        1.66 |                         2.38 |
# | fastp         | server    |          0.05 |                      0.002 |                        0.53 |                         0.76 |
# | fastqc        | gcpc2     |          0.18 |                      0.006 |                        1.67 |                         1.34 |
# | fastqc        | gcpn2     |          0.21 |                      0.004 |                        1.12 |                         0.99 |
# | fastqc        | gcpn1     |          0.26 |                      0.002 |                        0.58 |                         0.59 |
# | fastqc        | gpg13     |          0.26 |                      0.023 |                        6.94 |                         7    |
# | fastqc        | gpg14     |          0.26 |                      0.023 |                        6.81 |                         6.89 |
# | fastqc        | gpg15     |          0.26 |                      0.025 |                        7.33 |                         7.42 |
# | fastqc        | gpg22     |          0.13 |                      0.025 |                        7.46 |                         3.78 |
# | fastqc        | hu26      |          0.16 |                      0.017 |                        5.22 |                         3.8  |
# | fastqc        | server    |          0.16 |                      0.005 |                        1.49 |                         1.03 |
# | trimgalore    | gcpc2     |          1.07 |                      0.002 |                        0.53 |                        15.17 |
# | trimgalore    | gcpn2     |          1.28 |                      0.006 |                        1.19 |                        10.67 |
# | trimgalore    | gcpn1     |          1.93 |                      0.009 |                        1.91 |                         8.06 |
# | trimgalore    | gpg13     |          1.5  |                      0.046 |                        9.72 |                        58.2  |
# | trimgalore    | gpg14     |          1.49 |                      0.044 |                        9.24 |                        56.24 |
# | trimgalore    | gpg15     |          1.56 |                      0.053 |                       11.27 |                        63.35 |
# | trimgalore    | gpg22     |          0.86 |                      0.17  |                       48.33 |                        71.25 |
# | trimgalore    | hu26      |          1.05 |                      0.005 |                        1.06 |                        46.69 |
# | trimgalore    | server    |          1    |                      0.021 |                        5.79 |                        13.22 |
# | bowtie2_build | gcpc2     |          0.16 |                      0.005 |                        1.99 |                         1.22 |
# | bowtie2_build | gcpn2     |          0.18 |                      0.003 |                        1.33 |                         0.92 |
# | bowtie2_build | gcpn1     |          0.25 |                      0.002 |                        0.74 |                         0.63 |
# | bowtie2_build | gpg13     |          0.25 |                      0.022 |                        8.88 |                         7.48 |
# | bowtie2_build | gpg14     |          0.25 |                      0.022 |                        8.7  |                         7.35 |
# | bowtie2_build | gpg15     |          0.25 |                      0.024 |                        9.47 |                         8.03 |
# | bowtie2_build | gpg22     |          0.15 |                      0.029 |                       11.49 |                         6.26 |
# | bowtie2_build | hu26      |          0.16 |                      0.017 |                        6.82 |                         4.15 |
# | bowtie2_build | server    |          0.14 |                      0.004 |                        1
|
# | fastp         | hu26      |          0.05 |                      0.005 |                        3.24 |                         4.46 |
# | fastp         | server    |          0.05 |                      0.002 |                        1.04 |                         1.42 |
# | fastqc        | gcpc2     |          0.18 |                      0.006 |                        3.38 |                         2.51 |
# | fastqc        | gcpn2     |          0.21 |                      0.004 |                        2.26 |                         1.86 |
# | fastqc        | gcpn1     |          0.26 |                      0.002 |                        1.18 |                         1.1  |
# | fastqc        | gpg13     |          0.26 |                      0.023 |                       14.02 |                        13.11 |
# | fastqc        | gpg14     |          0.26 |                      0.023 |                       13.75 |                        12.89 |
# | fastqc        | gpg15     |          0.26 |                      0.025 |                       14.81 |                        13.88 |
# | fastqc        | gpg22     |          0.13 |                      0.025 |                       15.06 |                         7.08 |
# | fastqc        | hu26      |          0.16 |                      0.017 |                       10.53 |                         7.11 |
# | fastqc        | server    |          0.16 |                      0.005 |                        3    |                         1.94 |
# | trimgalore    | gcpc2     |          1.07 |                      0.002 |                        1.52 |                        29.48 |
# | trimgalore    | gcpn2     |          1.28 |                      0.006 |                        3.4  |                        20.73 |
# | trimgalore    | gcpn1     |          1.93 |                      0.009 |                        5.47 |                        15.66 |
# | trimgalore    | gpg13     |          1.5  |                      0.046 |                       27.88 |                       113.09 |
# | trimgalore    | gpg14     |          1.49 |                      0.044 |                       26.5  |                       109.28 |
# | trimgalore    | gpg15     |          1.56 |                      0.053 |                       32.32 |                       123.1  |
# | trimgalore    | gpg22     |          0.86 |                      0.17  |                      102.85 |                       136.38 |
# | trimgalore    | hu26      |          1.05 |                      0.005 |                        3.04 |                        90.7  |
# | trimgalore    | server    |          1    |                      0.021 |                       12.85 |                        25.66 |
#
# feb
# Comparison of Tasks @ Varied Frequencies using Average CI Data
# | task          | machine   |   runtime (h) |   energy consumption (kWh) |   average emissions (gCO2e) |   marginal emissions (gCO2e) |
# |---------------+-----------+---------------+----------------------------+-----------------------------+------------------------------|
# | bowtie2_build | gcpc2     |          0.16 |                      0.005 |                        0.62 |                         1.11 |
# | bowtie2_build | gcpn2     |          0.18 |                      0.003 |                        0.42 |                         0.83 |
# | bowtie2_build | gcpn1     |          0.25 |                      0.002 |                        0.23 |                         0.57 |
# | bowtie2_build | gpg13     |          0.25 |                      0.022 |                        2.79 |                         6.78 |
# | bowtie2_build | gpg14     |          0.25 |                      0.022 |                        2.73 |                         6.66 |
# | bowtie2_build | gpg15     |          0.25 |                      0.024 |                        2.97 |                         7.28 |
# | bowtie2_build | gpg22     |          0.15 |                      0.029 |                        3.6  |                         5.67 |
# | bowtie2_build | hu26      |          0.16 |                      0.017 |                        2.14 |                         3.76 |
# | bowtie2_build | server    |          0.14 |                      0.004 |                        0.55 |                         0.79 |
# | fastp         | gcpc2     |          0.06 |                      0.002 |                        0.25 |                         0.91 |
# | fastp         | gcpn2     |          0.08 |                      0.002 |                        0.19 |                         0.72 |
# | fastp         | gcpn1     |          0.15 |                      0.001 |                        0.16 |                         0.27 |
# | fastp         | gpg13     |          0.14 |                      0.013 |                        1.48 |                         2.33 |
# | fastp         | gpg14     |          0.16 |                      0.014 |                        1.62 |                         2.93 |
# | fastp         | gpg15     |          0.17 |                      0.017 |                        1.92 |                         3.82 |
# | fastp         | gpg22     |          0.11 |                      0.022 |                        2.51 |                         2.45 |
# | fastp         | hu26      |          0.05 |                      0.005 |                        0.61 |                         2.26 |
# | fastp         | server    |          0.05 |                      0.002 |                        0.19 |                         0.72 |
# | fastqc        | gcpc2     |          0.18 |                      0.006 |                        0.64 |                         1.26 |
# | fastqc        | gcpn2     |          0.21 |                      0.004 |                        0.43 |                         0.93 |
# | fastqc        | gcpn1     |          0.26 |                      0.002 |                        0.22 |                         0.55 |
# | fastqc        | gpg13     |          0.26 |                      0.023 |                        2.67 |                         6.58 |
# | fastqc        | gpg14     |          0.26 |                      0.023 |                        2.62 |                         6.47 |
# | fastqc        | gpg15     |          0.26 |                      0.025 |                        2.82 |                         6.97 |
# | fastqc        | gpg22     |          0.13 |                      0.025 |                        2.87 |                         3.55 |
# | fastqc        | hu26      |          0.16 |                      0.017 |                        2.01 |                         3.57 |
# | fastqc        | server    |          0.16 |                      0.005 |                        0.57 |                         0.97 |
# | trimgalore    | gcpc2     |          1.07 |                      0.002 |                        0.39 |                        15.6  |
# | trimgalore    | gcpn2     |          1.28 |                      0.006 |                        0.88 |                        10.89 |
# | trimgalore    | gcpn1     |          1.93 |                      0.009 |                        1.42 |                         8.14 |
# | trimgalore    | gpg13     |          1.5  |                      0.046 |                        7.25 |                        59.04 |
# | trimgalore    | gpg14     |          1.49 |                      0.044 |                        6.89 |                        57.07 |
# | trimgalore    | gpg15     |          1.56 |                      0.053 |                        8.4  |                        64.19 |
# | trimgalore    | gpg22     |          0.86 |                      0.17  |                       24.68 |                        71.32 |
# | trimgalore    | hu26      |          1.05 |                      0.005 |                        0.79 |                        47.99 |
# | trimgalore    | server    |          1    |                      0.021 |                        3.34 |                        13.58 |
# | bowtie2_build | gcpc2     |          0.16 |                      0.005 |                        1.75 |                         1.82 |
# | bowtie2_build | gcpn2     |          0.18 |                      0.003 |                        1.17 |                         1.37 |
# | bowtie2_build | gcpn1     |          0.25 |                      0.002 |                        0.65 |                         0.93 |
# | bowtie2_build | gpg13     |          0.25 |                      0.022 |                        7.81 |                        11.11 |
# | bowtie2_build | gpg14     |          0.25 |                      0.022 |                        7.65 |                        10.91 |
# | bowtie2_build | gpg15     |          0.25 |                      0.024 |                        8.32 |                        11.93 |
# | bowtie2_build | gpg22     |          0.15 |                      0.029 |                       10.1  |                         9.29 |
# | bowtie2_build | hu26      |          0.16 |                      0.017 |                        5.99 |                         6.16 |
# | bowtie2_build | server    |          0.14 |                      0.004 |                        1.53 |                         1.29 |
# | fastp         | gcpc2     |          0.06 |                      0.002 |                        0.7  |                         1.6  |
# | fastp         | gcpn2     |          0.08 |                      0.002 |                        0.55 |                         1.27 |
# | fastp         | gcpn1     |          0.15 |                      0.001 |                        0.46 |                         0.5  |
# | fastp         | gpg13     |          0.14 |                      0.013 |                        4.23 |                         4.34 |
# | fastp         | gpg14     |          0.16 |                      0.014 |                        4.62 |                         5.46 |
# | fastp         | gpg15     |          0.17 |                      0.017 |                        5.49 |                         7.08 |
# | fastp         | gpg22     |          0.11 |                      0.022 |                        7.17 |                         4.58 |
# | fastp         | hu26      |          0.05 |                      0.005 |                        1.74 |                         3.97 |
# | fastp         | server    |          0.05 |                      0.002 |                        0.55 |                         1.27 |
# | fastqc        | gcpc2     |          0.18 |                      0.006 |                        1.97 |                         2.27 |
# | fastqc        | gcpn2     |          0.21 |                      0.004 |                        1.31 |                         1.68 |
# | fastqc        | gcpn1     |          0.26 |                      0.002 |                        0.68 |                         1    |
# | fastqc        | gpg13     |          0.26 |                      0.023 |                        8.16 |                        11.84 |
# | fastqc        | gpg14     |          0.26 |                      0.023 |                        8    |                        11.65 |
# | fastqc        | gpg15     |          0.26 |                      0.025 |                        8.62 |                        12.54 |
# | fastqc        | gpg22     |          0.13 |                      0.025 |                        8.77 |                         6.39 |
# | fastqc        | hu26      |          0.16 |                      0.017 |                        6.13 |                         6.43 |
# | fastqc        | server    |          0.16 |                      0.005 |                        1.75 |                         1.75 |
# | trimgalore    | gcpc2     |          1.07 |                      0.002 |                        0.98 |                        24.79 |
# | trimgalore    | gcpn2     |          1.28 |                      0.006 |                        2.2  |                        17.38 |
# | trimgalore    | gcpn1     |          1.93 |                      0.009 |                        3.55 |                        13.05 |
# | trimgalore    | gpg13     |          1.5  |                      0.046 |                       18.09 |                        94.54 |
# | trimgalore    | gpg14     |          1.49 |                      0.044 |                       17.19 |                        91.36 |
# | trimgalore    | gpg15     |          1.56 |                      0.053 |                       20.97 |                       102.85 |
# | trimgalore    | gpg22     |          0.86 |                      0.17  |                       63.8  |                       117.77 |
# | trimgalore    | hu26      |          1.05 |                      0.005 |                        1.97 |                        76.29 |
# | trimgalore    | server    |          1    |                      0.021 |                        8.42 |                        21.61 |
# | bowtie2_build | gcpc2     |          0.16 |                      0.005 |                        1.23 |                         1.05 |
# | bowtie2_build | gcpn2     |          0.18 |                      0.003 |                        0.82 |                         0.79 |
# | bowtie2_build | gcpn1     |          0.25 |                      0.002 |                        0.46 |                         0.54 |
# | bowtie2_build | gpg13     |          0.25 |                      0.022 |                        5.47 |                         6.44 |
# | bowtie2_build | gpg14     |          0.25 |                      0.022 |                        5.36 |                         6.33 |
# | bowtie2_build | gpg15     |          0.25 |                      0.024 |                        5.83 |                         6.92 |
# | bowtie2_build | gpg22     |          0.15 |                      0.029 |                        7.08 |                         5.39 |
# | bowtie2_build | hu26      |          0.16 |                      0.017 |                        4.2  |                         3.57 |
# | bowtie2_build | server    |          0.14 |                      0.004 |                        1.07 |                         0.75 |
# | fastp         | gcpc2     |          0.06 |                      0.002 |                        0.52 |                         0.95 |
# | fastp         | gcpn2     |          0.08 |                      0.002 |                        0.41 |                         0.75 |
# | fastp         | gcpn1     |          0.15 |                      0.001 |                        0.34 |                         0.28 |
# | fastp         | gpg13     |          0.14 |                      0.013 |                        3.16 |                         2.44 |
# | fastp         | gpg14     |          0.16 |                      0.014 |                        3.45 |                         3.06 |
# | fastp         | gpg15     |          0.17 |                      0.017 |                        4.1  |                         4    |
# | fastp         | gpg22     |          0.11 |                      0.022 |                        5.36 |                         2.57 |
# | fastp         | hu26      |          0.05 |                      0.005 |                        1.3  |                         2.36 |
# | fastp         | server    |          0.05 |                      0.002 |                        0.41 |                         0.75 |
# | fastqc        | gcpc2     |          0.18 |                      0.006 |                        1.3  |                         1.32 |
# | fastqc        | gcpn2     |          0.21 |                      0.004 |                        0.87 |                         0.98 |
# | fastqc        | gcpn1     |          0.26 |                      0.002 |                        0.45 |                         0.58 |
# | fastqc        | gpg13     |          0.26 |                      0.023 |                        5.38 |                         6.92 |
# | fastqc        | gpg14     |          0.26 |                      0.023 |                        5.28 |                         6.8  |
# ...
# | trimgalore    | gcpc2     |          1.07 |                      0.002 |                        0.68 |                        17.31 |
# | trimgalore    | gcpn2     |          1.28 |                      0.006 |                
|
# | trimgalore    | hu26      |          1.05 |                      0.005 |                        2.81 |                        86.18 |
# | trimgalore    | server    |          1    |                      0.021 |                       12.24 |                        24.38 |

# %%
headers = ['task', 'machine', 'runtime (h)', 'energy consumption (kWh)', 'average emissions (gCO2e)', 'marginal emissions (gCO2e)']
mean_data = []

for task in tasks:
    for machine in machines:
        entry = all_ra_data[task][machine]
        mean_avg_ems = sum(entry['avg emissions']) / len(entry['avg emissions'])
        mean_marg_ems = sum(entry['marg emissions']) / len(entry['marg emissions'])
        mean_data.append([task, machine, entry['runtime'], entry['energy'], round(mean_avg_ems, 2), round(mean_marg_ems, 2)])
    mean_data.append([])

print(tabulate(mean_data, headers, tablefmt='orgtbl'))

with open('../data/results/resource-assignment/table_mean_data.csv', 'w') as f:
    f.write(','.join(headers) + '\n')

    for row in mean_data: 
        f.write(','.join([str(v) for v in row]) + '\n')
# Out:
# | task          | machine   |   runtime (h) |   energy consumption (kWh) |   average emissions (gCO2e) |   marginal emissions (gCO2e) |
# |---------------+-----------+---------------+----------------------------+-----------------------------+------------------------------|
# | bowtie2_build | gcpc2     |          0.16 |                      0.005 |                        1.81 |                         1.45 |
# | bowtie2_build | gcpn2     |          0.18 |                      0.003 |                        1.21 |                         1.09 |
# | bowtie2_build | gcpn1     |          0.25 |                      0.002 |                        0.68 |                         0.74 |
# | bowtie2_build | gpg13     |          0.25 |                      0.022 |                        8.09 |                         8.82 |
# | bowtie2_build | gpg14     |          0.25 |                      0.022 |                        7.92 |                         8.66 |
# | bowtie2_build | gpg15     |          0.25 |                      0.024 |                        8.62 |                         9.47 |
# | bowtie2_build | gpg22     |          0.15 |                      0.029 |                       10.46 |                         7.4  |
# | bowtie2_build | hu26      |          0.16 |                      0.017 |                        6.21 |                         4.9  |
# | bowtie2_build | server    |          0.14 |                      0.004 |                        1.59 |                         1.03 |
# |               |           |               |                            |                             |                              |
# | fastp         | gcpc2     |          0.06 |                      0.002 |                        0.79 |                         1.29 |
# | fastp         | gcpn2     |          0.08 |                      0.002 |                        0.63 |                         1.02 |
# | fastp         | gcpn1     |          0.15 |                      0.001 |                        0.52 |                         0.38 |
# | fastp         | gpg13     |          0.14 |                      0.013 |                        4.79 |                         3.32 |
# | fastp         | gpg14     |          0.16 |                      0.014 |                        5.23 |                         4.17 |
# | fastp         | gpg15     |          0.17 |                      0.017 |                        6.22 |                         5.45 |
# | fastp         | gpg22     |          0.11 |                      0.022 |                        8.12 |                         3.5  |
# | fastp         | hu26      |          0.05 |                      0.005 |                        1.97 |                         3.21 |
# | fastp         | server    |          0.05 |                      0.002 |                        0.63 |                         1.02 |
# |               |           |               |                            |                             |                              |
# | fastqc        | gcpc2     |          0.18 |                      0.006 |                        2.07 |                         1.75 |
# | fastqc        | gcpn2     |          0.21 |                      0.004 |                        1.38 |                         1.29 |
# | fastqc        | gcpn1     |          0.26 |                      0.002 |                        0.72 |                         0.77 |
# | fastqc        | gpg13     |          0.26 |                      0.023 |                        8.59 |                         9.12 |
# | fastqc        | gpg14     |          0.26 |                      0.023 |                        8.42 |                         8.97 |
# | fastqc        | gpg15     |          0.26 |                      0.025 |                        9.07 |                         9.66 |
# | fastqc        | gpg22     |          0.13 |                      0.025 |                        9.23 |                         4.92 |
# | fastqc        | hu26      |          0.16 |                      0.017 |                        6.46 |                         4.95 |
# | fastqc        | server    |          0.16 |                      0.005 |                        1.84 |                         1.35 |
# |               |           |               |                            |                             |                              |
# | trimgalore    | gcpc2     |          1.07 |                      0.002 |                        0.89 |                        20.3  |
# | trimgalore    | gcpn2     |          1.28 |                      0.006 |                        2    |                        14.28 |
# | trimgalore    | gcpn1     |          1.93 |                      0.009 |                        3.23 |                        10.68 |
# | trimgalore    | gpg13     |          1.5  |                      0.046 |                       16.44 |                        77.69 |
# | trimgalore    | gpg14     |          1.49 |                      0.044 |                       15.63 |                        75.08 |
# | trimgalore    | gpg15     |          1.56 |                      0.053 |                       19.06 |                        84.53 |
# | trimgalore    | gpg22     |          0.86 |                      0.17  |                       61.38 |                        95.97 |
# | trimgalore    | hu26      |          1.05 |                      0.005 |                        1.8  |                        62.47 |
# | trimgalore    | server    |          1    |                      0.021 |                        7.66 |                        17.7  |
# |               |           |               |                            |                             |                              |
